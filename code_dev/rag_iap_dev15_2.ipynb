# %%
import re
import uuid
from dataclasses import dataclass, field
from typing import List, Dict, Any, Tuple
from pathlib import Path

# --------- 유틸: 키 정규화 / 용어 추출 ---------
_WORD_SPLIT_RE = re.compile(r"[^\w]+", re.UNICODE)
CAMEL_RE = re.compile(r"(?<!^)(?=[A-Z])")

def normalize_key(s: str) -> str:
    # 대소문자/구분자 정규화 (camel/snake/kebab → 토큰화 후 소문자)
    s = s.strip()
    s = CAMEL_RE.sub(" ", s)
    toks = _WORD_SPLIT_RE.split(s.lower())
    toks = [t for t in toks if t]
    return " ".join(toks)

def extract_exact_keys(text: str) -> List[str]:
    keys = []
    # 코드값/상수/식별자 패턴들 (원문 보존)
    patterns = [
        r"\b[A-Z0-9_]{3,}\b",                 # E401, SINGLE_PAYMENT_TRANSACTION, MKT_ONE
        r"\b[A-Za-z_]+=[A-Za-z0-9._-]+\b",    # KEY=VALUE
        r'"[A-Za-z0-9_.-]+"\s*:',             # "msgVersion":  (JSON 필드명)
    ]
    for pat in patterns:
        for m in re.finditer(pat, text):
            keys.append(m.group(0).strip('"').rstrip(":"))
    # 중복 제거, 과도한 수는 상한
    dedup = []
    seen = set()
    for k in keys:
        if k not in seen:
            seen.add(k); dedup.append(k)
    return dedup[:200]

def extract_term_keys(title: str, body: str) -> List[str]:
    candidates = []
    # 제목/굵은글/정의형 문장 등에서 후보 수집(간단 규칙)
    candidates.append(title)
    for m in re.finditer(r"\*\*(.+?)\*\*", body):
        candidates.append(m.group(1))
    for m in re.finditer(r"(.+?)(?:란|은|는)\s.+?(?:이다|입니다)\.", body):
        if len(m.group(1)) <= 40:
            candidates.append(m.group(1))
    # 정규화 + dedup
    norm = []
    seen = set()
    for c in candidates:
        k = normalize_key(c)
        if k and k not in seen:
            seen.add(k); norm.append(k)
    return norm[:100]

# --------- 마크다운 파서(간단): H1~H3 섹션/코드/표/이미지 ---------
CODE_BLOCK_RE = re.compile(r"```([a-zA-Z0-9_-]*)[^\n]*\n(.*?)```", re.DOTALL)
TABLE_RE = re.compile(r"(?:^\|.*\|\s*\n)+", re.MULTILINE)  # Markdown 표 블록 대략 매칭
IMAGE_RE = re.compile(r"!\[(.*?)\]\((.*?)(?:\s+\"(.*?)\")?\)")

@dataclass
class Tile:
    id: str
    type: str  # definition|explanation|code|table|image
    text: str
    metadata: Dict[str, Any] = field(default_factory=dict)

@dataclass
class SectionPack:
    id: str
    title: str
    heading_path: str
    text: str               # 섹션 전체 텍스트(코드/표 캡션 요약 포함)
    tiles: List[Tile]
    metadata: Dict[str, Any] = field(default_factory=dict)

def split_markdown_to_sections(md_text: str, doc_id: str) -> List[SectionPack]:
    """
    H2/H3 기준 섹션을 만들고, 섹션별로 타일(정의/설명/코드/표/이미지)을 생성.
    코드/표는 '원자' 보존: 절대로 분할하지 않음.
    """
    # 헤더 파싱: 간단하게 H2/H3 라인 인덱스 수집
    lines = md_text.splitlines()
    header_idxs: List[Tuple[int, str, int]] = []  # (line_idx, title, level)
    for i, ln in enumerate(lines):
        m = re.match(r"^(#{2,3})\s+(.*)", ln)  # ## or ###
        if m:
            level = len(m.group(1))
            header_idxs.append((i, m.group(2).strip(), level))

    # 문서 전체를 하나의 H1로 간주하여 첫 섹션 전 구간 포함
    boundaries = []
    for idx, (line_idx, title, level) in enumerate(header_idxs):
        start = line_idx
        end = header_idxs[idx+1][0] if idx+1 < len(header_idxs) else len(lines)
        boundaries.append((start, end, title, level))

    section_packs: List[SectionPack] = []

    for start, end, title, level in boundaries:
        raw = "\n".join(lines[start:end])
        section_id = str(uuid.uuid4())

        # 코드블록 추출(원문 보존)
        code_tiles = []
        def code_repl(m):
            lang = (m.group(1) or "").lower()
            code = m.group(2)
            tile = Tile(
                id=str(uuid.uuid4()),
                type="code",
                text=code.strip(),
                metadata={"code_lang": lang or "text"}
            )
            code_tiles.append(tile)
            return f"\n[CODE_BLOCK::{tile.id}]\n"  # 자리표시자

        raw_wo_code = re.sub(CODE_BLOCK_RE, code_repl, raw)

        # 표 추출(원문 보존)
        table_tiles = []
        def table_repl(m):
            tbl = m.group(0)
            tile = Tile(
                id=str(uuid.uuid4()),
                type="table",
                text=tbl.strip(),
                metadata={}
            )
            table_tiles.append(tile)
            return f"\n[TABLE_BLOCK::{tile.id}]\n"

        raw_wo_code_table = re.sub(TABLE_RE, table_repl, raw_wo_code)

        # 이미지 캡션 추출
        image_tiles = []
        def image_repl(m):
            alt, path, title_opt = m.group(1), m.group(2), m.group(3) or ""
            caption = (alt or title_opt or path)
            tile = Tile(
                id=str(uuid.uuid4()),
                type="image",
                text=caption.strip(),
                metadata={"image_path": path}
            )
            image_tiles.append(tile)
            return f"\n[IMAGE_BLOCK::{tile.id}]\n"

        raw_clean = re.sub(IMAGE_RE, image_repl, raw_wo_code_table)

        # 정의/설명 타일 만들기
        # 첫 단락을 definition, 나머지를 explanation 타일들로 (문단 기준 분할, 10~15% 겹침 없음)
        paragraphs = [p.strip() for p in re.split(r"\n\s*\n", raw_clean) if p.strip()]
        tiles: List[Tile] = []

        if paragraphs:
            tiles.append(Tile(
                id=str(uuid.uuid4()),
                type="definition",
                text=paragraphs[0],
                metadata={}
            ))
            for p in paragraphs[1:]:
                tiles.append(Tile(
                    id=str(uuid.uuid4()),
                    type="explanation",
                    text=p,
                    metadata={}
                ))

        # 코드/표/이미지 타일 추가 (원자 보존)
        tiles.extend(code_tiles)
        tiles.extend(table_tiles)
        tiles.extend(image_tiles)

        # 메타데이터 구성
        heading_path = title  # 간단 예시: 실제로는 상위 H1/H2 경로까지 축적 권장
        body_for_keys = "\n".join(t.text for t in tiles if t.type in ("definition","explanation"))
        term_keys = extract_term_keys(title, body_for_keys)
        exact_keys = extract_exact_keys(raw)

        # 섹션팩 텍스트(LLM 주입용): 자리표시자 → 간단 요약문으로 치환
        def restore_placeholders(s: str) -> str:
            s = re.sub(r"\[CODE_BLOCK::([-\w]+)\]", "[코드블록: 전체 포함]", s)
            s = re.sub(r"\[TABLE_BLOCK::([-\w]+)\]", "[표: 전체 포함]", s)
            s = re.sub(r"\[IMAGE_BLOCK::([-\w]+)\]", "[이미지 캡션 포함]", s)
            return s

        section_text = restore_placeholders(raw_clean)

        pack = SectionPack(
            id=section_id,
            title=title,
            heading_path=heading_path,
            text=section_text.strip(),
            tiles=tiles,
            metadata={
                "doc_id": doc_id,
                "section_title": title,
                "heading_path": heading_path,
                "term_keys": term_keys,
                "exact_keys": exact_keys,
            }
        )
        # 타일 공통 메타 바인딩
        for t in pack.tiles:
            t.metadata.update({
                "doc_id": doc_id,
                "section_id": section_id,
                "section_title": title,
                "heading_path": heading_path,
            })
            if t.type == "table":
                # 표 헤더/키 후보 추출(간단): 1행을 헤더로 가정
                lines_tbl = [ln for ln in t.text.splitlines() if ln.strip()]
                if lines_tbl:
                    t.metadata["table_header"] = lines_tbl[0]
            if t.type == "code":
                t.metadata["exact_keys"] = extract_exact_keys(t.text)

        section_packs.append(pack)

    return section_packs

# %%
### TEST_CODE ###

def read_file_content(input_path: str) -> str:
    try:
        # UTF-8 인코딩으로 파일 읽기
        with open(input_path, 'r', encoding='utf-8') as f:
            content = f.read()
        return content
    except FileNotFoundError:
        raise FileNotFoundError(f"파일을 찾을 수 없습니다: {input_path}")
          
all_text = read_file_content("data/dev_center_guide_allmd_touched.md") 
# print(all_text)

list_section = split_markdown_to_sections(all_text, doc_id="iap_dev_integration_guide")

cnt = 0
for section in list_section:
    print(section)
    cnt += 1
    # if 'CANCELED' in section.text:
    #     print(section.title)
    #     print("=" * 50)
    #     print(section.text)
    #     print("-" * 100)
    #     cnt += 1

print(f"문장 개수: {cnt}")
# Out:
# SectionPack(id='87331454-5b8a-4768-a9f9-326de91b8b7d', title='**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', heading_path='**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', text='## **원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>\n\n원스토어 인앱결제(In-App Purchase, IAP)는 안드로이드 앱 내에 구현된 상품을 원스토어의 인증 및 결제 시스템을 이용하여 사용자에게 판매, 청구하여 개발자에게 정산하는 서비스입니다.\n\n인앱 상품 결제를 위해 원스토어 서비스(ONE store service, OSS) 앱과 연동이 필요하며, 원스토어 서비스 앱은 원스토어 결제 서버와 연동하여 인앱상품의 결제를 수행합니다.\n\n원스토어 인앱결제를 적용하기 위해서는 \'원스토어 IAP SDK(In-App Purchase Software Development Kit)\'를 적용하면 됩니다.', tiles=[Tile(id='c6f2880c-5c37-4907-ae4a-d248e56e527e', type='definition', text='## **원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '87331454-5b8a-4768-a9f9-326de91b8b7d', 'section_title': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', 'heading_path': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>'}), Tile(id='41ecf171-308d-4298-8018-6f762866fd00', type='explanation', text='원스토어 인앱결제(In-App Purchase, IAP)는 안드로이드 앱 내에 구현된 상품을 원스토어의 인증 및 결제 시스템을 이용하여 사용자에게 판매, 청구하여 개발자에게 정산하는 서비스입니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '87331454-5b8a-4768-a9f9-326de91b8b7d', 'section_title': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', 'heading_path': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>'}), Tile(id='bfedc377-19c7-4250-a6dc-3c4f5d846467', type='explanation', text='인앱 상품 결제를 위해 원스토어 서비스(ONE store service, OSS) 앱과 연동이 필요하며, 원스토어 서비스 앱은 원스토어 결제 서버와 연동하여 인앱상품의 결제를 수행합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '87331454-5b8a-4768-a9f9-326de91b8b7d', 'section_title': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', 'heading_path': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>'}), Tile(id='22ffaad9-5a1e-468e-8faf-bea3ece1c1e7', type='explanation', text="원스토어 인앱결제를 적용하기 위해서는 '원스토어 IAP SDK(In-App Purchase Software Development Kit)'를 적용하면 됩니다.", metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '87331454-5b8a-4768-a9f9-326de91b8b7d', 'section_title': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', 'heading_path': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', 'heading_path': '**원스토어 인앱결제란?** <a href="#id-01." id="id-01."></a>', 'term_keys': ['원스토어 인앱결제란 a href id 01 id id 01 a', '원스토어 인앱결제란', '원스토어 인앱결제 in app purchase i a p'], 'exact_keys': ['IAP', 'ONE', 'OSS', 'SDK']})
# SectionPack(id='f978d612-d35c-4e0e-ad25-423ad8f44cd6', title='**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>', heading_path='**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>', text='## **인앱 상품의 유형** <a href="#id-01." id="id-01."></a>\n\n원스토어 인앱결제 API V7(SDK V21)는 관리형 상품과 구독형 상품. 두 가지 유형의 인앱 상품을 제공 합니다.\\\n우선, 각 타입이 어떤 특성을 가지고 있는지 확인하신 후 본인이 제공하는 상품에 맞게 인앱 상품 목록을 구성해 보시기 바랍니다.\n\n<table><thead><tr><th width="239">구분</th><th>내용</th></tr></thead><tbody><tr><td>관리형 상품</td><td>구매 후 소비(consume)하기 전까지 재구매가 되지 않는 상품입니다. 해당 상품을 다시 구매하기 위해서는 소비(consume) 처리를 해야 합니다.<br>해당 특성을 이용하여 소비성/영구성/기간제 형태의 인앱 상품을 제공 할 수 있습니다.</td></tr><tr><td>월정액 상품 (Deprecated)</td><td><p>한 번 가입하면 지정된 날짜에 매월 일정 금액이 자동결제 되는 상품으로, 자동결제 갱신(재결제)은 원스토어에서 처리합니다.</p><p>SDK V21 (API V7) 적용 이후 신규 월정액 상품은 만들 수 없습니다. (기존에 만들어진 월정액 상품은 계속 이용 하실 수 있습니다.) </p><p>구독형 상품을 이용하여 정기 결제 상품을 제공할 수 있습니다,  </p></td></tr><tr><td>구독형 상품</td><td><p>SDK V21 (API V7) 부터 제공되는 정기 결제 상품 타입입니다.</p><p>정해진 주기에 따라 원스토어에서 정기 결제를 처리하며, 신규 고객을 유치하기 위한 프로모션 기능 및 결제 수단 변경 등의 사용자 편의 기능을 제공합니다. </p><p>구독형 상품에 대한 자세한 내용은 <a href="subs">정기결제 적용하기</a> 페이지를 참고하시기 바랍니다.</p></td></tr></tbody></table>', tiles=[Tile(id='9e5f9fee-356a-4f99-835c-282c735c87b2', type='definition', text='## **인앱 상품의 유형** <a href="#id-01." id="id-01."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f978d612-d35c-4e0e-ad25-423ad8f44cd6', 'section_title': '**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>'}), Tile(id='648d5562-4803-4b36-9892-b909c49bacc8', type='explanation', text='원스토어 인앱결제 API V7(SDK V21)는 관리형 상품과 구독형 상품. 두 가지 유형의 인앱 상품을 제공 합니다.\\\n우선, 각 타입이 어떤 특성을 가지고 있는지 확인하신 후 본인이 제공하는 상품에 맞게 인앱 상품 목록을 구성해 보시기 바랍니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f978d612-d35c-4e0e-ad25-423ad8f44cd6', 'section_title': '**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>'}), Tile(id='026bf60e-06bf-4587-8c5d-0bddda1f8372', type='explanation', text='<table><thead><tr><th width="239">구분</th><th>내용</th></tr></thead><tbody><tr><td>관리형 상품</td><td>구매 후 소비(consume)하기 전까지 재구매가 되지 않는 상품입니다. 해당 상품을 다시 구매하기 위해서는 소비(consume) 처리를 해야 합니다.<br>해당 특성을 이용하여 소비성/영구성/기간제 형태의 인앱 상품을 제공 할 수 있습니다.</td></tr><tr><td>월정액 상품 (Deprecated)</td><td><p>한 번 가입하면 지정된 날짜에 매월 일정 금액이 자동결제 되는 상품으로, 자동결제 갱신(재결제)은 원스토어에서 처리합니다.</p><p>SDK V21 (API V7) 적용 이후 신규 월정액 상품은 만들 수 없습니다. (기존에 만들어진 월정액 상품은 계속 이용 하실 수 있습니다.) </p><p>구독형 상품을 이용하여 정기 결제 상품을 제공할 수 있습니다,  </p></td></tr><tr><td>구독형 상품</td><td><p>SDK V21 (API V7) 부터 제공되는 정기 결제 상품 타입입니다.</p><p>정해진 주기에 따라 원스토어에서 정기 결제를 처리하며, 신규 고객을 유치하기 위한 프로모션 기능 및 결제 수단 변경 등의 사용자 편의 기능을 제공합니다. </p><p>구독형 상품에 대한 자세한 내용은 <a href="subs">정기결제 적용하기</a> 페이지를 참고하시기 바랍니다.</p></td></tr></tbody></table>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f978d612-d35c-4e0e-ad25-423ad8f44cd6', 'section_title': '**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품의 유형** <a href="#id-01." id="id-01."></a>', 'term_keys': ['인앱 상품의 유형 a href id 01 id id 01 a', '인앱 상품의 유형', '해당 상품을 다시 구매하기 위해서'], 'exact_keys': ['API', 'SDK', 'V21', '239']})
# SectionPack(id='e7c8fdd8-1259-40a0-96f3-35c03cf8f789', title='**결제 프로세스** <a href="#id-01." id="id-01."></a>', heading_path='**결제 프로세스** <a href="#id-01." id="id-01."></a>', text='## **결제 프로세스** <a href="#id-01." id="id-01."></a>\n\n원스토어 인앱결제는 크게 다음의 네 가지 프로세스로 구성되어 있습니다.&#x20;', tiles=[Tile(id='6439f073-c414-4c76-859d-7055fd9dc785', type='definition', text='## **결제 프로세스** <a href="#id-01." id="id-01."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'e7c8fdd8-1259-40a0-96f3-35c03cf8f789', 'section_title': '**결제 프로세스** <a href="#id-01." id="id-01."></a>', 'heading_path': '**결제 프로세스** <a href="#id-01." id="id-01."></a>'}), Tile(id='587af1c2-050b-4f0d-9856-3093769493f5', type='explanation', text='원스토어 인앱결제는 크게 다음의 네 가지 프로세스로 구성되어 있습니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'e7c8fdd8-1259-40a0-96f3-35c03cf8f789', 'section_title': '**결제 프로세스** <a href="#id-01." id="id-01."></a>', 'heading_path': '**결제 프로세스** <a href="#id-01." id="id-01."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**결제 프로세스** <a href="#id-01." id="id-01."></a>', 'heading_path': '**결제 프로세스** <a href="#id-01." id="id-01."></a>', 'term_keys': ['결제 프로세스 a href id 01 id id 01 a', '결제 프로세스'], 'exact_keys': []})
# SectionPack(id='25551d74-1642-48a5-90be-076a3707d84d', title='원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', heading_path='원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', text='### 원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>\n\n#### **GaaSignInClient 초기화**\n\nGaaSignInClient는 원스토어 로그인을 하기 위한 라이브러리입니다.\n\ngetClient() 통해 인스턴스를 생성합니다.\n\n\n[코드블록: 전체 포함]\n\n\n#### **포그라운드 로그인하기**\n\nslientSignIn()과 달리 해당 함수는 UiThread 에서만 호출해야 합니다.\n\n기본적으로 먼저 백그라운드 로그인을 시도하지만 실패에 대한 처리를 SDK에서 전담하여 처리합니다.\\\n이 후, 로그인 화면을 띄워 사용자에게 로그인을 유도합니다.\n\n\n[코드블록: 전체 포함]\n\n\n#### **백그라운드 로그인하기**\n\nslientSignIn() 통해 백그라운도 로그인을 호출합니다.\n\n사용자가 이미 원스토어 계정에 로그인 되어있을 경우 이후 부터는 백그라운드에서 토큰로그인을 시도합니다. 성공 또는 실패에 대한 결과값으로 SignInResult 객체로 응답을 받습니다.\n\n\n[코드블록: 전체 포함]', tiles=[Tile(id='0d59c940-dbc4-4394-a9fe-1c7409629614', type='definition', text='### 원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id='11019109-b095-41d1-b8ef-a5a5a6ce2cef', type='explanation', text='#### **GaaSignInClient 초기화**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id='ef5e06ee-d65a-432c-97cf-569e26b69049', type='explanation', text='GaaSignInClient는 원스토어 로그인을 하기 위한 라이브러리입니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id='55df14f0-6d72-4bde-88b5-d5abbb9aab25', type='explanation', text='getClient() 통해 인스턴스를 생성합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id='469766cf-7d7e-49b9-8d4c-9c39660b2caf', type='explanation', text='[CODE_BLOCK::3793032e-5e3a-45fe-a112-1a62a8111b51]', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id='0d021161-5809-490c-a427-1b4c5d4c4a70', type='explanation', text='#### **포그라운드 로그인하기**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id='712a45be-4320-4646-864d-2c192eb0bda2', type='explanation', text='slientSignIn()과 달리 해당 함수는 UiThread 에서만 호출해야 합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id='a64ee9b2-be39-4e9e-8774-c320772bc4a2', type='explanation', text='기본적으로 먼저 백그라운드 로그인을 시도하지만 실패에 대한 처리를 SDK에서 전담하여 처리합니다.\\\n이 후, 로그인 화면을 띄워 사용자에게 로그인을 유도합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id='87ce4960-abb4-4f85-8b5c-546b5e9e4098', type='explanation', text='[CODE_BLOCK::b1b9a352-0e89-4c12-a32f-8890d2ec8d2a]', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '25551d74-1642-48a5-90be-076a3707d84d', 'section_title': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>', 'heading_path': '원스토어 로그인 하기 <a href="#id-01." id="id-01."></a>'}), Tile(id=' ...
# SectionPack(id='6826e09b-6908-42a4-aa71-b348bd7fb3e2', title='**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', heading_path='**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', text='### **인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>\n\n상품을 구매하려면 먼저 상품 상세정보(queryProductDetailAsync) API 호출하여 상품의 정보을 가지고 launchPurchaseFlow API를 통해 구매 화면을 호출합니다.\n\n결제가 완료되면 PurchaseClient 객체를 초기화할 때 입력한 PurchasesUpdatedListener를 통해 구매정보를 전달받을 수 있습니다.\n\n결과 코드값을 검증한 후에 성공으로 확인되면 인앱 상품에 해당하는 아이템을 지급하는 프로세스를 진행합니다.\n\n아래 그림은 개발사 앱과 원스토어 사이의 인앱 상품을 구매하는 프로세스를 나타낸 것입니다.&#x20;\n\n&#x20;\n\n<figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2Fp9qDWlNUqSDbGD8tvxQH%2Fimage.png?alt=media&#x26;token=6d15b347-fa3d-4b63-aab2-138df9135dc3" alt=""><figcaption></figcaption></figure>', tiles=[Tile(id='ed5fb65e-b61a-482a-9f1f-4cc86f96eb56', type='definition', text='### **인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '6826e09b-6908-42a4-aa71-b348bd7fb3e2', 'section_title': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='a1abbfb8-1423-46e6-b7a7-73667b6aba9e', type='explanation', text='상품을 구매하려면 먼저 상품 상세정보(queryProductDetailAsync) API 호출하여 상품의 정보을 가지고 launchPurchaseFlow API를 통해 구매 화면을 호출합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '6826e09b-6908-42a4-aa71-b348bd7fb3e2', 'section_title': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='01cfe862-2338-48e4-8d56-d5c0b748f02c', type='explanation', text='결제가 완료되면 PurchaseClient 객체를 초기화할 때 입력한 PurchasesUpdatedListener를 통해 구매정보를 전달받을 수 있습니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '6826e09b-6908-42a4-aa71-b348bd7fb3e2', 'section_title': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='2e3e3e1e-cad6-4960-885e-5cc86a85ad62', type='explanation', text='결과 코드값을 검증한 후에 성공으로 확인되면 인앱 상품에 해당하는 아이템을 지급하는 프로세스를 진행합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '6826e09b-6908-42a4-aa71-b348bd7fb3e2', 'section_title': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='057f4d1e-2de1-4fbd-81bc-641415072826', type='explanation', text='아래 그림은 개발사 앱과 원스토어 사이의 인앱 상품을 구매하는 프로세스를 나타낸 것입니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '6826e09b-6908-42a4-aa71-b348bd7fb3e2', 'section_title': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='aac36777-8180-4010-9ca3-fdfed03c35f7', type='explanation', text='&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '6826e09b-6908-42a4-aa71-b348bd7fb3e2', 'section_title': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='333cef26-6c02-4057-b30a-98c8002c3461', type='explanation', text='<figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2Fp9qDWlNUqSDbGD8tvxQH%2Fimage.png?alt=media&#x26;token=6d15b347-fa3d-4b63-aab2-138df9135dc3" alt=""><figcaption></figcaption></figure>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '6826e09b-6908-42a4-aa71-b348bd7fb3e2', 'section_title': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**인앱 상품 구매 요청하기**  <a href="#id-01." id="id-0 ...
# SectionPack(id='b574f145-073c-4f1f-8ce7-2078e54ccfa2', title='**구매 확인하기**  <a href="#id-01." id="id-01."></a>', heading_path='**구매 확인하기**  <a href="#id-01." id="id-01."></a>', text='### **구매 확인하기**  <a href="#id-01." id="id-01."></a>\n\n원스토어 IAP 라이브러리 V6 이상을 사용하는 경우 3일 이내에 구매 확인을 진행해야 합니다. 구매 확인이 되지 않으면, 고객에게 구매 금액이 환불됩니다.&#x20;\n\n다음 두 가지 방법을 사용하면 구매를 확인할 수 있습니다.&#x20;\n\n*   **소비하기 (consume)**&#x20;\n\n    * 관리형 상품의 특징은 구매 후 소비(consume) 하기 전까지 재구매가 되지 않는 것입니다. 따라서, 관리형 상품 중 반복 구매가 가능한 소비성 상품을 제공할 경우에는 반드시 PurchaseClient.consumeAsync()를 사용하여 소비 처리를 해야 고객이 해당 상품을 다시 구매할 수 있습니다. &#x20;\n    * 소비성 형태의 상품을 구현할 때는 구매 프로세스 완료 후 바로 구매한 상품을 소비시키고, 소비가 완료된 후에 아이템을 지급합니다. &#x20;\n    * 사용자가 앱(게임)을 실행하는 시점 또는 앱(게임)에 로그인하는 시점에 위의 API들을 호출하여, 미지급된 상품이 있는지 사전에 체크하고 상품을 지급하는 프로세스를 추가하는 것을 권장합니다.  \\\n\n\n    <figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2FaRwb57SLYpt27clACavA%2Fimage.png?alt=media&#x26;token=3a66175d-f6f3-4845-82c1-23484c8a4869" alt=""><figcaption></figcaption></figure>\n* **구매 확인하기 (acknowledge)**\n  * 소비성 상품이 아닌 경우, PurchaseClient.acknowledgeAsync() 를 사용합니다. 소비 처리를 하지않고, 구매 인증만 하는 방법으로 영구성 상품을 구현할 수 있습니다.&#x20;\n  * 영구성 형태의 상품을 구현할 때는, 소비가 아닌 구매 확인 (acknowledge)을 해야 합니다.&#x20;\n  *   구독 상품의 경우에도 구매 확인이 필요하며, 최초 결제에 대해서만 구매 확인을 진행하면 됩니다.  \\\n\n\n      <figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2FtpneRxlaTI4QskC895DK%2Fimage.png?alt=media&#x26;token=366d6ae4-828f-465e-b48d-50d887508798" alt=""><figcaption></figcaption></figure>\n\n네트워크 단절이나 앱의 갑작스러운 비정상 종료 등으로 인해, 고객은 결제를 완료하였으나 개발사에 결제정보 전달이 누락되어 인앱 상품이 지급되지 않는 경우가 발생할 수 있습니다.\\\n구매정보 가져오기(queryPurchases) 및 소비(consume) 기능을 활용하여 구매가 완료 되었으나 미지급된 내역이 있는지 확인 후 미지급된 상품이 지급 처리될 수 있도록 프로세스를 구현하는 것을 권장합니다.&#x20;', tiles=[Tile(id='ad16ef78-bc9d-4304-b45c-57a7b039ff3f', type='definition', text='### **구매 확인하기**  <a href="#id-01." id="id-01."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b574f145-073c-4f1f-8ce7-2078e54ccfa2', 'section_title': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='47ff8304-c106-4137-8b3d-2eb79a85b87e', type='explanation', text='원스토어 IAP 라이브러리 V6 이상을 사용하는 경우 3일 이내에 구매 확인을 진행해야 합니다. 구매 확인이 되지 않으면, 고객에게 구매 금액이 환불됩니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b574f145-073c-4f1f-8ce7-2078e54ccfa2', 'section_title': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='7421f50c-fe27-4cb0-a82d-c0be94d34ae6', type='explanation', text='다음 두 가지 방법을 사용하면 구매를 확인할 수 있습니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b574f145-073c-4f1f-8ce7-2078e54ccfa2', 'section_title': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='d8323251-ce6f-4e17-b718-2d0bc7556f08', type='explanation', text='*   **소비하기 (consume)**&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b574f145-073c-4f1f-8ce7-2078e54ccfa2', 'section_title': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>', 'heading_path': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>'}), Tile(id='89008832-99c1-4719-bda5-07f72be2d855', type='explanation', text='* 관리형 상품의 특징은 구매 후 소비(consume) 하기 전까지 재구매가 되지 않는 것입니다. 따라서, 관리형 상품 중 반복 구매가 가능한 소비성 상품을 제공할 경우에는 반드시 PurchaseClient.consumeAsync()를 사용하여 소비 처리를 해야 고객이 해당 상품을 다시 구매할 수 있습니다. &#x20;\n    * 소비성 형태의 상품을 구현할 때는 구매 프로세스 완료 후 바로 구매한 상품을 소비시키고, 소비가 완료된 후에 아이템을 지급합니다. &#x20;\n    * 사용자가 앱(게임)을 실행하는 시점 또는 앱(게임)에 로그인하는 시점에 위의 API들을 호출하여, 미지급된 상품이 있는지 사전에 체크하고 상품을 지급하는 프로세스를 추가하는 것을 권장합니다.  \\', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b574f145-073c-4f1f-8ce7-2078e54ccfa2', 'section_title': '**구매 확인하기**  <a href="#id-01." id="id-01."></a>', 'heading_p ...
# SectionPack(id='5a263979-af55-4a90-916c-e29b6d71ddfd', title='구독형 상품 관리 <a href="#id-01." id="id-01."></a>', heading_path='구독형 상품 관리 <a href="#id-01." id="id-01."></a>', text='### 구독형 상품 관리 <a href="#id-01." id="id-01."></a>\n\n구독형 상품(subscription)은 첫 구매 이후 상품 결제 주기에 따라 정기적으로 결제를 갱신합니다.\n\n원스토어는 사용자가 정기 결제 상품을 관리 할 수 있도록 일시 중지, 구독 해지, 결제 수단 변경 등 다양한 기능이 있는 정기 결제 관리 화면을 제공합니다.  &#x20;\n\nlaunchManageSubscription API를 호출하거나 딥링크를 사용하여 정기 결제 관리 메뉴를 제공 할 수 있습니다.&#x20;', tiles=[Tile(id='f5867774-3edc-4915-9b4a-e0e5f26b982f', type='definition', text='### 구독형 상품 관리 <a href="#id-01." id="id-01."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '5a263979-af55-4a90-916c-e29b6d71ddfd', 'section_title': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>', 'heading_path': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>'}), Tile(id='69f65ff6-628b-48b9-a376-fd366a0f2190', type='explanation', text='구독형 상품(subscription)은 첫 구매 이후 상품 결제 주기에 따라 정기적으로 결제를 갱신합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '5a263979-af55-4a90-916c-e29b6d71ddfd', 'section_title': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>', 'heading_path': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>'}), Tile(id='a0b8421e-d2db-49e1-ab49-d027a43920ea', type='explanation', text='원스토어는 사용자가 정기 결제 상품을 관리 할 수 있도록 일시 중지, 구독 해지, 결제 수단 변경 등 다양한 기능이 있는 정기 결제 관리 화면을 제공합니다.  &#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '5a263979-af55-4a90-916c-e29b6d71ddfd', 'section_title': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>', 'heading_path': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>'}), Tile(id='cedf59c2-1596-4001-bd67-ea79a3dde06a', type='explanation', text='launchManageSubscription API를 호출하거나 딥링크를 사용하여 정기 결제 관리 메뉴를 제공 할 수 있습니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '5a263979-af55-4a90-916c-e29b6d71ddfd', 'section_title': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>', 'heading_path': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>', 'heading_path': '구독형 상품 관리 <a href="#id-01." id="id-01."></a>', 'term_keys': ['구독형 상품 관리 a href id 01 id id 01 a'], 'exact_keys': []})
# SectionPack(id='f787dc96-c18f-4666-a087-0528f90da143', title='**권장 개발 환경** <a href="#id-01." id="id-01."></a>', heading_path='**권장 개발 환경** <a href="#id-01." id="id-01."></a>', text='## **권장 개발 환경** <a href="#id-01." id="id-01."></a>\n\n원스토어 IAP SDK를 적용하기 위해 다음과 같은 개발 환경이 필요합니다.\n\n* Android 6.0 이상 버전(API 버전 23 이상)\n* [Java SDK 11 버전](http://www.oracle.com/technetwork/java/javase/downloads/index.html)\n* [Android studio 2.0 이상 버전](https://developer.android.com/studio/index.html)\n\n\n\n출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/pre.md\n# 02. 사전준비', tiles=[Tile(id='b3c26e79-16d5-4916-b0f4-4d6dd75d964e', type='definition', text='## **권장 개발 환경** <a href="#id-01." id="id-01."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f787dc96-c18f-4666-a087-0528f90da143', 'section_title': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>', 'heading_path': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>'}), Tile(id='cdd9012a-9104-4db5-b3c9-7c9fe6eba4c8', type='explanation', text='원스토어 IAP SDK를 적용하기 위해 다음과 같은 개발 환경이 필요합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f787dc96-c18f-4666-a087-0528f90da143', 'section_title': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>', 'heading_path': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>'}), Tile(id='9e539bb4-d6e8-46ea-9170-751a3fc28021', type='explanation', text='* Android 6.0 이상 버전(API 버전 23 이상)\n* [Java SDK 11 버전](http://www.oracle.com/technetwork/java/javase/downloads/index.html)\n* [Android studio 2.0 이상 버전](https://developer.android.com/studio/index.html)', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f787dc96-c18f-4666-a087-0528f90da143', 'section_title': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>', 'heading_path': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>'}), Tile(id='c934132f-3bcf-4b6c-89b3-6b30c0ef7a14', type='explanation', text='출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/pre.md\n# 02. 사전준비', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f787dc96-c18f-4666-a087-0528f90da143', 'section_title': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>', 'heading_path': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>', 'heading_path': '**권장 개발 환경** <a href="#id-01." id="id-01."></a>', 'term_keys': ['권장 개발 환경 a href id 01 id id 01 a', '권장 개발 환경'], 'exact_keys': ['IAP', 'API', 'SDK']})
# SectionPack(id='3724d13e-f549-44b4-b479-c242d445ada6', title='**상품 등록하기**  <a href="#id-02." id="id-02."></a>', heading_path='**상품 등록하기**  <a href="#id-02." id="id-02."></a>', text='## **상품 등록하기**  <a href="#id-02." id="id-02."></a>\n\n* 상품 등록과 관련된 내용은 아래 가이드를 참고 부탁 드립니다.&#x20;\n  * [상품 등록과 관리](../../../docs/apps)&#x20;', tiles=[Tile(id='c3c62399-c4ef-404b-aa27-3d10797b9271', type='definition', text='## **상품 등록하기**  <a href="#id-02." id="id-02."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '3724d13e-f549-44b4-b479-c242d445ada6', 'section_title': '**상품 등록하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**상품 등록하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='735e91cf-45d5-40bc-b544-785c0e7aeb42', type='explanation', text='* 상품 등록과 관련된 내용은 아래 가이드를 참고 부탁 드립니다.&#x20;\n  * [상품 등록과 관리](../../../docs/apps)&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '3724d13e-f549-44b4-b479-c242d445ada6', 'section_title': '**상품 등록하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**상품 등록하기**  <a href="#id-02." id="id-02."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**상품 등록하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**상품 등록하기**  <a href="#id-02." id="id-02."></a>', 'term_keys': ['상품 등록하기 a href id 02 id id 02 a', '상품 등록하기'], 'exact_keys': []})
# SectionPack(id='4916dfe2-abb9-43da-a31f-431178d777d2', title='**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>', heading_path='**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>', text='## **라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>\n\n공통정보 >  라이선스 관리 메뉴에서 라이선스 키와 서버 API를 위한 OAuth 인증 정보를 확인할 수 있습니다.&#x20;\n\n* 라이선스 키 : 원스토어가 전달한 인앱결제 내역의 위변조 여부를 확인하는 용도로 사용합니다.\n* OAuth 인증 정보 : 원스토어 서버 API를 사용하기 위한 인증 용도로 사용합니다.', tiles=[Tile(id='c1560fb7-b270-4576-ba94-1b9c95df4332', type='definition', text='## **라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '4916dfe2-abb9-43da-a31f-431178d777d2', 'section_title': '**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>', 'heading_path': '**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>'}), Tile(id='d5f605bd-fc7e-4cdb-b23c-deb2af94c743', type='explanation', text='공통정보 >  라이선스 관리 메뉴에서 라이선스 키와 서버 API를 위한 OAuth 인증 정보를 확인할 수 있습니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '4916dfe2-abb9-43da-a31f-431178d777d2', 'section_title': '**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>', 'heading_path': '**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>'}), Tile(id='df30d1e7-35dc-42a3-b4ee-76430461ee2d', type='explanation', text='* 라이선스 키 : 원스토어가 전달한 인앱결제 내역의 위변조 여부를 확인하는 용도로 사용합니다.\n* OAuth 인증 정보 : 원스토어 서버 API를 사용하기 위한 인증 용도로 사용합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '4916dfe2-abb9-43da-a31f-431178d777d2', 'section_title': '**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>', 'heading_path': '**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>', 'heading_path': '**라이선스 키(Public Key) 및 OAuth 인증 정보 확인하기**  <a href="#id-02.-publickey-oauth" id="id-02.-publickey-oauth"></a>', 'term_keys': ['라이선스 키 public key 및 o auth 인증 정보 확인하기 a href id 02 publickey oauth id id 02 publickey oauth a', '라이선스 키 public key 및 o auth 인증 정보 확인하기'], 'exact_keys': []})
# SectionPack(id='3ed6d9f5-4740-4457-a29f-a8d3f4fedc72', title='**원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>', heading_path='**원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>', text='## **원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>\n\n원스토어 인앱결제를 사용하기 위해 필요한 샘플 앱을 [깃허브(github](https://github.com/ONE-store/onestore_iap_release))에서 다운로드 받을 수 있습니다.&#x20;', tiles=[Tile(id='8329b0fd-859b-46e1-bcbb-e953d070bec7', type='definition', text='## **원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '3ed6d9f5-4740-4457-a29f-a8d3f4fedc72', 'section_title': '**원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>', 'heading_path': '**원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>'}), Tile(id='660f9dae-2c2e-41b4-805d-2828a26a65cb', type='explanation', text='원스토어 인앱결제를 사용하기 위해 필요한 샘플 앱을 [깃허브(github](https://github.com/ONE-store/onestore_iap_release))에서 다운로드 받을 수 있습니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '3ed6d9f5-4740-4457-a29f-a8d3f4fedc72', 'section_title': '**원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>', 'heading_path': '**원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>', 'heading_path': '**원스토어 인앱결제 Sample App 다운로드** <a href="#id-02.-sampleapp" id="id-02.-sampleapp"></a>', 'term_keys': ['원스토어 인앱결제 sample app 다운로드 a href id 02 sampleapp id id 02 sampleapp a', '원스토어 인앱결제 sample app 다운로드'], 'exact_keys': ['ONE']})
# SectionPack(id='7550d63f-8c4f-4615-8df2-4d664c58be0c', title='**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', heading_path='**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', text='## **인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>\n\n프로젝트 최상위 _build.gradle_ 파일에 원스토어 maven 주소를 등록합니다.\n\n\n[코드블록: 전체 포함]\n\n\n다음은 앱의 _build.gradle_ 파일에 원스토어 결제 라이브러리 종속 항목을 추가합니다.\n\n\n[코드블록: 전체 포함]', tiles=[Tile(id='87ce7bcd-8310-4b51-b671-f25da2743be8', type='definition', text='## **인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '7550d63f-8c4f-4615-8df2-4d664c58be0c', 'section_title': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='45943862-24ce-4c38-ae10-b5d190636bd0', type='explanation', text='프로젝트 최상위 _build.gradle_ 파일에 원스토어 maven 주소를 등록합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '7550d63f-8c4f-4615-8df2-4d664c58be0c', 'section_title': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='b00d988c-f37b-4eee-9f8e-8fe8652e44c4', type='explanation', text='[CODE_BLOCK::89d8667f-d1c8-4d75-b99d-90079da7bcd0]', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '7550d63f-8c4f-4615-8df2-4d664c58be0c', 'section_title': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='de49d3bc-ebb1-4883-87cb-855e08368397', type='explanation', text='다음은 앱의 _build.gradle_ 파일에 원스토어 결제 라이브러리 종속 항목을 추가합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '7550d63f-8c4f-4615-8df2-4d664c58be0c', 'section_title': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='312bd2a7-579a-46b8-912f-d3205dacec0f', type='explanation', text='[CODE_BLOCK::382085d9-3049-43f4-95ad-991e8040be02]', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '7550d63f-8c4f-4615-8df2-4d664c58be0c', 'section_title': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='89d8667f-d1c8-4d75-b99d-90079da7bcd0', type='code', text="allprojects {\n    repositories {\n        ...\n \xa0    \xa0 maven { url 'https://repo.onestore.net/repository/onestore-sdk-public' }\n    }\n}", metadata={'code_lang': 'gradle', 'doc_id': 'iap_dev_integration_guide', 'section_id': '7550d63f-8c4f-4615-8df2-4d664c58be0c', 'section_title': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'exact_keys': []}), Tile(id='382085d9-3049-43f4-95ad-991e8040be02', type='code', text='dependencies {\n    implementation "com.onestorecorp.sdk:sdk-iap:21.02.01"\n}', metadata={'code_lang': 'gradle', 'doc_id': 'iap_dev_integration_guide', 'section_id': '7550d63f-8c4f-4615-8df2-4d664c58be0c', 'section_title': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'exact_keys': []})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**인앱결제 라이브러리 추가하기**  <a href="#id-02." id="id-02."></a>', 'term_keys': ['인앱결제 라이브러리 추가하기 a href id 02 id id 02 a', '인앱결제 라이브러리 추가하기'], 'exact_keys': []})
# SectionPack(id='c06eacc3-74ab-426b-afa2-b1ebed828554', title='**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', heading_path='**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', text='## **원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>\n\n개발자나 사용자가 원스토어 인앱결제를 이용하기 위해서는 원스토어 앱이 필요합니다.\n\n* [원스토어 앱 다운로드 안내](../../../policy/download)\n\n\n\n출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/test.md\n# 03. 결제 테스트 및 보안', tiles=[Tile(id='d562640c-959c-4e29-b4b6-b272f90b6ddf', type='definition', text='## **원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'c06eacc3-74ab-426b-afa2-b1ebed828554', 'section_title': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='5d217060-e18e-49c3-8f5c-90acce95231a', type='explanation', text='개발자나 사용자가 원스토어 인앱결제를 이용하기 위해서는 원스토어 앱이 필요합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'c06eacc3-74ab-426b-afa2-b1ebed828554', 'section_title': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='9eb6e745-b690-4dcc-b6d8-293ae2a7caf9', type='explanation', text='* [원스토어 앱 다운로드 안내](../../../policy/download)', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'c06eacc3-74ab-426b-afa2-b1ebed828554', 'section_title': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>'}), Tile(id='d2936ae2-a8dc-477d-9db1-20e89fa11c45', type='explanation', text='출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/test.md\n# 03. 결제 테스트 및 보안', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'c06eacc3-74ab-426b-afa2-b1ebed828554', 'section_title': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', 'heading_path': '**원스토어 앱 설치하기**  <a href="#id-02." id="id-02."></a>', 'term_keys': ['원스토어 앱 설치하기 a href id 02 id id 02 a', '원스토어 앱 설치하기'], 'exact_keys': []})
# SectionPack(id='b9e6bf76-4b96-4106-b236-cc8eee7425ef', title='**개요** <a href="#id-03." id="id-03."></a>', heading_path='**개요** <a href="#id-03." id="id-03."></a>', text='## **개요** <a href="#id-03." id="id-03."></a>\n\n원스토어는 개발환경(이하 Sandbox) 또는 상용 결제환경(이하 상용테스트)에서 인앱상품의 결제 테스트를 지원합니다.\n\nSandbox는 상용 결제환경이 아닌 가상의 결제환경으로, 결제화면에서 결제실패 또는 성공 중 원하는 응답을 선택하면 해당 응답결과를 전송합니다.\n\n상용테스트는 상용 결제환경에서 해당 인앱상품의 결제를 진행하여 결제 결과를 전송합니다.\n\n상용테스트 환경에서 결제를 하실 경우 취소하지 않으면 과금이 발생할 수 있으니, 결제 테스트 후 반드시 결제취소를 진행해주셔야 합니다.\n\n{% hint style="warning" %}\n주의사항\n\n* 상품을 배포하고자 하는 OS에서 반드시 한 번은 샌드박스 테스트를 진행해야 합니다.\n* OGL AAB/APK의 경우 안드로이드 환경에서 샌드박스 테스트를 진행하면 됩니다.&#x20;\n*   Sandbox 및 상용환경에서 테스트하기 위해서는 사전에 원스토어 ID를 테스트 ID로 등록해야 합니다.\n\n    등록하지 않은 원스토어 ID로 테스트할 경우 Sandbox에서 테스트가 불가능하고, 상용테스트 환경에서는 테스트 상용결제가 아닌 실제 상용결제가 진행되어 과금이 되므로 주의해주시기 바랍니다.\n* 원스토어는 테스트 ID를 통해 결제한 내역에 대해 책임지지 않습니다. 테스트 ID의 관리 및 결제 테스트는 개발사 내부 책임자의 관리감독 하에 진행하시기 바랍니다.\n{% endhint %}', tiles=[Tile(id='27f63d7d-85fc-4df1-8d5e-40571164f4e5', type='definition', text='## **개요** <a href="#id-03." id="id-03."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b9e6bf76-4b96-4106-b236-cc8eee7425ef', 'section_title': '**개요** <a href="#id-03." id="id-03."></a>', 'heading_path': '**개요** <a href="#id-03." id="id-03."></a>'}), Tile(id='4613c3da-a1bd-4e24-a638-014a49512123', type='explanation', text='원스토어는 개발환경(이하 Sandbox) 또는 상용 결제환경(이하 상용테스트)에서 인앱상품의 결제 테스트를 지원합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b9e6bf76-4b96-4106-b236-cc8eee7425ef', 'section_title': '**개요** <a href="#id-03." id="id-03."></a>', 'heading_path': '**개요** <a href="#id-03." id="id-03."></a>'}), Tile(id='ac315b4c-48e4-4520-9087-c54dbc74b96f', type='explanation', text='Sandbox는 상용 결제환경이 아닌 가상의 결제환경으로, 결제화면에서 결제실패 또는 성공 중 원하는 응답을 선택하면 해당 응답결과를 전송합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b9e6bf76-4b96-4106-b236-cc8eee7425ef', 'section_title': '**개요** <a href="#id-03." id="id-03."></a>', 'heading_path': '**개요** <a href="#id-03." id="id-03."></a>'}), Tile(id='51c83329-71e5-4f81-a8c5-132554158749', type='explanation', text='상용테스트는 상용 결제환경에서 해당 인앱상품의 결제를 진행하여 결제 결과를 전송합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b9e6bf76-4b96-4106-b236-cc8eee7425ef', 'section_title': '**개요** <a href="#id-03." id="id-03."></a>', 'heading_path': '**개요** <a href="#id-03." id="id-03."></a>'}), Tile(id='1ea56014-7614-4cec-8c56-ed78e27feec7', type='explanation', text='상용테스트 환경에서 결제를 하실 경우 취소하지 않으면 과금이 발생할 수 있으니, 결제 테스트 후 반드시 결제취소를 진행해주셔야 합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b9e6bf76-4b96-4106-b236-cc8eee7425ef', 'section_title': '**개요** <a href="#id-03." id="id-03."></a>', 'heading_path': '**개요** <a href="#id-03." id="id-03."></a>'}), Tile(id='e0d577ea-1100-4c6e-b539-1a0b64f2bd6c', type='explanation', text='{% hint style="warning" %}\n주의사항', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b9e6bf76-4b96-4106-b236-cc8eee7425ef', 'section_title': '**개요** <a href="#id-03." id="id-03."></a>', 'heading_path': '**개요** <a href="#id-03." id="id-03."></a>'}), Tile(id='7848f5f1-c107-4349-9ed4-3719e527cfd3', type='explanation', text='* 상품을 배포하고자 하는 OS에서 반드시 한 번은 샌드박스 테스트를 진행해야 합니다.\n* OGL AAB/APK의 경우 안드로이드 환경에서 샌드박스 테스트를 진행하면 됩니다.&#x20;\n*   Sandbox 및 상용환경에서 테스트하기 위해서는 사전에 원스토어 ID를 테스트 ID로 등록해야 합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b9e6bf76-4b96-4106-b236-cc8eee7425ef', 'section_title': '**개요** <a href="#id-03." id="id-03."></a>', 'heading_path': '**개요** <a href="#id-03." id="id-03."></a>'}), Tile(id='f4d4b052-3c1e-44e3-9ad2-b4b817e896a4', type='explanation', text='등록하지 않은 원스토어 ID로 테스트할 경우 Sandbox에서 테스트가 불가능하고, 상용테스트 환경에서는 테스트 상용결제가 아닌 실제 상용결제가 진행되어 과금이 되므로 주의해주시기 바랍니다.\n* 원스토어는 테스트 ID를 통해 결제한 내역에 대해 책임지지 않습니다. 테스트 ID의 관리 및 결제 테스트는 개발사 내부 책임자의 관리감독 하에 진행하시기 바랍니다.\n{% endhint %}', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'b9e6bf76-4b96-4106-b236-cc8eee7425ef', 'section_title ...
# SectionPack(id='3a8a6cbc-2c47-4d0c-8f3c-232ac7c0665c', title='**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>', heading_path='**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>', text='## **인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>\n\nIn-App정보 화면에서 \'결제 테스트\' 버튼을 누르면 인앱결제 테스트 화면이 제공됩니다.\n\n인앱결제 테스트 화면에서 테스트 ID를 관리하거나, 결제 테스트 내역을 조회할 수 있습니다.', tiles=[Tile(id='8fd0e7e7-531a-4249-ad6a-c55d6eb472c0', type='definition', text='## **인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '3a8a6cbc-2c47-4d0c-8f3c-232ac7c0665c', 'section_title': '**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>', 'heading_path': '**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>'}), Tile(id='f2895166-f35a-4b7b-8b3d-490ba418860d', type='explanation', text="In-App정보 화면에서 '결제 테스트' 버튼을 누르면 인앱결제 테스트 화면이 제공됩니다.", metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '3a8a6cbc-2c47-4d0c-8f3c-232ac7c0665c', 'section_title': '**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>', 'heading_path': '**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>'}), Tile(id='ac34b278-3f8b-420d-b049-49c91c76e9e9', type='explanation', text='인앱결제 테스트 화면에서 테스트 ID를 관리하거나, 결제 테스트 내역을 조회할 수 있습니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '3a8a6cbc-2c47-4d0c-8f3c-232ac7c0665c', 'section_title': '**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>', 'heading_path': '**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>', 'heading_path': '**인앱결제 테스트 화면** <a href="#id-03." id="id-03."></a>', 'term_keys': ['인앱결제 테스트 화면 a href id 03 id id 03 a', '인앱결제 테스트 화면'], 'exact_keys': []})
# SectionPack(id='4ed30b1b-8c4a-4273-9caf-750d1763743f', title='**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', heading_path='**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', text='## **테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>\n\n개발 및 상용환경에서 인앱결제를 테스트하기 위해서는 사전에 테스트 ID를 등록해야 합니다.\n\n인앱결제 테스트 화면에서 \'테스트 ID 등록/관리\' 탭을 선택하시면, 테스트 ID를 관리하는 화면으로 이동합니다.\n\n테스트 ID는 원스토어 사용자 ID로, 원스토어에 회원으로 등록되어 있는 ID를 조회하여 등록할 수 있습니다.&#x20;\n\n만약, 원스토어 회원으로 등록되어 있지 않다면 원스토어 앱을 실행하여 테스트용 원스토어 ID를 만드신 후 해당 ID를 테스트 ID로 등록하면 됩니다. &#x20;', tiles=[Tile(id='402c88da-5dfd-413c-aed6-01bafa51aa32', type='definition', text='## **테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '4ed30b1b-8c4a-4273-9caf-750d1763743f', 'section_title': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>'}), Tile(id='46dbef89-cf4a-489d-b593-62e8c9d79fba', type='explanation', text='개발 및 상용환경에서 인앱결제를 테스트하기 위해서는 사전에 테스트 ID를 등록해야 합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '4ed30b1b-8c4a-4273-9caf-750d1763743f', 'section_title': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>'}), Tile(id='f844ed27-449d-4820-9309-5b54e3b61c2f', type='explanation', text="인앱결제 테스트 화면에서 '테스트 ID 등록/관리' 탭을 선택하시면, 테스트 ID를 관리하는 화면으로 이동합니다.", metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '4ed30b1b-8c4a-4273-9caf-750d1763743f', 'section_title': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>'}), Tile(id='4818ef6a-fcef-496e-ae5d-063053977cbc', type='explanation', text='테스트 ID는 원스토어 사용자 ID로, 원스토어에 회원으로 등록되어 있는 ID를 조회하여 등록할 수 있습니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '4ed30b1b-8c4a-4273-9caf-750d1763743f', 'section_title': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>'}), Tile(id='5676d5bd-a18e-414e-b721-692976ab5b31', type='explanation', text='만약, 원스토어 회원으로 등록되어 있지 않다면 원스토어 앱을 실행하여 테스트용 원스토어 ID를 만드신 후 해당 ID를 테스트 ID로 등록하면 됩니다. &#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '4ed30b1b-8c4a-4273-9caf-750d1763743f', 'section_title': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록/관리** <a href="#id-03.-id" id="id-03.-id"></a>', 'term_keys': ['테스트 i d 등록 관리 a href id 03 id id id 03 id a', '테스트 i d 등록 관리'], 'exact_keys': []})
# SectionPack(id='f87b7eed-0add-4e30-8914-fb2daa35b588', title='**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>', heading_path='**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>', text='### **테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>\n\n* 테스트 ID로 사용 할 원스토어 회원 ID를 조회합니다.\n* 조회한 원스토어 ID 확인 후, 해당 테스트 ID로 어느 결제환경(Sandbox, 상용테스트)에서 결제 테스트를 진행할지 선택합니다.\n*   필요한 경우 참고 사항을 입력하고 등록 버튼을 눌러 테스트 ID를 등록 합니다.\n\n    하나의 테스트 ID는 하나의 결제환경만 선택가능하며, 결제환경 설정은 언제든 변경할 수 있습니다.\n* 등록되어 있는 테스트 ID로 어느 환경에서 결제 테스트 할지 설정할 수 있습니다.&#x20;\n* 테스트 ID 결제환경을 변경할 경우 반드시 \'저장\' 버튼을 눌러 새로운 설정을 저장해야 합니다.', tiles=[Tile(id='7cd45ea6-2333-4dd7-8cc4-685425079cfa', type='definition', text='### **테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f87b7eed-0add-4e30-8914-fb2daa35b588', 'section_title': '**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>'}), Tile(id='17525983-55f7-48fb-8ab1-a86a7c8c9540', type='explanation', text='* 테스트 ID로 사용 할 원스토어 회원 ID를 조회합니다.\n* 조회한 원스토어 ID 확인 후, 해당 테스트 ID로 어느 결제환경(Sandbox, 상용테스트)에서 결제 테스트를 진행할지 선택합니다.\n*   필요한 경우 참고 사항을 입력하고 등록 버튼을 눌러 테스트 ID를 등록 합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f87b7eed-0add-4e30-8914-fb2daa35b588', 'section_title': '**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>'}), Tile(id='ea5656c3-49d8-4ac3-b3c5-6ed2538148d0', type='explanation', text="하나의 테스트 ID는 하나의 결제환경만 선택가능하며, 결제환경 설정은 언제든 변경할 수 있습니다.\n* 등록되어 있는 테스트 ID로 어느 환경에서 결제 테스트 할지 설정할 수 있습니다.&#x20;\n* 테스트 ID 결제환경을 변경할 경우 반드시 '저장' 버튼을 눌러 새로운 설정을 저장해야 합니다.", metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': 'f87b7eed-0add-4e30-8914-fb2daa35b588', 'section_title': '**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>', 'heading_path': '**테스트 ID 등록하기**   <a href="#id-03.-id" id="id-03.-id"></a>', 'term_keys': ['테스트 i d 등록하기 a href id 03 id id id 03 id a', '테스트 i d 등록하기'], 'exact_keys': []})
# SectionPack(id='40964d30-a318-4987-aa28-0df1126477a2', title='**테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**', heading_path='**테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**', text="### **테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**\n\n* 테스트 ID가 더 이상 유효하지 않을 경우 테스트 ID를 삭제할 수 있습니다.&#x20;\n* '삭제'하기 버튼을 눌러 개별 테스트 ID를 삭제하거나, 여러 테스트 ID를 체크한 후 '체크한 ID 삭제' 버튼을 눌러 일괄 삭제할 수 있습니다.", tiles=[Tile(id='f95bd89f-d412-41c7-b160-e025f359b8ce', type='definition', text='### **테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '40964d30-a318-4987-aa28-0df1126477a2', 'section_title': '**테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**', 'heading_path': '**테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**'}), Tile(id='c539882a-9930-434b-a23e-d775ed889c06', type='explanation', text="* 테스트 ID가 더 이상 유효하지 않을 경우 테스트 ID를 삭제할 수 있습니다.&#x20;\n* '삭제'하기 버튼을 눌러 개별 테스트 ID를 삭제하거나, 여러 테스트 ID를 체크한 후 '체크한 ID 삭제' 버튼을 눌러 일괄 삭제할 수 있습니다.", metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '40964d30-a318-4987-aa28-0df1126477a2', 'section_title': '**테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**', 'heading_path': '**테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '**테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**', 'heading_path': '**테스트 ID 삭제하기 (개별 삭제, 일괄 삭제)**', 'term_keys': ['테스트 i d 삭제하기 개별 삭제 일괄 삭제'], 'exact_keys': []})
# ...
# SectionPack(id='5ad4eee3-76f3-470a-aaed-d606125dc5cd', title='getSubscriptionDetail <a href="#id-2.-apiv7-4.11getsubscriptiondetail" id="id-2.-apiv7-4.11getsubscriptiondetail"></a>', heading_path='getSubscriptionDetail <a href="#id-2.-apiv7-4.11getsubscriptiondetail" id="id-2.-apiv7-4.11getsubscriptiondetail"></a>', text='### getSubscriptionDetail <a href="#id-2.-apiv7-4.11getsubscriptiondetail" id="id-2.-apiv7-4.11getsubscriptiondetail"></a>\n\n#### **\\[ API Spec. ]**\n\n\n[표: 전체 포함]\n<table data-header-hidden><thead><tr><th width="128.640625"></th><th></th></tr></thead><tbody><tr><td><strong>Path</strong></td><td><p>(상용) <br><a href="https://pcapis.onestore.net/pc/v7/apps/%7BclientId%7D/purchases/subscription/%7BpurchaseToken%7D">https://pcapis.onestore.net/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}</a><br></p><p>(개발) <br><a href="https://sbpp.onestore.net/pc/v7/apps/%7BclientId%7D/purchases/subscription/%7BpurchaseToken%7D">https://sbpp.onestore.net/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}</a></p></td></tr><tr><td><strong>Description</strong></td><td><ul><li>구독의 상세정보를 조회한다.</li><li>오류 코드 : 표준 응답코드 참조</li></ul></td></tr></tbody></table>\n\n#### **\\[ Request ]**\n\n**Path Parameter**\n\n\n[표: 전체 포함]\n**Header**\n\n\n[표: 전체 포함]\n**Body**\n\n**Example**\n\n\n[코드블록: 전체 포함]\n\n\n#### **\\[ Response ]**\n\n<table><thead><tr><th width="149">Element Name</th><th></th><th></th><th>Data Type</th><th>Description</th></tr></thead><tbody><tr><td>result {</td><td></td><td></td><td>Object</td><td>API호출 결과(정상) - 정상 시에 응답</td></tr><tr><td></td><td>code</td><td></td><td>String</td><td>응답코드</td></tr><tr><td></td><td>message</td><td></td><td>String</td><td>응답메시지</td></tr><tr><td>}</td><td><br></td><td><br></td><td></td><td></td></tr><tr><td>error {</td><td></td><td></td><td>Object</td><td>API호출 결과(에러) - 에러 시에 응답</td></tr><tr><td></td><td>code</td><td></td><td>String</td><td>응답코드</td></tr><tr><td></td><td>message</td><td></td><td>String</td><td>응답메시지</td></tr><tr><td>}</td><td><br></td><td><br></td><td></td><td></td></tr><tr><td>subscription {</td><td></td><td><br></td><td>Object</td><td></td></tr><tr><td><br></td><td>productId</td><td></td><td>String</td><td>커스텀 상품 ID</td></tr><tr><td><br></td><td>productName</td><td></td><td>String</td><td>상품명</td></tr><tr><td><br></td><td>parentProductId</td><td></td><td>String</td><td>모상품 ID</td></tr><tr><td><br></td><td>parentProductName</td><td></td><td>String</td><td>모상품명</td></tr><tr><td><br></td><td>packageName</td><td></td><td>String</td><td>패키지명</td></tr><tr><td><br></td><td>productAmount</td><td></td><td>String</td><td>상품 금액</td></tr><tr><td><br></td><td>productAmountMicros</td><td></td><td>Long</td><td>상품 금액 * 100만</td></tr><tr><td><br></td><td>priceCurrencyCode<br></td><td></td><td>String</td><td>KRW, USD 등등의 통화 구분</td></tr><tr><td><br></td><td>imagePath</td><td></td><td>String</td><td>상품 이미지 경로</td></tr><tr><td><br></td><td>periodUnit</td><td></td><td>String</td><td>이용 기간 단위</td></tr><tr><td><br></td><td>period</td><td></td><td>Integer</td><td>이용 기간</td></tr><tr><td><br></td><td>purchaseToken</td><td></td><td>String</td><td>구매 토큰</td></tr><tr><td><br></td><td>status</td><td></td><td>String</td><td>구독 상태 코드</td></tr><tr><td><br></td><td>startDate</td><td></td><td>Long</td><td>구독 시작(첫 결제) 일시(millis)</td></tr><tr><td><br></td><td>expiryDate</td><td></td><td>Long</td><td>구독 만료 일시(millis)</td></tr><tr><td><br></td><td>paymentAmount</td><td></td><td>String</td><td>이전 결제 금액</td></tr><tr><td><br></td><td>paymentAmountMicros</td><td></td><td>Long</td><td>이전 결제 금액 * 100만</td></tr><tr><td><br></td><td>nextPaymentAmount</td><td></td><td>String</td><td>다음 결제 금액 </td></tr><tr><td><br></td><td>nextPaymentAmountMicros</td><td></td><td>Long</td><td>다음 결제 금액 * 100만</td></tr><tr><td><br></td><td>nextPaymentDate</td><td></td><td>Long</td><td>다음 결제 일시(millis)</td></tr><tr><td><br></td><td>pauseAllow</td><td></td><td>String</td><td>일시중지 사용 가능 여부(Y/N(default))</td></tr><tr><td><br ...
# SectionPack(id='5f23f63a-515b-4923-946c-86bbdeec655a', title='결제', heading_path='결제', text='## 결제', tiles=[Tile(id='8226c413-5dcf-40f5-b3cb-a943373aea7b', type='definition', text='## 결제', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '5f23f63a-515b-4923-946c-86bbdeec655a', 'section_title': '결제', 'heading_path': '결제'})], metadata={'doc_id': 'iap_dev_integration_guide', 'section_title': '결제', 'heading_path': '결제', 'term_keys': ['결제'], 'exact_keys': []})
# SectionPack(id='015bf64b-3318-4a3e-92e0-a0e9342a848b', title='결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', heading_path='결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', text='### 결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>\n\n원스토어 인 결제를 요청합니다. paymentUrl로 paymentParam을 전달합니다.&#x20;\n\n성공 시, ONE store 표준 결제화면이 노출됩니다.\n\n#### **\\[ 호출 Spec. ]**\n\n\n[표: 전체 포함]\n<table data-header-hidden><thead><tr><th width="125.93359375"></th><th></th></tr></thead><tbody><tr><td>URL Path</td><td>paymentUrl</td></tr><tr><td>Description</td><td>웹 표준 결제화면 호출</td></tr></tbody></table>\n\n**Parameter**\n\n\n[표: 전체 포함]\n#### **결제 요청 시 브라우저 크기**\n\n원스토어 표준 결제화면에 최적화된 브라우저 크기는 width=400, height=580 입니다.&#x20;\n\n브라우저 크기가 다른 경우 결제화면이 정상적으로 노출되지 않거나 동작하지 않을 수 있습니다. &#x20;\n\n아래는 새 브라우저 창으로 원스토어 결제화면을 호출할 때의 예입니다.&#x20;\n\n{% code overflow="wrap" %}\n\n[코드블록: 전체 포함]\n\n{% endcode %}', tiles=[Tile(id='458fd4b2-805f-463d-9fff-b11ae4be9466', type='definition', text='### 결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '015bf64b-3318-4a3e-92e0-a0e9342a848b', 'section_title': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', 'heading_path': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>'}), Tile(id='691a4a4f-450f-47a9-88e7-21580f08cbd9', type='explanation', text='원스토어 인 결제를 요청합니다. paymentUrl로 paymentParam을 전달합니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '015bf64b-3318-4a3e-92e0-a0e9342a848b', 'section_title': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', 'heading_path': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>'}), Tile(id='3548cbf2-0c7d-4ed5-b544-da9e7cc9b9d3', type='explanation', text='성공 시, ONE store 표준 결제화면이 노출됩니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '015bf64b-3318-4a3e-92e0-a0e9342a848b', 'section_title': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', 'heading_path': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>'}), Tile(id='08d24327-b631-4023-a523-4befedb7b3d4', type='explanation', text='#### **\\[ 호출 Spec. ]**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '015bf64b-3318-4a3e-92e0-a0e9342a848b', 'section_title': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', 'heading_path': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>'}), Tile(id='434e160b-3fe4-42d6-ad21-abad941c5fd1', type='explanation', text='[TABLE_BLOCK::762d0fea-be0f-4d3a-b103-b85ed4e87e6b]\n<table data-header-hidden><thead><tr><th width="125.93359375"></th><th></th></tr></thead><tbody><tr><td>URL Path</td><td>paymentUrl</td></tr><tr><td>Description</td><td>웹 표준 결제화면 호출</td></tr></tbody></table>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '015bf64b-3318-4a3e-92e0-a0e9342a848b', 'section_title': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', 'heading_path': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>'}), Tile(id='f2723043-15b3-4940-bddb-d5a874066a92', type='explanation', text='**Parameter**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '015bf64b-3318-4a3e-92e0-a0e9342a848b', 'section_title': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', 'heading_path': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>'}), Tile(id='75a0916a-ba81-420f-b058-badf211b6218', type='explanation', text='[TABLE_BLOCK::b6ebb8b8-d802-41f6-b921-80a83c4d66ab]\n#### **결제 요청 시 브라우저 크기**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '015bf64b-3318-4a3e-92e0-a0e9342a848b', 'section_title': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>', 'heading_path': '결제 요청 <a href="#id-2.-apiv7-5.1" id="id-2.-apiv7-5.1"></a>'}), Tile(id='1e07b3ff-1044-461e-86d0-7b22f44f933b', type='explanation', text='원스토어 표준 결제화면에 최적화된 브라우저 크기는 width=400, height=580 입니다.&#x20;', metadata={'doc_id': 'iap_dev_integration_guide',  ...
# SectionPack(id='1d4a02c1-a765-47b1-b874-aad614924d0e', title='결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', heading_path='결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', text='### 결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>\n\n표준 결제화면의 결제결과를 개발사로 전달합니다.\n\n#### **\\[ 호출 Spec. ]**\n\n\n[표: 전체 포함]\n<table data-header-hidden><thead><tr><th width="125.15234375"></th><th></th></tr></thead><tbody><tr><td>URL Path</td><td>returnUrl, callbackUrl</td></tr><tr><td>Description</td><td><p>개발사가 제공한 returnUrl(Redirect Page)와 callbackUrl(REST API)을 통해 결제결과를 전달합니다. 두 방식 모두 Parameter Element는 동일하며 returnUrl은 form data submit 형태로, callbackUrl은 json 형태로 전달됩니다.</p><ul><li>단, callbackUrl 데이터는 실제 PG와의 연동 발생시 최종 결제결과에 대해서만 전달됩니다.</li></ul></td></tr></tbody></table>\n\n**Parameter**\n\n\n[표: 전체 포함]\n**Example(returnUrl)**\n\n\n[코드블록: 전체 포함]\n\n\n**Example(callbackUrl)**\n\n\n[코드블록: 전체 포함]\n\n\n#### **응답코드**\n\n\n[표: 전체 포함]\n| PaymentTimeExpired | 결제시간이 초과 되었습니다.(10분) | <p><br></p>                      |', tiles=[Tile(id='184ec0ad-4619-494d-bf97-f65e79c707a8', type='definition', text='### 결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '1d4a02c1-a765-47b1-b874-aad614924d0e', 'section_title': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', 'heading_path': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>'}), Tile(id='949a59f4-915e-41a9-8f8b-7b0a6c790593', type='explanation', text='표준 결제화면의 결제결과를 개발사로 전달합니다.', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '1d4a02c1-a765-47b1-b874-aad614924d0e', 'section_title': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', 'heading_path': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>'}), Tile(id='9392b33c-d404-41a0-b528-780515795728', type='explanation', text='#### **\\[ 호출 Spec. ]**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '1d4a02c1-a765-47b1-b874-aad614924d0e', 'section_title': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', 'heading_path': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>'}), Tile(id='1aad57d9-fe37-4bcb-97f5-4d385e410ac4', type='explanation', text='[TABLE_BLOCK::9850608d-e274-42a6-8fcb-ef1e0f59d685]\n<table data-header-hidden><thead><tr><th width="125.15234375"></th><th></th></tr></thead><tbody><tr><td>URL Path</td><td>returnUrl, callbackUrl</td></tr><tr><td>Description</td><td><p>개발사가 제공한 returnUrl(Redirect Page)와 callbackUrl(REST API)을 통해 결제결과를 전달합니다. 두 방식 모두 Parameter Element는 동일하며 returnUrl은 form data submit 형태로, callbackUrl은 json 형태로 전달됩니다.</p><ul><li>단, callbackUrl 데이터는 실제 PG와의 연동 발생시 최종 결제결과에 대해서만 전달됩니다.</li></ul></td></tr></tbody></table>', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '1d4a02c1-a765-47b1-b874-aad614924d0e', 'section_title': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', 'heading_path': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>'}), Tile(id='fab2442a-2b93-4c47-ad95-72c06e36088a', type='explanation', text='**Parameter**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '1d4a02c1-a765-47b1-b874-aad614924d0e', 'section_title': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', 'heading_path': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>'}), Tile(id='c23164d5-42f7-4fa6-9146-c1035fda6492', type='explanation', text='[TABLE_BLOCK::d418dd2f-7950-4fcb-9ba6-fbdc40f6c89d]\n**Example(returnUrl)**', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '1d4a02c1-a765-47b1-b874-aad614924d0e', 'section_title': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>', 'heading_path': '결제 응답 <a href="#id-2.-apiv7-5.2" id="id-2.-apiv7-5.2"></a>'}), Tile(id='15d4f4c5-2ddd-408c-ae8d-a8049c4fe4aa', type='explanation', text='[CODE_BLOCK::bdba2950-a19e-4c0a-a74d-d2458f08f4b0]', metadata={'doc_id': 'iap_dev_integration_guide', 'section_id': '1d4a02c1-a765-47b1-b874 ...
# 문장 개수: 385

# %%
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores.utils import DistanceStrategy
from langchain_community.retrievers import BM25Retriever
from langchain.schema import Document
from langchain.retrievers import EnsembleRetriever
from langchain.storage import InMemoryStore

def build_retrievers_from_md(md_path: str, doc_id: str):
    md = Path(md_path).read_text(encoding="utf-8")
    packs = split_markdown_to_sections(md, doc_id=doc_id)

    child_docs: List[Document] = []
    for pack in packs:
        for t in pack.tiles:
            meta = dict(t.metadata)
            term_keys = " ".join(pack.metadata.get("term_keys", []))
            exact_keys = " ".join(pack.metadata.get("exact_keys", []))
            if t.type == "code":
                exact_keys += " " + " ".join(t.metadata.get("exact_keys", []))
            meta["term_keys"] = term_keys
            meta["exact_keys"] = exact_keys
            meta["tile_type"] = t.type
            child_docs.append(Document(page_content=t.text, metadata=meta))

    # --- 임베딩: Ollama bge-m3 ---
    emb = OllamaEmbeddings(model="bge-m3:latest")  # GPU/CPU 자동 판단

    child_vectorstore = FAISS.from_documents(
        child_docs, emb, distance_strategy=DistanceStrategy.COSINE
    )

    # --- BM25 (정확일치 강화: term_keys/exact_keys 포함) ---
    bm25_docs = []
    for d in child_docs:
        extra = f"\n{d.metadata.get('term_keys','')}\n{d.metadata.get('exact_keys','')}"
        bm25_docs.append(Document(page_content=d.page_content + extra, metadata=d.metadata))
    bm25 = BM25Retriever.from_documents(bm25_docs); bm25.k = 12

    vector_retriever = child_vectorstore.as_retriever(search_kwargs={"k": 12})
    ensemble = EnsembleRetriever(retrievers=[bm25, vector_retriever], weights=[0.55, 0.45])

    # --- Parent Join 준비 ---
    parent_store = InMemoryStore()
    parent_docs = []
    for p in packs:
        parent_docs.append(Document(
            page_content=p.text,
            metadata=p.metadata | {"section_id": p.id, "section_title": p.title}
        ))
    for d in parent_docs:
        parent_store.mset([(d.metadata["section_id"], d)])

    child_store = InMemoryStore()
    for d in child_docs:
        child_store.mset([(d.metadata["section_id"], d)])
        # child_store.madd([(d.metadata["section_id"], d)])

    return packs, ensemble, parent_store, child_vectorstore

def hybrid_parent_search(query: str, ensemble: EnsembleRetriever, parent_store: InMemoryStore, k: int = 4) -> List[Document]:
    child_hits = ensemble.get_relevant_documents(query)
    bucket_by_section = {}
    for ch in child_hits:
        sid = ch.metadata.get("section_id")
        bucket_by_section.setdefault(sid, []).append(ch)
    ordered_sections = list(bucket_by_section.keys())[:k]
    parent_results = []
    for sid in ordered_sections:
        doc = parent_store.mget([sid])[0]
        parent_results.append(doc)
    return parent_results

# %%
from langchain_community.chat_models import ChatOllama
from langchain.schema import SystemMessage, HumanMessage

def build_llm():
    # 필요 시 num_ctx(컨텍스트 길이)나 num_predict(출력 길이) 조정 가능
    llm = ChatOllama(
        model="exaone3.5:latest",
        temperature=0,
        # num_ctx=8192,   # 모델/로컬 자원에 맞게 조절
        # num_predict=1024
    )
    return llm

def answer(query: str, ensemble: EnsembleRetriever, parent_store: InMemoryStore, llm: ChatOllama, k: int = 4) -> str:
    parents = hybrid_parent_search(query, ensemble, parent_store, k=k)
    context_blocks = []
    for i, p in enumerate(parents, 1):
        context_blocks.append(f"[Section {i}: {p.metadata.get('heading_path')}]\\n{p.page_content}")

    system = SystemMessage(content=(
        "당신은 기술 문서 기반 QA 어시스턴트입니다. "
        "반드시 제공된 컨텍스트만으로 답하고, 불확실하면 명시하세요."
    ))
    user = HumanMessage(content=(
        f"질문: {query}\n\n컨텍스트:\n" + "\n\n".join(context_blocks)
    ))
    res = llm([system, user])
    return res.content

# =============== 실행 예시 ===============
# if __name__ == "__main__":
#     # 샘플 마크다운 파일 경로
#     md_path = "pns_sample.md"   # 제공하신 PNS 예제를 저장한 파일
#     packs, ensemble, parent_store, child_vectorstore = build_retrievers_from_md(md_path, doc_id="pns_doc_v1")
#     llm = build_llm()

#     q1 = "PNS 3.1.0에서 packageName이 clientId로 바뀐 이유와 주의사항을 알려줘"
#     q2 = "paymentMethod의 종류와 설명 전체를 보여줘"
#     q3 = "messageType이 SINGLE_PAYMENT_TRANSACTION일 때 JSON 필드 목록"

#     print("Q1:", answer(q1, ensemble, parent_store, llm))
#     print("Q2:", answer(q2, ensemble, parent_store, llm))
#     print("Q3:", answer(q3, ensemble, parent_store, llm))

# %%
# 샘플 마크다운 파일 경로
md_path = "data/dev_center_guide_allmd_touched.md"   # 제공하신 PNS 예제를 저장한 파일
packs, ensemble, parent_store, child_vectorstore = build_retrievers_from_md(md_path, doc_id="pns_doc_v1")
llm = build_llm()

q1 = "PNS는 무엇입니까?"
q2 = "PNS의 메세지의 purchaseState는 어떤 값들이 있습니까?"
q3 = "Push Notification과 Payment Notification의 차이는 무엇입니까?"

print("Q1", answer(q1, ensemble, parent_store, llm))
print("Q2:", answer(q2, ensemble, parent_store, llm))
print("Q3:", answer(q3, ensemble, parent_store, llm))
# Out:
# Q1 PNS는 **Payment Notification Service**의 약자로, 모바일 네트워크 연결의 불안정성을 보완하기 위해 개발사가 지정한 서버로 원스토어가 사용자의 결제 상태 (결제 완료, 결제 취소 등) 정보를 메시지 형태로 전송하는 기능입니다. 이를 통해 결제 트랜잭션의 상태를 안정적으로 전달하고 관리할 수 있습니다.
# Q2: 제공된 컨텍스트에서 PNS (아마도 원스토어 인앱 결제 시스템을 가리키는 것으로 추정됨)의 `purchaseState`에 대한 구체적인 값 목록은 명시적으로 언급되어 있지 않습니다. 주어진 정보는 주로 인앱 상품의 유형 (관리형 상품, 구독형 상품 등)과 관련된 파라미터 및 메서드에 초점을 맞추고 있습니다.
#
# `purchaseState`에 대한 일반적인 인앱 결제 시스템의 값들은 다음과 같을 수 있지만, 이는 특정 컨텍스트나 문서에 따라 다를 수 있습니다:
#
# - **PENDING**: 구매 요청이 아직 처리 중인 상태
# - **COMPLETED**: 구매가 성공적으로 완료된 상태
# - **REFUNDED**: 환불이 이루어진 상태
# - **FAILED**: 구매 과정에서 오류가 발생하여 실패한 상태
#
# 하지만, 이 값들은 제공된 컨텍스트에서 직접적으로 확인된 것이 아니므로, 정확한 `purchaseState` 값들을 알고 싶으시다면 원스토어 인앱 결제 API 문서나 관련 SDK 문서를 직접 참조하시는 것이 가장 정확할 것입니다. 만약 추가 정보가 필요하시다면, 해당 문서나 공식 지원 채널을 통해 확인하시는 것을 권장드립니다.
# Q3: Push Notification과 Payment Notification의 주요 차이점은 다음과 같습니다:
#
# 1. **목적**:
#    - **Push Notification**: 주로 사용자에게 실시간으로 정보를 전달하는 데 사용됩니다. 이는 앱 내에서 사용자에게 새로운 업데이트, 메시지, 이벤트 알림 등을 즉시 알리는 데 초점을 맞춥니다. 예를 들어, 새로운 콘텐츠 알림, 친구 요청, 중요한 앱 이벤트 등이 여기에 해당합니다.
#    - **Payment Notification**: 주로 결제 트랜잭션의 상태 업데이트를 위한 것입니다. 사용자의 결제 활동 (결제 완료, 결제 취소 등)에 대한 정보를 개발사의 서버로 전송하여 결제 상태를 실시간으로 관리하고 업데이트하는 데 사용됩니다.
#
# 2. **사용 컨텍스트**:
#    - **Push Notification**: 사용자 경험 향상을 위해 앱 외부에서 사용자에게 직접 알림을 보내는 데 사용됩니다. 사용자가 앱을 실행하지 않아도 알림을 받을 수 있습니다.
#    - **Payment Notification**: 주로 백엔드 시스템 간의 통신으로, 원스토어의 결제 시스템에서 개발사의 서버로 결제 상태 변경 정보를 전달합니다. 이는 주로 서버 간 데이터 동기화와 결제 트랜잭션 관리에 활용됩니다.
#
# 3. **데이터 내용**:
#    - **Push Notification**: 다양한 유형의 사용자 관련 정보나 앱 내 이벤트를 포함할 수 있습니다.
#    - **Payment Notification**: 주로 결제 관련 정보를 포함합니다. 예를 들어, 결제 ID, 결제 상태 (성공, 실패, 취소 등), 결제 방법, 사용자 정보 등이 포함될 수 있습니다.
#
# 요약하자면, Push Notification은 사용자에게 직접적인 정보 전달에 초점을 맞추고, Payment Notification은 결제 트랜잭션의 정확한 상태 관리와 업데이트에 중점을 두고 있습니다.
