# %%
import os
import re
from typing import List
from pathlib import Path
from langchain.docstore.document import Document
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_text_splitters import MarkdownHeaderTextSplitter

# %%
"""
Contextual Retrieval Class Implementation

이 모듈은 문서의 컨텍스트 정보를 생성하여 검색 품질을 향상시키는 
ContextualRetriever 클래스를 제공합니다.
"""

import os
from pathlib import Path
from typing import Optional, List
from langchain.docstore.document import Document
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser


class ContextualRetriever:
    """Contextual Retrieval을 위한 클래스"""
    
    def __init__(self, whole_document: str, model_name: str = "exaone3.5:latest", temperature: float = 0.1):
        """
        ContextualRetriever 초기화
        
        Args:
            whole_document (str): 전체 문서 내용
            model_name (str): 사용할 LLM 모델명 (기본값: "exaone3.5:latest")
            temperature (float): LLM temperature 설정 (기본값: 0.1)
        """
        self.whole_document = whole_document
        self.model_name = model_name
        self.temperature = temperature
        
        # LLM 초기화
        self._initialize_llm()
        
        # 프롬프트 템플릿 설정
        self._setup_prompt()
        
        # 체인 구성
        self._setup_chain()
        
        print(f"🚀 ContextualRetriever 초기화 완료")
        print(f"📄 전체 문서 길이: {len(self.whole_document):,} characters")
        print(f"🤖 모델: {self.model_name}")
        print(f"🌡️ Temperature: {self.temperature}")
        
    def _initialize_llm(self):
        """LLM 초기화"""
        print(f"🤖 LLM 초기화 중... ({self.model_name})")
        self.llm = ChatOllama(
            model=self.model_name,
            temperature=self.temperature
        )
        
    def _setup_prompt(self):
        """프롬프트 템플릿 설정"""
        print("📝 프롬프트 템플릿 설정 중...")
        self.contextual_prompt = PromptTemplate.from_template(
            """<document> 
{WHOLE_DOCUMENT} 
</document> 
다음은 chunk 처리된 Document입니다. chunk의 내용은 전체 문서에서 일부분을 의미합니다.
<chunk> 
{CHUNK_CONTENT}
</chunk> 
- document의 맥락에서 chunk를 간단 명료하게 요약해주세요.
- 요약문의 최대 토큰은 150 이하여야 합니다. 
- 요약문의 목적은 Document 내에 재삽입하여 retriever를 통합 검색 품질을 높이기 위함입니다.
- 요약문은 한글로 작성해 주세요. 단, chunk내에 코드명, 영문 이니셜 혹은 영어 표현이 문서를 요약하는데 반드시 필요한 내용이라면 영어 그대로 포함될 수 있습니다.
- 요약문을 대표할 수 있는 용어(예, 영문 이니셜, 기능명 등)는 요약문 내에 포함해 주세요.
- 주요 코드값은 한국어로 변환하지 마세요.
- 요약문의 끝부분에 문서를 대표할 수 있는 키워드를 추가해주세요.
"""
        )
        
    def _setup_chain(self):
        """체인 구성"""
        print("⛓️ 체인 구성 중...")
        self.chain = self.contextual_prompt | self.llm | StrOutputParser()
        
    def get_contextual_text(self, chunk_content: str, section_path: str, verbose: bool = True) -> Optional[Document]:
        """
        주어진 청크에 대한 컨텍스트 정보를 생성하고 향상된 Document를 반환
        
        Args:
            chunk_content (str): 처리할 청크 내용
            verbose (bool): 상세 로그 출력 여부 (기본값: True)
            
        Returns:
            Document: 향상된 Document 객체 (성공시) 또는 None (실패시)
        """
        if verbose:
            print(f"\n🔍 컨텍스트 정보 생성 시작...")
            print(f"📊 청크 길이: {len(chunk_content):,} characters")
        
        try:
            # 컨텍스트 정보 생성
            context = self.chain.invoke({
                "WHOLE_DOCUMENT": self.whole_document,
                "CHUNK_CONTENT": chunk_content
            })
            
            if verbose:
                print("=" * 50)
                print(f"✅ 생성된 컨텍스트:\n{context}")
                print("=" * 50)
            
            # 향상된 Document 생성
            enhanced_content = f"[제목]: {section_path}\n\n[요약]: {context}\n\n[원문]: {chunk_content}"
            
            enhanced_doc = Document(
                page_content=enhanced_content,
                metadata={
                    "original_content": chunk_content,
                    "contextual_info": context,
                    "source": "contextual_retrieval",
                    "model": self.model_name,
                    "original_length": len(chunk_content),
                    "enhanced_length": len(enhanced_content)
                }
            )
            
            if verbose:
                print(f"✅ 향상된 Document 생성 완료!")
                print(f"📏 원본 길이: {len(chunk_content):,} characters")
                print(f"📏 향상된 길이: {len(enhanced_doc.page_content):,} characters")
                print(f"📈 증가율: {(len(enhanced_doc.page_content) / len(chunk_content) - 1) * 100:.1f}%")
            
            return enhanced_doc
            
        except Exception as e:
            print(f"❌ 오류 발생: {e}")
            return None


    def get_stats(self) -> dict:
        """
        클래스 인스턴스의 통계 정보를 반환
        
        Returns:
            dict: 통계 정보 딕셔너리
        """
        return {
            "model_name": self.model_name,
            "temperature": self.temperature,
            "document_length": len(self.whole_document),
            "document_size_mb": len(self.whole_document) / (1024 * 1024),
        }
    
    def __repr__(self) -> str:
        """클래스의 문자열 표현"""
        return f"ContextualRetriever(model='{self.model_name}', doc_size={len(self.whole_document):,} chars)"

# %%
def load_markdown_file(file_path: str) -> str:
    """마크다운 파일을 로드합니다."""
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

contextual_retriever = ContextualRetriever(
    whole_document=load_markdown_file("data/dev_center_guide_allmd_touched.md"),
    model_name="exaone3.5:latest",
    temperature=0.1
)

print("\n" + "="*60)
print("✅ 클래스 초기화 완료 (import된 클래스 사용)!")
print("="*60)
# Out:
# 🤖 LLM 초기화 중... (exaone3.5:latest)
# 📝 프롬프트 템플릿 설정 중...
# ⛓️ 체인 구성 중...
# 🚀 ContextualRetriever 초기화 완료
# 📄 전체 문서 길이: 383,563 characters
# 🤖 모델: exaone3.5:latest
# 🌡️ Temperature: 0.1
#
# ============================================================
# ✅ 클래스 초기화 완료 (import된 클래스 사용)!
# ============================================================

# %%
def hierarchical_markdown_split(md_text: str, path_prefix: str = "") -> list[Document]:
    """마크다운 문서를 계층적으로 분할합니다."""
    splitter = MarkdownHeaderTextSplitter(headers_to_split_on=[
        ("#", "title"),
        ("##", "section"),
        ("###", "subsection"),
        ("####", "subsubsection"),
        ("#####", "subsubsubsection")
    ])
    docs = splitter.split_text(md_text)

    result_docs = []
    current_title = None
    chunk_idx = 0
    for doc in docs:
        metadata = doc.metadata
        if "title" in metadata:
            current_title = metadata["title"]

        if current_title:
            chunk_idx += 1
            full_title = "" + current_title
            if "section" in metadata:
                full_title += f" / {metadata['section']}"
            if "subsection" in metadata:
                full_title += f" / {metadata['subsection']}"
            if "subsubsection" in metadata:
                full_title += f" / {metadata['subsubsection']}"
            if "subsubsubsection" in metadata:
                full_title += f" / {metadata['subsubsubsection']}"

            # content = f"[section_path]: {full_title}\n\n{doc.page_content}"
            # doc = Document(page_content=content, metadata={
            #     **doc.metadata,
            #     "type": "documentation",
            #     "source": "dev_center_guide_allmd.md",
            #     "chunk_idx": chunk_idx
            # })
            doc = contextual_retriever.get_contextual_text(doc.page_content, section_path=full_title)

        result_docs.append(doc)

    return result_docs

def load_markdown_file(file_path: str) -> str:
    """마크다운 파일을 로드합니다."""
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

# 마크다운 파일 로드 및 분할
# allmd 적용시 검색 품질의 급격한 저하 확(495 chunks)
str_md_file = load_markdown_file("data/dev_center_guide_allmd_touched.md") 
docs_markdown = hierarchical_markdown_split(str_md_file)

print(f"마크다운 문서 분할 완료: {len(docs_markdown)}개 청크")
# Out:
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,165 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 인앱결제 API V7(SDK V21)은 최신 기능과 강력한 보안을 제공하며, 이전 버전(V4 이하)과 호환되지 않습니다. 주요 기능은 결제 테스트, 서버 API 활용, 정기 결제 구현 등이 포함됩니다. 이 버전은 앱 배포 시 대한민국 외 지역 가이드도 함께 제공됩니다. **API V7**, **결제 구현**, **서버 API**, **앱 배포 가이드**
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,165 characters
# 📏 향상된 길이: 1,437 characters
# 📈 증가율: 23.3%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 307 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 IAP는 안드로이드 앱 내에서 상품을 판매하고 결제하는 서비스로, 개발자는 '원스토어 IAP SDK'를 통해 앱에 연동할 수 있습니다. 이 서비스는 사용자 결제를 원스토어 인증 및 결제 시스템을 통해 처리하며, 개발자에게 정산을 지원합니다. 주요 용어: **IAP SDK**, **원스토어 결제 시스템**
#
# **키워드:** IAP, 원스토어 결제, SDK 연동
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 307 characters
# 📏 향상된 길이: 613 characters
# 📈 증가율: 99.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 894 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 인앱결제 API V7(SDK V21)는 관리형 상품과 구독형 상품을 지원합니다. 관리형 상품은 일회성 구매로 소비 전까지 재구매가 필요하며, 구독형 상품은 정해진 주기로 자동 결제를 처리합니다. 구독형 상품은 프로모션 기능과 결제 편의성을 제공하여 정기 결제 상품을 효과적으로 관리할 수 있습니다. (**API V7, 구독형 상품, 자동결제**)
#
# **키워드:** 인앱 결제, API V7, 구독형 상품, 자동결제
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 894 characters
# 📏 향상된 길이: 1,228 characters
# 📈 증가율: 37.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 45 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 인앱결제 프로세스는 크게 네 가지로 구성되어 있습니다: 결제 요청, 결제 처리, 결제 응답, 그리고 결과 확인. 개발자는 결제 요청을 위해 REST API를 통해 주문 정보와 결제 정보를 전송하며, 응답으로는 결제 성공 여부와 필요한 토큰 정보를 받습니다. 결제 완료 후에는 개발사로 결제 결과가 callbackUrl 또는 returnUrl을 통해 전달됩니다. 주요 키워드: 인앱결제, REST API, 결제응답, 결과확인
#
# **요약 키워드:** 인앱결제, 결제API, 응답처리, 결과확인
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 45 characters
# 📏 향상된 길이: 419 characters
# 📈 증가율: 831.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 145 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# GaaSignInClient 라이브러리는 Android 애플리케이션에서 원스토어 로그인 기능을 구현하기 위한 도구입니다. `getClient()` 메서드를 통해 로그인 클라이언트 인스턴스를 쉽게 생성할 수 있습니다. 이 라이브러리를 활용하면 사용자 인증 및 로그인 프로세스를 간소화하고 효율적으로 관리할 수 있습니다.
#
# **대표 키워드:** GaaSignInClient, 로그인, 원스토어, getClient()
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 145 characters
# 📏 향상된 길이: 546 characters
# 📈 증가율: 276.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 219 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `signInClient.launchSignInFlow(activity)` 함수는 UiThread에서만 호출되어야 하며, 백그라운드에서 로그인을 시도한 후 실패 시 자동 처리 후 사용자에게 로그인 화면을 제공합니다. 이를 통해 사용자는 원활한 로그인 경험을 얻을 수 있습니다. 주요 기능명은 `signInFlow`이며, 키워드로는 `로그인`, `UI스레드`를 추가합니다.
#
# **요약 키워드:** 로그인, UiThread, signInFlow
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 219 characters
# 📏 향상된 길이: 628 characters
# 📈 증가율: 186.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 206 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `signInClient.silentSignIn()` 함수를 통해 사용자의 백그라운드 로그인을 처리합니다. 이미 원스토어 계정에 로그인된 사용자의 경우, 토큰 기반의 로그인을 시도합니다. 이 과정에서 `SignInResult` 객체를 통해 로그인 성공 또는 실패 결과를 반환받습니다. 이 기능은 사용자 경험 향상을 위해 원활한 인증 프로세스를 제공하는 데 중점을 둡니다.
#
# **대표 키워드:** silentSignIn, SignInResult, 백그라운드 로그인, 원스토어 인증
#
# **추가 키워드:** 로그인 처리, 사용자 인증
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 206 characters
# 📏 향상된 길이: 664 characters
# 📈 증가율: 222.3%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 600 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 상품 구매 프로세스는 `queryProductDetailAsync` API를 통해 상품 정보를 획득한 후, `launchPurchaseFlow` API로 구매 화면을 호출합니다. 결제 완료 후 `PurchasesUpdatedListener`를 통해 구매 정보를 받고, 성공 코드 검증 후 인앱 아이템 지급 프로세스를 진행합니다. 주요 단계는 상품 정보 조회 → 구매 화면 호출 → 결제 처리 → 구매 정보 전달 → 아이템 지급으로 구성됩니다. **키워드:** 상품 구매, 인앱 결제, 구매 처리, 아이템 지급
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 600 characters
# 📏 향상된 길이: 1,036 characters
# 📈 증가율: 72.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,586 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 IAP 라이브러리를 사용할 때, 구매 확인은 필수적입니다. 소비형 상품은 `PurchaseClient.consumeAsync()`로 소비 처리를 해야 재구매가 가능하며, 영구형 상품은 `PurchaseClient.acknowledgeAsync()`로 구매 인증을 진행해야 합니다. 네트워크 문제 등으로 인해 미지급된 구매 내역이 있을 경우, `queryPurchases`와 `consume` 기능을 활용해 미지급 상품을 지급 처리하는 것이 중요합니다. **IAP 구매 확인**
#
# **키워드:** IAP 구매 확인, 소비 처리, 구매 인증, 미지급 상품 지급
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,586 characters
# 📏 향상된 길이: 2,048 characters
# 📈 증가율: 29.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 237 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 구독형 상품 관리 기능을 통해 사용자는 일시 중지, 해지, 결제 수단 변경 등을 관리할 수 있는 정기 결제 관리 화면을 이용할 수 있습니다. 이를 통해 `launchManageSubscription` API 호출이나 딥링크를 통해 정기 결제를 효과적으로 제어할 수 있습니다. **핵심 기능:** 일시 중지, 해지, 결제 수단 변경  **키워드:** 구독 관리, 정기 결제
#
# 이 요약문은 정기 결제 관리의 핵심 기능과 접근 방법을 간결하게 전달하며, 검색 시 관련성을 높일 수 있는 키워드를 포함하고 있습니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 237 characters
# 📏 향상된 길이: 664 characters
# 📈 증가율: 180.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 310 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 IAP SDK 적용을 위해 필요한 개발 환경은 다음과 같습니다:
# - Android 6.0 이상 (API 23 이상)
# - Java SDK 11 버전 이상
# - Android Studio 2.0 이상 버전
#
# **키워드:** 원스토어 IAP, 개발 환경, Android, Java SDK, Android Studio
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 310 characters
# 📏 향상된 길이: 584 characters
# 📈 증가율: 88.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 82 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 상품 등록 및 관리 가이드와 함께 제공된 문서는 원스토어 오픈마켓 API 문서로, 특히 상품 정보 API와 결제 API에 초점을 맞추고 있습니다. 상품 정보 API는 상품 등록, 수정, 삭제 등을 다루며, 결제 API는 결제 프로세스, 응답 처리, 그리고 결제 결과 전달 방법을 상세히 설명하고 있습니다. 결제 프로세스에서는 표준 결제 화면 구현과 결제 결과 전달을 위한 반환 URL 및 콜백 URL 사용법을 포함하고 있습니다. 주요 키워드: 상품 등록, 결제 API, 반환 URL, 콜백 URL, 결제 결과 전달.
#
# **키워드:** 상품 등록, 결제 API, 결제 결과 전달
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 82 characters
# 📏 향상된 길이: 493 characters
# 📈 증가율: 501.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 177 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 라이선스 관리 메뉴에서 원스토어 인앱 결제 내역의 위변조 확인을 위한 라이선스 키와 서버 API 인증을 위한 OAuth 정보를 확인할 수 있습니다. 이 정보들은 결제 내역의 정확성과 보안을 유지하는 데 필수적입니다. (KEY: LICENSE, KEYWORD: 결제보안)
#
# **요약문 최대 토큰 수 확인:** 149 토큰 이내로 작성되었습니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 177 characters
# 📏 향상된 길이: 519 characters
# 📈 증가율: 193.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 117 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 인앱 결제 API 문서는 결제 요청, 응답 처리, 보안 서명 등 결제 프로세스 전반을 상세히 설명합니다. 특히, 결제 요청 시 필요한 파라미터와 응답 코드 해석이 포함되어 있으며, 개발사는 이를 통해 안전하고 효율적인 결제 시스템을 구축할 수 있습니다. 주요 용어: **원스토어 IAP API**, **결제 서명**, **응답 코드**
#
# **키워드:** 원스토어 IAP, 결제 API, 보안 서명, 응답 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 117 characters
# 📏 향상된 길이: 476 characters
# 📈 증가율: 306.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 323 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 SDK 통합을 위한 주요 단계 요약:
#
# 1. **최상위 build.gradle** 파일에 원스토어 Maven 리포지토리 추가:
#    ```gradle
#    maven { url 'https://repo.onestore.net/repository/onestore-sdk-public' }
#    ```
#
# 2. **앱 build.gradle** 파일에 원스토어 결제 라이브러리 종속성 추가:
#    ```gradle
#    implementation "com.onestorecorp.sdk:sdk-iap:21.02.01"
#    ```
#
# **키워드:** 원스토어 SDK 통합, build.gradle, 결제 라이브러리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 323 characters
# 📏 향상된 길이: 764 characters
# 📈 증가율: 136.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 160 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 인앱 결제를 이용하려면 원스토어 앱을 먼저 설치해야 합니다. 앱 다운로드는 [링크](../../../policy/download)에서 안내받을 수 있습니다. 이 시스템은 개발자와 사용자가 안전하고 효율적인 결제 프로세스를 경험할 수 있도록 설계되었습니다. **결제API**
#
# **키워드:** 원스토어 결제API, 앱설치, 결제프로세스
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 160 characters
# 📏 향상된 길이: 444 characters
# 📈 증가율: 177.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 699 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어는 Sandbox와 상용테스트 환경을 통해 인앱 상품 결제 테스트를 지원합니다. Sandbox는 가상 결제 환경으로 원하는 응답 결과를 선택적으로 전송하며, 상용테스트는 실제 결제 환경에서 진행됩니다. 테스트를 위해서는 사전에 원스토어 ID를 테스트 ID로 등록해야 하며, 테스트 결제는 개발사 내부 책임자의 관리 하에 진행되어야 합니다. 과금 발생에 주의해야 합니다.
#
# **대표 키워드:** 원스토어 테스트 환경, 결제 테스트 주의사항
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 699 characters
# 📏 향상된 길이: 1,037 characters
# 📈 증가율: 48.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 104 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# In-App 결제 테스트 기능은 '결제 테스트' 버튼을 통해 접근 가능하며, 여기서 테스트 ID 관리와 결제 테스트 내역 조회가 가능합니다. 이 기능은 개발자가 인앱 결제 시스템을 효과적으로 테스트하고 관리할 수 있도록 지원합니다. **결제 테스트**
#
# **키워드:** 결제 테스트, 인앱 결제, 테스트 관리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 104 characters
# 📏 향상된 길이: 375 characters
# 📈 증가율: 260.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 279 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 테스트 환경에서 인앱 결제를 위한 테스트 ID 등록이 필수적입니다. 원스토어 회원 ID 또는 테스트용 원스토어 계정을 통해 생성된 테스트 ID를 등록할 수 있습니다. 테스트 ID 관리는 '테스트 ID 등록/관리' 탭에서 이루어지며, 이는 개발 및 상용 환경에서 결제 테스트를 원활하게 진행하기 위한 핵심 단계입니다.
#
# **대표 키워드:** 테스트 ID 등록, 인앱 결제 테스트, 원스토어 테스트 계정
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 279 characters
# 📏 향상된 길이: 608 characters
# 📈 증가율: 117.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 326 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 테스트 ID로 원스토어 회원 ID를 조회하고, 선택한 결제 환경(Sandbox 또는 상용테스트)에서 결제 테스트를 진행합니다. 테스트 ID 등록 시 필요한 정보를 입력하고 저장하며, 환경 설정은 언제든지 변경 가능합니다. 변경 사항은 반드시 '저장' 버튼으로 적용해야 합니다.
#
# **대표 키워드:** 테스트 ID, 결제 환경 설정, 저장 기능, 결제 테스트
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 326 characters
# 📏 향상된 길이: 692 characters
# 📈 증가율: 112.3%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 136 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 테스트 ID 관리 기능을 통해 유효하지 않은 테스트 ID를 삭제할 수 있습니다. 개별 삭제 또는 체크박스를 활용한 일괄 삭제 옵션이 제공됩니다. 이 기능은 검색 품질 향상을 위해 문서 내에 통합될 예정입니다. (키워드: 테스트 ID 관리)
#
# **대표 키워드:** 테스트 ID 관리, 검색 품질 향상
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 136 characters
# 📏 향상된 길이: 441 characters
# 📈 증가율: 224.3%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 195 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 테스트 ID 관리 기능을 통해 여러 앱 간에 테스트 ID를 공유하고 복사할 수 있습니다. 복사 가능 앱은 체크박스 활성화로 확인되며, 선택 후 '복사하기' 버튼을 누르면 됩니다. 샌드박스 테스트 ID는 앱 등록 여부에 따라 제한될 수 있습니다. **API 테스트 관리**
#
# 이 요약은 주요 기능과 사용 방법을 간결하게 전달하며, 문서의 핵심 키워드인 "API 테스트 관리"를 포함하여 문서의 주제를 명확히 합니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 195 characters
# 📏 향상된 길이: 551 characters
# 📈 증가율: 182.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 601 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# Sandbox 환경은 가상 결제 테스트를 위한 플랫폼으로, 개발자는 원하는 결제 결과(성공/실패)를 선택하여 테스트할 수 있습니다. 테스트는 특정 국가/지역에 국한되지 않고 편리한 환경에서 진행 가능하며, 안드로이드 환경에서 주로 수행됩니다. 테스트 ID를 Sandbox로 설정해야 Sandbox 결제 테스트가 가능하며, 환경 변경 시 앱 재시작이 필요합니다. 주요 키워드: Sandbox 테스트, 결제 시뮬레이션, 앱 재시작
#
# **대표 용어:** Sandbox 테스트
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 601 characters
# 📏 향상된 길이: 1,067 characters
# 📈 증가율: 77.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 629 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# Sandbox 환경에서 구독형 상품 테스트를 용이하게 하기 위해 결제 주기와 기능별 가상 시간 흐름을 조정하였습니다. 주요 시간 설정은 다음과 같습니다:
#
# - **결제 주기:**
#   - 1주: 5분
#   - 1개월: 5분
#   - 3개월: 10분
#   - 6개월: 15분
#   - 1년: 30분
#
# - **기능:**
#   - 무료 구독: 3분
#   - 유예 기간: 5분
#   - 계정 보류: 10분
#   - 가격 변경 반영 (7일): 5분
#   - 가격 변경 동의 기간 (30일): 5분
#
# **대표 키워드:** Sandbox, 구독 주기, 테스트 시간 조정, 결제 주기
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 629 characters
# 📏 향상된 길이: 1,141 characters
# 📈 증가율: 81.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 464 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 상용테스트 환경에서 인앱상품 결제를 진행하고 결과를 확인할 수 있습니다. 테스트 ID가 상용테스트로 설정되어 있어야 하며, 실제 결제가 발생할 수 있으므로 테스트 후 반드시 결제취소를 진행해야 합니다. 테스트 ID 설정 오류 시 실제 과금이 발생할 수 있으니 주의가 필요합니다. **(키워드: 상용테스트, 결제취소, 테스트ID)**
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 464 characters
# 📏 향상된 길이: 761 characters
# 📈 증가율: 64.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 440 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 인앱결제 테스트 환경에서 Sandbox와 상용테스트 탭을 통해 결제 내역을 조회하고 결제 상태를 확인할 수 있습니다. 각 결제 내역에 대한 상세 정보(상품 정보, 결제 상태 등)를 확인하며 필요 시 결제 취소도 가능합니다. 주요 키워드: 인앱결제 테스트, Sandbox, 상용테스트, 결제 내역 조회, 결제 취소
#
# **대표 키워드:** IAP_TEST, Sandbox_Payment, Cancel_Option
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 440 characters
# 📏 향상된 길이: 777 characters
# 📈 증가율: 76.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 889 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 인앱 결제 보안 강화를 위해 개발사는 서버 기반 인증 시스템 구축, 코드 난독화 적용, 결제 관련 정보 서버 저장 등을 권장합니다. 특히 'developerPayload' 필드를 활용해 결제 요청과 완료 시 추가 보안 검증 데이터를 교환하면 보안성을 높일 수 있습니다. 핵심 용어: **보안 강화, 개발자페이로드**
#
# **대표 키워드:** 보안, 결제 보안
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 889 characters
# 📏 향상된 길이: 1,239 characters
# 📈 증가율: 39.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 498 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 인증 및 서명 검증**
#
# - **키 알고리즘**: RSA 방식 사용
# - **서명 알고리즘**: SHA512withRSA
# - **SDK 활용**: 'AppSecurity' 클래스의 `verifyPurchase` 메서드를 통해 서명 인증 수행
# - **직접 구현**: SDK 없이 직접 서명 검증 코드 구현 필요
#
# **키워드**: 서명 인증, RSA, SHA512withRSA, AppSecurity
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 498 characters
# 📏 향상된 길이: 876 characters
# 📈 증가율: 75.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 81 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 결제 라이브러리는 Java 환경에서 최신 결제 기능을 지원하며, 이 가이드는 해당 라이브러리의 구현 방법을 설명합니다. 주요 기능으로는 결제 요청, 응답 처리, 그리고 다양한 응답 코드 해석이 포함되어 있습니다. 특히, 결제 성공 및 실패 시의 응답 처리와 개발자 페이로드를 통한 구매 식별이 강조됩니다. **결제API, Java**
#
# 이 요약은 문서의 핵심 내용을 간결하게 전달하며, 검색 품질 향상을 위해 주요 용어와 키워드를 포함하고 있습니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 81 characters
# 📏 향상된 길이: 400 characters
# 📈 증가율: 393.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 459 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 SDK 통합을 위한 주요 단계는 다음과 같습니다:
# 1. 프로젝트 최상위 `gradle` 파일에 원스토어 Maven 리포지토리 주소를 추가합니다 (`settings.gradle` 또는 `build.gradle`).
# 2. 앱의 `build.gradle` 파일에 원스토어 결제 라이브러리 종속 항목을 포함시킵니다 (예: `implementation "com.onestorecorp.sdk:sdk-iap:21.xx.xx"`).
#
# **대표 용어:** 원스토어 SDK 통합
# **키워드:** 원스토어, SDK, 결제 라이브러리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 459 characters
# 📏 향상된 길이: 840 characters
# 📈 증가율: 83.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 773 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `AndroidManifest.xml` 파일에 `<queries>` 섹션을 추가하여 원스토어 In-app SDK를 활성화해야 합니다. 특히 `<intent>` 태그 내에서 `com.onestore.ipc.iap.IapService.ACTION` 액션과 `android.intent.action.VIEW` 액션을 지정해야 합니다. 이 설정은 SDK가 원스토어 서비스를 올바르게 인식하고 사용할 수 있도록 보장합니다. 이를 통해 앱 내 결제 및 상품 기능을 원활하게 구현할 수 있습니다.
#
# **대표 용어:** AndroidManifest, `<queries>`, SDK 활성화
#
# **키워드:** AndroidManifest, 원스토어 SDK, `<queries>` 태그
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 773 characters
# 📏 향상된 길이: 1,229 characters
# 📈 증가율: 59.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 830 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# IAP SDK 21.02.00 버전부터 `onestore:dev_option`의 `android:value`를 설정하여 특정 스토어 앱과 연동할 수 있습니다. 주요 값은 다음과 같습니다:
# - `onestore_00`: 대한민국 (기본값)
# - `onestore_01`: 싱가포르, 타이완
# - `onestore_02`: 미국 – Digital Turbine
#
# **주의사항:** 배포 버전에서는 이 옵션을 반드시 제거해야 합니다.
#
# **키워드:** IAP SDK, onestore_dev_option, 스토어 연동, 배포 주의사항
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 830 characters
# 📏 향상된 길이: 1,250 characters
# 📈 증가율: 50.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 549 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# SDK 로그 레벨 설정을 통해 개발 단계에서 데이터 흐름을 자세히 확인할 수 있습니다. `Logger.setLogLevel()` 함수를 사용하여 로그 레벨을 조정할 수 있으며, 상수 값은 다음과 같습니다:
# - VERBOSE: 2
# - DEBUG: 3
# - INFO (기본값): 4
# - WARN: 5
# - ERROR: 6
#
# **주의:** 배포 버전에서는 보안 문제로 인해 이 옵션을 삭제해야 합니다.
#
# **대표 키워드:** SDK 로그 레벨, Logger 설정, 보안 주의
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 549 characters
# 📏 향상된 길이: 893 characters
# 📈 증가율: 62.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 198 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 결제 라이브러리는 `IapResult` 형식으로 결제 관련 오류를 `ResponseCode`를 통해 반환합니다. 주요 오류 코드로는 `RESULT_NEED_LOGIN`, `RESULT_NEED_UPDATE` 등이 있으며, 앱은 이러한 코드에 따라 적절한 사용자 처리를 해야 합니다. 결제 결과는 `callbackUrl`을 통해 JSON 형태로 전달되며, 성공 시 `Success` 메시지를 포함합니다. 키워드: 결제 오류, IapResult, ResponseCode, 결제 결과 처리
#
# **요약 키워드:** 결제 오류 처리, IapResult, ResponseCode, 결제 결과
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 198 characters
# 📏 향상된 길이: 652 characters
# 📈 증가율: 229.3%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,325 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `GaaSignInClient` 라이브러리를 사용하여 원스토어 로그인을 처리합니다. `getClient()`로 인스턴스를 생성한 후, 백그라운드에서는 `silentSignIn()`으로 비동기 로그인을 시도하고, 사용자 인터페이스에서는 `launchSignInFlow()`로 동기 로그인을 진행합니다. 로그인 결과는 `SignInResult` 객체로 반환됩니다. 주요 기능 키워드: `GaaSignInClient`, `silentSignIn`, `launchSignInFlow`.
#
# **키워드:** GaaSignInClient 로그인 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,325 characters
# 📏 향상된 길이: 1,756 characters
# 📈 증가율: 32.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,327 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchaseClient`는 원스토어 결제 시스템과 앱 간의 통신을 위한 핵심 인터페이스로, 구매 업데이트를 효율적으로 관리합니다. 앱에서 구매 관련 이벤트를 실시간으로 모니터링하려면 `PurchaseClient`를 초기화하고 `PurchasesUpdatedListener`를 설정해야 합니다. 또한 보안을 위해 구매 데이터의 무결성을 확인하기 위해 `setBase64PublicKey()` 메서드를 사용하는 것이 권장됩니다. 이 기능을 통해 앱은 구매 정보의 변조를 방지할 수 있습니다. **핵심 용어:** PurchaseClient, PurchasesUpdatedListener, 보안 키 설정
# **키워드:** 구매 관리, 보안 결제 통신
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,327 characters
# 📏 향상된 길이: 1,858 characters
# 📈 증가율: 40.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,091 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchaseClient`를 생성하고 `startConnection()`을 통해 원스토어 서비스에 연결합니다. 연결 완료 시 `PurchaseClientStateListener` 콜백을 통해 상태를 확인할 수 있습니다. 연결 준비가 완료되면 구매 정보 쿼리를 시작할 수 있으며, 연결 실패 시 재연결을 시도합니다. 주요 용어: `PurchaseClient`, `startConnection`, `PurchaseClientStateListener`. 키워드: 구매, 연결, 쿼리
#
# **요약 키워드:** 구매 연결 쿼리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,091 characters
# 📏 향상된 길이: 1,515 characters
# 📈 증가율: 38.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,630 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `queryProductDetailsAsync()` 함수를 사용하여 상품 상세 정보를 비동기로 조회할 수 있습니다. 이 함수는 `ProductDetailsParams` 객체를 통해 상품 유형(`ProductType`)과 상품 ID 목록을 지정하며, 주로 관리형 상품(`ProductType.INAPP`)과 구독 상품(`ProductType.SUBS`)의 정보를 가져옵니다. 결과 처리를 위해 `ProductDetailsListener` 인터페이스를 구현해야 하며, Kotlin과 Java 모두에서 해당 함수를 호출하는 방법이 제공됩니다. 이 기능은 제품 정보를 사용자에게 표시하기 전에 필수적인 단계입니다. **키워드:** 상품 상세 조회, 비동기 처리, ProductDetailsListener, ProductType
#
# **키워드 요약:** 상품 상세 조회 API, 비동기 처리, 개발자 센터 상품 ID
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,630 characters
# 📏 향상된 길이: 2,212 characters
# 📈 증가율: 35.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 4,365 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 구매 플로우 처리를 위해 앱은 `launchPurchaseFlow()` 함수를 호출하며, 이 과정에서 `PurchaseFlowParams` 객체를 생성합니다. 이 객체는 상품 정보와 함께 개발자 페이로드, 상품 수량, 상품 이름, 사용자 ID 및 프로모션 적용 여부 등의 옵션 파라미터를 설정할 수 있습니다. 구매 요청이 성공하면 사용자에게 결제 완료 화면이 표시되고, 성공 시 구매 토큰과 영수증 이메일이 제공됩니다. 주요 키워드: PurchaseFlowParams, launchPurchaseFlow, 구매 토큰, 영수증 이메일, 프로모션 적용.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 4,365 characters
# 📏 향상된 길이: 4,799 characters
# 📈 증가율: 9.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 442 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 정기 결제 상태는 활성, 일시 중지 예약, 주간/월간 일시 중지, 해지 예약, 유예/보류로 구분됩니다. 활성 상태에서는 사용자가 콘텐츠를 원활하게 이용 가능하며, 일시 중지 옵션을 통해 일정 기간 동안 결제를 중단할 수 있습니다. 해지 예약 상태에서는 다음 결제일에 결제가 이루어지지 않으며, 유예/보류 상태에서는 즉시 해지가 가능합니다. **정기결제, 상태관리**
#
# **키워드:** 정기결제, 상태변경, 사용자관리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 442 characters
# 📏 향상된 길이: 799 characters
# 📈 증가율: 80.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,309 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 정기 결제 업그레이드 또는 다운그레이드 시 비례 배분 모드를 설정할 수 있습니다. 주요 모드는 다음과 같습니다:
# - **IMMEDIATE\_WITH\_TIME\_PRORATION**: 교체 즉시 남은 기간 가격 조정 청구 (기본 동작)
# - **IMMEDIATE\_AND\_CHARGE\_PRORATED\_PRICE**: 업그레이드 시 즉시 교체 및 나머지 기간 가격 청구
# - **IMMEDIATE\_WITHOUT\_PRORATION**: 교체 즉시 다음 결제일에 새로운 가격 청구
# - **DEFERRED**: 기존 요금제 만료 후 새 요금제 적용 및 동시 청구
#
# **대표 용어:** 비례 배분 모드 (ProrationMode)
# **키워드:** 정기 결제, 비례 배분, 업그레이드/다운그레이드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,309 characters
# 📏 향상된 길이: 1,909 characters
# 📈 증가율: 45.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,637 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 정기 결제 업그레이드 및 다운그레이드는 기존 구매 토큰과 비례 배분 모드를 포함한 정보를 사용하여 수행됩니다. Kotlin과 Java에서 각각 `SubscriptionUpdateParams`와 `PurchaseFlowParams`를 통해 업데이트 요청을 보내며, 이 과정에서도 `PurchasesUpdatedListener`를 통해 응답을 수신합니다. 비례 배분 모드의 경우에도 일반 구매와 마찬가지로 `PurchaseClient.acknowledgeAsync()`를 통해 구매 확인이 필요합니다. 정기 결제 관리와 관련된 주요 키워드: **정기 결제**, **비례 배분 모드**, **업데이트 요청**.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,637 characters
# 📏 향상된 길이: 2,161 characters
# 📈 증가율: 32.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 343 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 구매 완료 후 앱은 `PurchasesUpdatedListener` 또는 `PurchaseClient.queryPurchasesAsync()`를 통해 구매 내역을 확인해야 합니다. 소모성 제품은 `PurchaseClient.consumeAsync()`로 확인하고, 그렇지 않은 경우 `PurchaseClient.acknowledgeAsync()`를 사용하여 구매를 인정합니다. 이 과정은 구매 내역의 정확한 처리와 앱 내 재고 관리에 필수적입니다. **(키워드: PurchaseClient, consumeAsync, acknowledgeAsync)**
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 343 characters
# 📏 향상된 길이: 779 characters
# 📈 증가율: 127.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,823 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 관리형 상품 소비 처리 가이드
# - `consumeAsync()` 함수를 통해 상품 소비 요청 가능
# - 소비 결과 확인을 위해 `ConsumeListener` 인터페이스 구현 필요
# - 구매 확인(`acknowledge`) 또는 소비(`consume`) 미실시 3일 이내 자동 환불
# - 키워드: ConsumeAsync, ConsumeListener, 자동환불
#
# 이 요약은 관리형 상품의 소비 프로세스와 주의사항을 간결하게 전달하며, 주요 함수와 인터페이스 이름을 포함하여 문서의 핵심 내용을 효과적으로 전달합니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,823 characters
# 📏 향상된 길이: 2,327 characters
# 📈 증가율: 27.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,663 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchaseClient.acknowledgeAsync()` 함수를 사용하여 비 소비성 상품의 구매 확인 처리를 수행할 수 있습니다. 이 함수는 관리형 상품, 월정액 상품, 구독형 상품 모두에 적용 가능하며, 구매 확인 여부는 `PurchaseData.isAcknowledged()`로 확인할 수 있습니다. 구매 확인 결과를 받기 위해 `AcknowledgeListener`를 구현해야 합니다. 처리 결과는 `AcknowledgeListener.onAcknowledgeResponse()`를 통해 얻을 수 있으며, 이 데이터는 초기 요청 시의 상태를 반영하므로 필요시 구매 내역을 다시 조회해야 합니다. **핵심 용어:** PurchaseClient, AcknowledgeAsync, AcknowledgeListener
#
# **키워드:** 구매 확인, PurchaseClient, 상품 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,663 characters
# 📏 향상된 길이: 2,327 characters
# 📈 증가율: 39.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,915 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchasesUpdatedListener`만으로는 모든 구매 처리를 보장할 수 없으므로, 앱은 `onCreate()` 또는 `onResume()`에서 `PurchaseClient.queryPurchasesAsync()`를 호출하여 구매 확인이 필요합니다. 이를 통해 네트워크 문제나 다중 기기 사용 등의 예외 상황에서도 구매를 정확히 추적할 수 있습니다. 주요 코드 예시는 Kotlin과 Java로 제공되며, 각 상황에 따른 적절한 콜백 처리 방법이 포함되어 있습니다. **핵심 키워드:** 구매 추적, 네트워크 문제, 다중 기기, `PurchaseClient`, `queryPurchasesAsync`
#
# **대표 키워드:** 구매 추적, 네트워크 안정성, 다중 기기 지원, `PurchaseClient` API
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,915 characters
# 📏 향상된 길이: 2,446 characters
# 📈 증가율: 27.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,778 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 월정액 상품 관리 기능 소개
# - `PurchaseClient.manageRecurringProductAsync()`를 통해 구독 상태 변경 가능
# - `RecurringProductParams`로 구매 데이터와 변경 액션(중지/재활성화 등) 설정
# - SDK V21 이후 신규 월정액 상품 생성 불가, 대신 구독형 상품 이용 권장
# - `RecurringProductListener`로 응답 처리, 변경된 `PurchaseData`는 별도 조회 필요
#
# **키워드:** 월정액, 구독관리, PurchaseClient, RecurringProductParams
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,778 characters
# 📏 향상된 길이: 2,265 characters
# 📈 증가율: 27.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 976 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 정기 결제 관리 화면을 띄우기 위해 `launchManageSubscription` 함수를 사용합니다. 이 함수는 `SubscriptionParams` 객체를 생성하는데, 이 객체는 선택적으로 `PurchaseData`를 포함할 수 있습니다. `PurchaseData`가 제공되면 해당 정기 결제 상품의 관리 화면이 실행되고, 제공되지 않으면 사용자의 전체 정기 결제 리스트 화면이 나타납니다. Kotlin과 Java 모두에서 동일한 방식으로 구현 가능하며, 주요 코드값은 변경 없이 유지됩니다.
#
# **대표 키워드:** 정기결제 관리, SubscriptionParams, PurchaseData
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 976 characters
# 📏 향상된 길이: 1,443 characters
# 📈 증가율: 47.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 547 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# SDK 버전 19 이상에서는 Server API를 사용하기 위해 마켓 구분 코드(`storeCode`)가 필수적입니다. `getStoreInfoAsync()` 메서드를 통해 마켓 코드를 획득하고, 이를 Server to Server API 호출 시 활용해야 합니다. 이 과정은 결제 및 구매 정보의 정확한 처리를 위해 중요합니다.
#
# **대표 키워드:** Server API, 스토어 코드, getStoreInfoAsync
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 547 characters
# 📏 향상된 길이: 913 characters
# 📈 증가율: 66.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 88 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `StoreEnvironment.getStoreType()` API는 애플리케이션이 원스토어 환경에서 실행되고 있는지 확인하는 기능을 제공합니다. 이 API를 통해 개발자는 플랫폼 구분 없이 일관된 동작을 구현할 수 있으며, 원스토어 설치 여부를 쉽게 판단할 수 있습니다. **KEYWORD: StoreType 확인**
#
# 이 기능은 애플리케이션의 플랫폼 인식과 환경 적응을 용이하게 하여 사용자 경험을 향상시키는 데 기여합니다. **KEYWORD: 플랫폼 인식**
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 88 characters
# 📏 향상된 길이: 450 characters
# 📈 증가율: 411.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 574 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 이 문서는 ONE Store 이벤트 API를 통해 앱의 스토어 정보와 구매 내역을 조회하는 방법을 설명합니다. 주요 기능은 다음과 같습니다:
#
# - **StoreType 조회**: 앱의 설치 스토어 유형을 확인 (UNKNOWN, ONESTORE, VENDING, ETC)
# - **이벤트 데이터 가져오기**: 앱 내 구매 내역, 이벤트 참여 정보 등을 REST API를 통해 가져옵니다.
# - **결제 결과 처리**: 결제 성공/실패 결과를 `returnUrl` 또는 `callbackUrl`을 통해 개발자에게 전달합니다.
#
# **대표 키워드**: ONE Store API, 스토어 유형, 이벤트 데이터, 결제 결과 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 574 characters
# 📏 향상된 길이: 1,036 characters
# 📈 증가율: 80.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 941 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# ONE Store API 문서는 앱 내 구매 및 결제 처리를 위한 다양한 엔드포인트와 요청/응답 구조를 설명합니다. 주요 기능으로는 상품 정보 조회, 구매 요청, 결제 상태 확인 등이 포함되어 있으며, 각 요청은 JSON 형식으로 데이터를 주고받습니다. 결제 결과는 `returnUrl` 또는 `callbackUrl`을 통해 개발자에게 전달됩니다. 요약 키워드: ONE Store API, 구매 처리, 결제 결과 전달
#
# **요약 키워드:** ONE Store API, 구매 처리, 결제 결과
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 941 characters
# 📏 향상된 길이: 1,330 characters
# 📈 증가율: 41.3%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 372 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 이 문서는 앱의 스토어 판별 방법을 설명하며, 세 가지 주요 방법을 제시합니다:
# 1. **원스토어 마켓 서명 확인**: 원스토어에서 배포된 앱인지 확인합니다.
# 2. **Installer Package Name 분석**: 원스토어 서명 없이도 설치 패키지 이름을 통해 스토어를 판별합니다.
# 3. **개발자 옵션 활성화 확인**: `onestore:dev_option`이 활성화되면 무조건 원스토어(ONESTORE)로 판별합니다.
#
# **핵심 키워드**: ONESTORE, 스토어 판별, 마켓 서명, Installer Package Name, 개발자 옵션
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 372 characters
# 📏 향상된 길이: 794 characters
# 📈 증가율: 113.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 416 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# ONE Store 결제 API는 결제 요청, 결제 결과 처리 등을 위한 RESTful API를 제공합니다. 주요 기능으로는 결제 요청 시 필요한 파라미터 전송, 결제 완료 후 개발사로 결과 반환 등이 포함됩니다. 스토어별 UI 차별화와 기능 차단을 위한 조건문을 활용하여 원스토어 특화 기능을 적용할 수 있습니다. 결제 결과 전달은 `returnUrl` (Form 데이터)와 `callbackUrl` (JSON 데이터) 두 방식으로 이루어지며, 각각의 방식은 결제 성공 여부와 필요한 파라미터를 포함합니다. 주요 키워드: ONE Store, 결제 API, 스토어 특화 기능, 결제 결과 처리.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 416 characters
# 📏 향상된 길이: 858 characters
# 📈 증가율: 106.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 651 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# ONE Store 서비스 버전 확인 후 인앱 결제 기능 활성화 필요. Kotlin에서 `PurchaseClient.startConnection()` 호출 후 `IapResult.getResponseCode()`로 연결 상태 확인. `RESULT_NEED_UPDATE` 시 `launchUpdateOrInstallFlow()` 메서드로 업데이트 또는 설치 흐름 시작. 결제 연결 재시도 권장.
#
# **대표 키워드:** ONE Store, PurchaseClient, 연결 재시도, 업데이트 흐름
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 651 characters
# 📏 향상된 길이: 1,058 characters
# 📈 증가율: 62.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 4,119 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 이 문서는 OneStore Billing API의 주요 기능과 클래스, 인터페이스를 설명합니다. 특히 `PurchaseClient`, `PurchaseData`, `SubscriptionParams` 등 구매 및 구독 관리 관련 클래스들이 강조됩니다. `AcknowledgeParams`, `ConsumeParams`, `IapResult` 등의 매개변수 클래스와 `AcknowledgeListener`, `ConsumeListener`, `PurchaseClientStateListener` 등의 리스너 인터페이스도 중요한 역할을 합니다. 이 문서는 개발자들이 구매 흐름을 관리하고 구독을 처리하는 데 필요한 도구와 방법을 제공합니다.
#
# **키워드:** Billing API, Purchase Client, Subscription Management
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 4,119 characters
# 📏 향상된 길이: 4,588 characters
# 📈 증가율: 11.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,126 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **Purchase API 요약**
#
# - **주요 기능**: 구매 클라이언트 연결 상태, 구매 데이터 상태 관리, 결제 흐름 파라미터 설정 등을 위한 다양한 어노테이션 제공.
# - **어노테이션 예시**: `PurchaseClient.ConnectionState`, `PurchaseData.PurchaseState`, `PurchaseFlowParams.ProrationMode` 등.
# - **응답 코드**: 결제 성공(`Success`), 실패(`Fail`), 사용자 취소(`UserCancel`), 결제 시간 만료(`PaymentTimeExpired`) 등 다양한 응답 상태 처리 지원.
#
# **키워드**: Purchase API, 구매 클라이언트, 결제 흐름, 응답 코드 관리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,126 characters
# 📏 향상된 길이: 1,548 characters
# 📈 증가율: 37.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 148 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchaseClient.ConnectionState` 인터페이스는 `com.gaa.sdk.iap.PurchaseClient` 클래스의 연결 상태를 정의합니다. 이 상태 값은 앱 내 구매 클라이언트의 연결 상태를 관리하는데 사용되며, 개발자가 클라이언트의 실시간 연결 상태를 추적하고 관리할 수 있도록 지원합니다. 주요 키워드: PurchaseClient, ConnectionState, 구매 클라이언트 연결 상태 관리.
#
# **키워드:** PurchaseClient, 연결 상태 관리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 148 characters
# 📏 향상된 길이: 481 characters
# 📈 증가율: 225.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 3 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 결제 서비스 API**
#
# 이 문서는 결제 서비스를 위한 API 구조와 기능을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 서비스 엔드포인트**: 결제 관련 요청을 처리하는 엔드포인트 정보 제공.
# 2. **결제 요청 및 응답 포맷**: 결제 요청과 응답에 사용되는 JSON 및 폼 데이터 포맷 설명.
# 3. **결제 상태 확인**: 결제 상태를 확인하기 위한 엔드포인트와 요청 방법 설명.
# 4. **결제 서비스 오류 처리**: 결제 과정에서 발생할 수 있는 오류 코드와 설명 제공.
# 5. **결제 결과 전달**: 반환 URL과 콜백 URL을 통한 결제 결과 전달 방법 설명.
#
# **키워드**: 결제 API, 엔드포인트, JSON 포맷, 오류 처리, 결제 결과 전달
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 3 characters
# 📏 향상된 길이: 576 characters
# 📈 증가율: 19100.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 72 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 문서 요약:**
#
# **API 이름:** OnePay API
# **주요 기능:** 결제 요청 및 결과 처리
# **요청 타입:** REST API
# ** ** **
# - **결제 요청:**
#   - **엔드포인트:** `/payment`
#   - **방법:** POST
#   - **요청 파라미터:** 결제 정보 (금액, 상품 정보 등)
#   - **응답:** 결제 요청 확인 메시지 및 토큰 반환
#
# - **결제 응답 처리:**
#   - **방법:**
#     - **리턴 URL 방식:** 결제 결과 페이지로 리다이렉트 (`returnUrl` 파라미터 사용)
#     - **콜백 URL 방식:** JSON 형식으로 결제 결과 전달 (`callbackUrl` 파라미터 사용)
#   - **응답 코드:**
#     - `Success`: 결제 성공
#     - `Fail`: 결제 실패 (오류 메시지 포함)
#     - `UserCancel`: 사용자 취소
#     - `PaymentTimeExpired`: 결제 시간 만료
#
# **주요 키워드:** OnePay API, 결제 요청, 결제 응답, REST API, 리턴 URL, 콜백 URL, 응답 코드
#
# **문서 키워드:** OnePay API 결제 처리 문서
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 72 characters
# 📏 향상된 길이: 1,017 characters
# 📈 증가율: 1312.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 62 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 현재 서비스는 `CONNECTED` 상태로, 사용자와의 안정적인 연결을 유지하고 있습니다 (Constant Value: 2). 이 상태는 서비스의 지속적인 가용성과 사용자 요청 처리 능력을 보장합니다. 키워드: CONNECTED, 서비스 가용성
#
# **참고 키워드:** CONNECTED 상태, 서비스 연결 품질
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 62 characters
# 📏 향상된 길이: 546 characters
# 📈 증가율: 780.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 68 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 현재 서비스는 `CONNECTING` 상태로, 사용자와의 연결이 진행 중입니다. 이 상태는 서비스와 클라이언트 간의 통신 연결 설정 과정을 나타냅니다. (키워드: CONNECTING, 연결 상태)
#
# **요약 키워드:** CONNECTING 상태, 연결 설정
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 68 characters
# 📏 향상된 길이: 525 characters
# 📈 증가율: 672.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 180 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 서비스 상태 코드 요약:**
#
# - **DISCONNECTED (0)**: 서비스와의 연결이 끊어진 상태를 나타냅니다. 이 상태에서는 결제 및 데이터 통신이 불가능합니다.
#
# **키워드:** DISCONNECTED, 서비스연결, 결제상태
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 180 characters
# 📏 향상된 길이: 636 characters
# 📈 증가율: 253.3%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 125 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchaseClient.FeatureType` 인터페이스는 구매 클라이언트에서 지원하는 기능 유형을 정의합니다. 주요 기능 유형은 문서 내에서 구체적으로 명시되어 있으며, 이를 통해 다양한 구매 관련 기능을 관리하고 통합할 수 있습니다. 이 기능은 구매 프로세스의 효율성과 사용자 경험 향상에 중점을 두고 있습니다. **구매 기능 유형**
#
# **키워드:** PurchaseClient, FeatureType, 구매 기능
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 125 characters
# 📏 향상된 길이: 419 characters
# 📈 증가율: 235.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 3 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# API 문서는 원스토어 결제 시스템의 상세한 API 사용법을 설명합니다. 주요 내용은 다음과 같습니다:
#
# - **결제 요청**: 결제 요청을 위한 요청 파라미터와 서명 검증 방법 설명.
# - **결제 응답**: 결제 결과를 전달하는 두 가지 방식 (`returnUrl`, `callbackUrl`)에 대한 세부 사항 포함.
# - **응답 코드**: 결제 성공 및 실패 시의 응답 코드와 메시지 목록 제공.
#
# **대표 키워드:** 결제 API, 서명 검증, 응답 처리, 결제 결과 전달
#
# 이 요약은 문서의 핵심 내용을 간결하게 전달하여 검색 및 이해를 돕습니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 3 characters
# 📏 향상된 길이: 488 characters
# 📈 증가율: 16166.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 200 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **SUBSCRIPTIONS** 기능은 사용자가 구독 상품을 구매하고 관리할 수 있도록 지원합니다. 이 기능을 통해 상품 정보, 구독 상태, 결제 내역 등을 확인하고 관리할 수 있습니다. 주요 API 엔드포인트와 응답 코드를 통해 성공적인 구독 처리와 오류 관리를 수행할 수 있습니다.
#
# **키워드:** SUBSCRIPTIONS, 구독 관리, API 엔드포인트, 응답 코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 200 characters
# 📏 향상된 길이: 711 characters
# 📈 증가율: 255.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 124 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchaseClient.ProductType` 인터페이스는 다양한 상품 유형을 지원하며, 이를 통해 구매 클라이언트는 다양한 제품 카테고리를 관리할 수 있습니다. 이 기능은 앱 내 구매 처리의 유연성을 높이는데 핵심적입니다. **핵심 용어:** PurchaseClient, ProductType
# **키워드:** 구매 처리, 상품 유형 지원
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 124 characters
# 📏 향상된 길이: 375 characters
# 📈 증가율: 202.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 3 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# API 문서는 원스토어 결제 시스템의 상세한 API 사용법을 설명합니다. 주요 내용은 다음과 같습니다:
#
# - **결제 요청**: 결제 요청을 위한 요청 파라미터와 서명 검증 방법 설명.
# - **결제 응답**: 결제 결과를 전달하는 두 가지 방식 (`returnUrl`, `callbackUrl`)에 대한 세부 사항 포함.
# - **응답 코드**: 결제 성공 및 실패 시의 응답 코드와 메시지 목록 제공.
#
# **대표 키워드:** 결제 API, 서명 검증, 응답 처리, 결제 결과 전달
#
# 이 요약은 문서의 핵심 내용을 간결하게 전달하여 검색 및 이해를 돕습니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 3 characters
# 📏 향상된 길이: 488 characters
# 📈 증가율: 16166.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 66 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# API 문서는 원스토어 결제 시스템을 위한 REST API와 결제 결과 처리 방법을 상세히 설명합니다. 주요 기능은 상품 상세 정보 조회(`GET /products/{productId}`), 결제 요청(`POST /payments`), 결제 결과 수신(`POST /callbackUrl`) 등이 포함되어 있습니다. 응답 코드와 메시지는 결제 상태를 명확히 전달하며, 특히 `Success`, `Fail`, `UserCancel`, `PaymentTimeExpired` 등의 코드는 다양한 결제 상황을 나타냅니다. 이 문서는 개발자가 원활한 결제 프로세스를 구현하고 관리할 수 있도록 지원합니다.
#
# **대표 키워드:** 결제 API, 상품 정보, 결제 결과 처리, 결제 상태 코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 66 characters
# 📏 향상된 길이: 718 characters
# 📈 증가율: 987.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 58 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **INAPP** 상품 타입 요약
# - **관리형 상품**: "inapp" 타입으로 표시
# - **주요 기능**: 인앱 결제 및 상품 관리 API 제공
# - **키워드**: INAPP, 상품 관리, 결제 API
#
# 이 요약은 문서 내에서 인앱 상품 관리와 관련된 핵심 정보를 간결하게 전달하며, 검색 및 통합 검색 품질 향상에 기여할 것입니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 58 characters
# 📏 향상된 길이: 525 characters
# 📈 증가율: 805.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 56 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 월정액 상품 타입은 "auto"로 정의되며, 이는 자동 결제를 의미합니다. 이 타입은 구독 모델의 핵심 기능을 나타내며, 사용자에게 정기적인 요금 청구를 제공합니다. (Keywords: auto, 구독모델)
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 56 characters
# 📏 향상된 길이: 447 characters
# 📈 증가율: 698.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 181 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# SUBS는 구독형 상품 타입을 나타내며, 주로 반복적인 결제 모델을 가진 상품을 의미합니다. 이 타입은 OneStore 플랫폼에서 구매 클라이언트의 반복 행동을 정의하는 데 사용됩니다 (출처: OneStore 개발 문서).
#
# **대표 키워드:** SUBS, 구독형 상품, 반복 결제 모델
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 181 characters
# 📏 향상된 길이: 617 characters
# 📈 증가율: 240.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 145 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchaseClient.RecurringAction`은 월정액 상품의 구독 상태를 관리하기 위한 Java 인터페이스입니다. 이 타입은 구독 관련 반복 작업을 처리하는데 사용되며, 고객의 구독 상태를 효과적으로 추적하고 관리하는 데 핵심적인 역할을 합니다. 주요 기능은 구독 시작, 갱신, 종료 등을 포함합니다.
#
# **대표 키워드:** RecurringAction, 구독 관리, 구독 상태
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 145 characters
# 📏 향상된 길이: 425 characters
# 📈 증가율: 193.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 3 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 결제 서비스 API**
#
# 이 문서는 결제 서비스를 위한 API 구조와 기능을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 요청**: 결제 요청을 위한 엔드포인트와 요청 파라미터 설명 (예: `POST /payment/initiate`).
# 2. **결제 상태 확인**: 결제 상태 확인을 위한 엔드포인트와 응답 코드 설명 (예: `GET /payment/status`).
# 3. **결제 응답 처리**: 결제 완료 후 개발사로 전달되는 응답 처리 방법 (returnUrl 및 callbackUrl 방식).
#
# **키워드**: 결제 API, 결제 요청, 결제 상태 확인, 응답 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 3 characters
# 📏 향상된 길이: 528 characters
# 📈 증가율: 17500.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 65 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문:**
#
# 월정액 상품 자동결제 관리 API 문서는 주로 결제 상태 조회, 취소, 그리고 결제 결과 처리에 초점을 맞추고 있습니다. 주요 기능으로는 `getPaymentStatus`, `cancelAutoPay`, `handlePaymentCallback` 등이 있으며, 이들은 결제 확인, 취소 요청, 그리고 결제 결과의 안전한 전달을 담당합니다. 특히 `CANCEL` 상수는 월정액 상품의 자동결제 취소를 위한 핵심 코드로 활용됩니다. 이 문서는 개발자들이 안정적이고 효율적인 결제 시스템을 구축하는 데 필요한 상세 지침을 제공합니다. **결제 자동화 API**
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 65 characters
# 📏 향상된 길이: 678 characters
# 📈 증가율: 943.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 190 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 월정액 상품의 자동결제 기능을 재개하는 명령어는 `REACTIVATE`입니다. 이 명령어는 사용자가 일시적으로 중단한 자동결제를 다시 활성화하여 월정액 서비스를 지속적으로 제공받을 수 있게 합니다. 주요 코드값은 그대로 유지되며, 이 기능은 `BillingClient` 내에서 중요한 역할을 합니다.
#
# **대표 키워드:** REACTIVATE, 자동결제 재개, BillingClient
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 190 characters
# 📏 향상된 길이: 719 characters
# 📈 증가율: 278.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 131 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# `PurchaseClient.ResponseCode` 인터페이스는 SDK 내에서 사용되는 결제 응답 코드를 정의합니다. 주요 응답 코드로는 `Success`, `Fail`, `UserCancel`, `PaymentTimeExpired` 등이 있으며, 각 코드는 결제 상태와 관련된 다양한 상황을 나타냅니다. 이 코드들은 결제 결과 처리 시 중요한 역할을 합니다. **결제응답코드**
#
# 이 요약은 문서 내에서 `PurchaseClient.ResponseCode` 관련 내용을 빠르게 파악하고 검색할 수 있도록 도와줍니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 131 characters
# 📏 향상된 길이: 479 characters
# 📈 증가율: 265.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 3 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 결제 서비스 API**
#
# 이 문서는 결제 서비스를 위한 API 구조와 기능을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 요청**: 결제 요청을 위한 엔드포인트와 요청 파라미터 설명 (주문 정보, 결제 정보 등).
# 2. **결제 응답**: 결제 결과를 전달하는 두 가지 방식 (`returnUrl`을 통한 리다이렉트, `callbackUrl`을 통한 REST API 호출) 설명.
#    - `returnUrl`: 결제 결과를 폼 데이터로 전달.
#    - `callbackUrl`: JSON 형식으로 결제 결과를 전달.
# 3. **응답 코드**: 결제 성공, 실패 등 다양한 응답 코드와 그 의미 설명.
#
# **키워드**: 결제 API, 엔드포인트, 응답 처리, 결제 결과 전달
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 3 characters
# 📏 향상된 길이: 574 characters
# 📈 증가율: 19033.3%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 46 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# API 문서는 원스토어 결제 시스템의 REST API를 설명하며, 주요 기능은 구독 결제 및 결제 결과 처리입니다. 주요 요소로는 구독 결제 요청(`POST /subscriptions`), 결제 상태 조회(`GET /payments/{paymentId}`), 결제 결과 수신(`POST /callbackUrl`) 등이 포함됩니다. 응답 코드와 메시지는 성공, 실패, 사용자 취소 등 다양한 상황을 구분하며, 결제 결과는 `orderId`, `purchaseId`, `purchaseToken`, `purchaseTime`, `developerPayload`, `quantity`, `purchaseSignature`, `billingKey` 등의 파라미터를 통해 전달됩니다. 핵심 키워드: 구독 결제, 결제 처리, API 응답 코드.
#
# **대표 키워드:** 구독 결제 API, 결제 결과 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 46 characters
# 📏 향상된 길이: 786 characters
# 📈 증가율: 1608.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 60 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문:**
#
# 결제 프로세스에서 사용자 취소(USER_CANCELED) 시 결제가 취소되었음을 나타냅니다. 이 코드는 결제 과정 중 사용자의 취소 행위를 명확히 식별하며, 개발사는 이를 통해 취소된 결제 건을 효과적으로 관리할 수 있습니다. 키워드: 결제취소, USER_CANCELED
#
# **참고 키워드:** 결제취소, API 응답코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 60 characters
# 📏 향상된 길이: 549 characters
# 📈 증가율: 815.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 87 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **RESULT_SERVICE_UNAVAILABLE (2)**: 단말 또는 서버 네트워크 오류로 인해 서비스가 일시적으로 이용 불가능한 상태입니다. 이 오류는 네트워크 연결 문제를 나타냅니다.
#
# **키워드**: 네트워크 오류, 서비스 이용 불가능
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 87 characters
# 📏 향상된 길이: 573 characters
# 📈 증가율: 558.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 83 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문:**
#
# 구매 처리 중 오류 발생 시 상수 값 `RESULT_BILLING_UNAVAILABLE` (코드값: 3)이 사용됩니다. 이는 결제 시스템 이용 불가능을 나타내며, 개발사는 이 코드를 통해 오류 처리를 진행할 수 있습니다. 키워드: 구매오류, RESULT_BILLING_UNAVAILABLE
#
# **목적:** 구매 처리 과정에서 발생하는 결제 시스템 관련 오류를 명확하게 식별하고 관리할 수 있도록 지원합니다. 키워드: 결제오류처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 83 characters
# 📏 향상된 길이: 672 characters
# 📈 증가율: 709.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 87 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문:**
#
# **RESULT_ITEM_UNAVAILABLE (코드값: 4)**
# 해당 상품은 현재 판매 중이 아니거나 구매가 불가능한 상태입니다. 이 상태는 상품의 가용성 문제를 나타내며, 개발 및 운영 팀에서 즉시 확인이 필요합니다. 키워드: 상품 가용성, 구매 불가능
#
# 이 요약문은 문서 내에서 상품 상태 관련 정보를 빠르게 파악하고 문제 해결을 돕기 위해 사용될 수 있습니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 87 characters
# 📏 향상된 길이: 635 characters
# 📈 증가율: 629.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 71 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# API 문서는 원스토어 결제 API의 상세 내용을 다룹니다. 주요 기능은 구독 상품 관리, 결제 요청 및 응답 처리입니다. 구독 상품은 `POST /subscriptions`를 통해 생성되며, `GET /subscriptions/{subscriptionId}`로 조회 가능합니다. 결제 요청은 `POST /payments`로 이루어지며, 응답은 `callbackUrl`을 통해 JSON 형태로 결제 결과를 전달합니다. 응답 코드는 `Success`, `Fail`, `UserCancel`, `PaymentTimeExpired` 등이 있으며, 각 코드에 따른 메시지가 명시되어 있습니다. 이 문서는 개발자가 결제 시스템을 통합하고 관리하는 데 필요한 핵심 정보를 제공합니다.
#
# **키워드:** 결제 API, 구독 관리, 결제 요청, 응답 처리, 결제 결과 전달
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 71 characters
# 📏 향상된 길이: 832 characters
# 📈 증가율: 1071.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 70 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# API 문서는 주로 게임 개발사와 결제 게이트웨이(PG) 간의 상호작용을 위한 REST API 세부 사항을 다룹니다. 주요 내용은 다음과 같습니다:
#
# - **결제 요청 및 응답 구조**: 결제 요청 시 필요한 파라미터와 응답 코드, 메시지 설명을 포함합니다.
# - **결제 결과 전달**: `returnUrl` (리다이렉트 페이지)와 `callbackUrl` (REST API)을 통해 결제 결과를 개발사로 전달합니다.
# - **보안 요소**: 결제 요청 시 서명 검증을 위한 `purchaseSignature`와 자동 결제 승인을 위한 `billingKey`를 포함합니다.
# - **오류 코드**: 다양한 오류 상황에 대한 응답 코드와 설명을 제공합니다 (예: Success, Fail, UserCancel, PaymentTimeExpired).
#
# **대표 키워드**: 결제 API, 서명 검증, 자동 결제, 오류 처리
#
# 이 요약은 문서의 핵심 내용을 간결하게 전달하여 검색 및 이해를 돕습니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 70 characters
# 📏 향상된 길이: 875 characters
# 📈 증가율: 1150.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 78 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문:**
#
# **RESULT_ITEM_ALREADY_OWNED (7)**: 이미 아이템 소유 상태를 나타냄. 이 코드는 사용자가 이미 해당 아이템을 보유하고 있음을 확인하는 데 사용됩니다. 문서는 결제 및 아이템 소유 상태 확인과 관련된 다양한 응답 코드와 메시지를 다루고 있으며, 특히 결제 성공 및 실패 상황에 대한 상세한 설명을 포함하고 있습니다. 키워드: 결제 상태 확인, 아이템 소유 확인
#
# **참고 키워드:** 결제 응답 코드, 아이템 소유 확인
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 78 characters
# 📏 향상된 길이: 674 characters
# 📈 증가율: 764.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 83 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문:**
#
# **API_ERR**
# - **요청**: 게임 아이템 구매 및 결제 API 요청
# - **응답**: 구매 결과 전달 (성공/실패 코드, 주문 ID, 구매 토큰, 구매 시간, 개발자 페이로드, 수량, 구매 서명, 빌링 키 포함)
# - **주요 코드**:
#   - `Success`: 결제 성공
#   - `Fail`: 결제 실패 (오류 설명 포함)
#   - `UserCancel`: 사용자 취소
#   - `PaymentTimeExpired`: 결제 시간 만료
# - **키워드**: 구매결과, 결제API, 응답코드
#
# 이 요약문은 API 요청과 응답의 핵심 내용을 간결하게 담아 게임 결제 시스템의 주요 동작을 이해하는 데 도움을 줍니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 83 characters
# 📏 향상된 길이: 767 characters
# 📈 증가율: 824.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 89 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문:**
#
# 결제 프로세스에서 `RESULT_FAIL` 코드는 결제 실패를 나타냅니다 (코드 값: 9). 사용자는 결제 가능 여부와 결제 수단을 확인한 후 다시 결제를 시도해야 합니다. 이 오류는 결제 시스템의 문제 또는 사용자의 취소로 인해 발생할 수 있습니다. 키워드: 결제실패, RESULT_FAIL, 재결제 필요
#
# **대표 용어:** RESULT_FAIL, 결제오류
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 89 characters
# 📏 향상된 길이: 594 characters
# 📈 증가율: 567.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 70 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문:**
#
# **API_V7_Payment**
# 스토어 앱 로그인 필요 (RESULT_NEED_LOGIN: 10). 결제 관련 API 문서로, 결제 요청, 응답 처리 및 보안 관련 서명 정보 포함. 주요 응답 코드: Success, Fail, UserCancel, PaymentTimeExpired. 결제 결과 전달 방식: returnUrl(Redirect Page), callbackUrl(REST API).
# **키워드:** 결제 API, 로그인 필요, 응답 처리, 서명 검증
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 70 characters
# 📏 향상된 길이: 656 characters
# 📈 증가율: 837.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 73 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 결제 모듈 업데이트 필요 (Constant Value: 11). 결제 API는 주문 정보, 결제 상태, 개발자 페이로드 등을 포함한 응답 코드와 메시지를 통해 결제 결과를 전달합니다. 성공 시 빈 응답 메시지를 반환하며, 실패 시 구체적인 오류 설명을 제공합니다. 주요 응답 코드로는 'Success', 'Fail', 'UserCancel', 'PaymentTimeExpired' 등이 있습니다. 결제 처리 과정에서 chunk 처리를 통해 효율적인 데이터 관리를 지원합니다.
#
# **키워드:** 결제 모듈 업데이트, 결제 API 응답 코드, 효율적인 데이터 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 73 characters
# 📏 향상된 길이: 711 characters
# ...
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 951 characters
# 📏 향상된 길이: 1,538 characters
# 📈 증가율: 61.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,379 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 호출 요약 (API_CALL)**
#
# - **요청 파라미터:** `clientId`, `purchaseToken` (필수), `developerPayload` (선택)
# - **헤더 정보:** `Authorization` (사용자 액세스 토큰), `x-market-code` (마켓 구분 코드, MKT_ONE 또는 MKT_GLB)
# - **목적:** 앱 내 구매 처리를 위한 API 호출, 구매 토큰을 통해 구매 내역 관리 및 소비 처리
#
# **주요 키워드:** API 호출, 구매 토큰, 마켓 구분, 소비 처리
#
# 이 요약은 API 호출의 핵심 요소와 목적을 간결하게 전달하며, 검색 및 통합 품질 향상에 기여할 것입니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,379 characters
# 📏 향상된 길이: 1,909 characters
# 📈 증가율: 38.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 690 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 결제 및 구독 관리 API**
#
# 이 문서는 결제 및 구독 관리를 위한 REST API의 상세 설명을 담고 있습니다. 주요 기능은 구독 상품 관리, 구독 상태 변경, 결제 처리, 그리고 결제 결과 확인입니다. 각 엔드포인트는 구독 생성, 수정, 삭제, 결제 확인, 환불 요청 등을 지원하며, 응답 코드와 메시지를 통해 처리 결과를 명확히 전달합니다. 주요 응답 코드로는 `Success`, `Fail`, `UserCancel`, `PaymentTimeExpired` 등이 있습니다.
#
# **키워드:** 결제 API, 구독 관리, 응답 코드, 결제 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 690 characters
# 📏 향상된 길이: 1,187 characters
# 📈 증가율: 72.0%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 967 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 명세 요약:**
#
# - **API 경로:** 구매 확인 API (상용: `https://pcapis.onestore.net/pc/v7/apps/{clientId}/purchases/all/{purchaseToken}/acknowledge`, 개발: `https://sbpp.onestore.net/pc/v7/apps/{clientId}/purchases/all/{purchaseToken}/acknowledge`)
# - **목적:** 구매한 인앱 상품의 구매 확인 상태 변경 (소멸성 상품, 월정액 상품 지원)
# - **응답 코드:** 표준 응답코드 참조
# - **주요 용어:** Purchase Acknowledge
#
# **대표 키워드:** Purchase Acknowledge, API 구매 확인
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 967 characters
# 📏 향상된 길이: 1,462 characters
# 📈 증가율: 51.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,388 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요청 요약 (API_V7)**
#
# - **요청 목적:** 앱 구매 내역 확인 및 승인
# - **주요 파라미터:**
#   - `clientId`: 앱 클라이언트 ID (필수)
#   - `purchaseToken`: 구매 토큰 (필수)
#   - `developerPayload`: 개발자 식별자 (선택)
# - **헤더 정보:**
#   - `Authorization`: 사용자 액세스 토큰 (필수)
#   - `x-market-code`: 마켓 코드 (선택, MKT_ONE/MKT_GLB)
# - **응답 예시:** 구매 내역 확인 결과 및 승인 상태 반환
#
# **키워드:** API_V7, 구매내역, 승인, 클라이언트ID, 구매토큰
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,388 characters
# 📏 향상된 길이: 1,834 characters
# 📈 증가율: 32.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 689 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 결제 및 구독 관리 API**
#
# 이 문서는 결제 및 구독 관리를 위한 REST API의 상세 설명을 담고 있습니다. 주요 기능은 구독 상품 관리, 구독 상태 변경, 결제 처리, 그리고 결제 결과 확인입니다. 각 API 엔드포인트는 HTTP 메소드와 함께 사용되며, 요청 및 응답 데이터 포맷은 JSON 형식을 따릅니다. 성공 응답은 `result` 객체 내 `code`와 `message`로 구성되며, 실패 시 `error` 객체를 통해 오류 코드와 메시지를 제공합니다. 주요 응답 코드로는 `Success`, `AlreadyPurchased`, `PaymentTimeExpired` 등이 있습니다.
#
# **키워드:** 결제 API, 구독 관리, REST 엔드포인트
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 689 characters
# 📏 향상된 길이: 1,172 characters
# 📈 증가율: 70.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 943 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 월정액 자동결제 상품의 다음 자동결제를 취소 예약할 수 있는 API 엔드포인트입니다. 상용 및 개발 환경에 따라 다른 URL을 사용하며, 이 엔드포인트를 통해 구매 토큰 기반의 해지 예약을 처리할 수 있습니다. 주요 응답 코드는 표준 응답코드를 따릅니다.
#
# **대표 키워드:** API 엔드포인트, 자동결제 취소 예약, 구매 토큰
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 943 characters
# 📏 향상된 길이: 1,333 characters
# 📈 증가율: 41.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,077 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 호출 요약 (API_CANCEL)**
#
# - **목적:** 앱 구매 내역 자동 처리 취소 요청
# - **필수 파라미터:** `clientId`, `purchaseToken`
# - **헤더 파라미터:** `Authorization` (User Access Token), `x-market-code` (마켓 구분 코드)
# - **요청 예시:** 취소 요청을 위한 POST 요청은 클라이언트 ID와 구매 토큰을 포함하며, 마켓 코드와 인증 토큰을 헤더로 전달합니다.
#
# **대표 키워드:** API_CANCEL, 구매취소, 자동처리, 인증토큰
#
# 이 요약은 API 취소 요청의 핵심 요소를 간결하게 전달하며, 검색 및 통합 품질 향상에 기여할 것입니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,077 characters
# 📏 향상된 길이: 1,643 characters
# 📈 증가율: 52.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 645 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 구독 관리 및 결제 API**
#
# - **구독 관리 API**: 사용자 구독 정보 조회, 수정, 해지 기능 제공 (`/subscriptions`, `/subscription`)
# - **결제 API**: 결제 정보 생성, 확인, 처리 (`/payments`, `/payment-methods`)
#
# **주요 응답 코드:**
# - `Success`: 정상 처리 완료
# - `Fail`: 시스템 오류 또는 결제 실패
# - `UserCancel`: 사용자 취소
# - `PaymentTimeExpired`: 결제 시간 초과
#
# **키워드:** 구독, 결제, API 응답코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 645 characters
# 📏 향상된 길이: 1,168 characters
# 📈 증가율: 81.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,037 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 이름:** Reactivate Auto Purchase
# **기능 요약:**
# 월정액 자동결제 상품의 취소 예약을 취소하여 다음 자동결제를 재개합니다. 이 API는 상품 상태가 취소 예약 상태일 때만 작동합니다.
# **키워드:** Reactivate, Auto Purchase, Cancel Reservation
#
# 이 기능을 통해 사용자는 취소 예약된 월정액 상품의 자동결제를 재시작할 수 있습니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,037 characters
# 📏 향상된 길이: 1,487 characters
# 📈 증가율: 43.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,081 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약:** `reactivate` 엔드포인트는 구매 내역의 재활성화를 요청하는 API로, `clientId`, `purchaseToken` 등의 파라미터를 통해 앱 클라이언트 정보와 구매 토큰을 전달합니다. 요청은 `Authorization` 토큰과 `x-market-code` 마켓 코드를 포함한 헤더로 보호됩니다. 이 API는 주로 구매 내역의 상태를 변경하거나 재개하는데 사용되며, 원스토어 마켓 코드에 따라 대한민국 또는 글로벌 시장에 대한 요청을 처리합니다.
#
# **대표 용어:** `reactivate`, `purchaseToken`
#
# **키워드:** 구매 재활성화, 토큰 기반 인증, 마켓 코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,081 characters
# 📏 향상된 길이: 1,641 characters
# 📈 증가율: 51.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 645 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 구독 관리 API**
#
# - **요청 응답 구조**: `result` 객체 내 `code`와 `message`로 응답 상태 확인 가능.
# - **주요 기능**:
#   - 구독 정보 조회 (`/subscriptions/{subscriptionId}`)
#   - 구독 상태 업데이트 (`/subscriptions/{subscriptionId}/status`)
#   - 구독 플랜 변경 (`/subscriptions/{subscriptionId}/changePlan`)
#   - 구독 일시 중지/해제 (`/subscriptions/{subscriptionId}/pause`, `/subscriptions/{subscriptionId}/unpause`)
#   - 구독 취소 (`/subscriptions/{subscriptionId}`)
#
# **키워드**: 구독 관리, API 엔드포인트, 상태 업데이트, 플랜 변경, 일시 중지, 취소
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 645 characters
# 📏 향상된 길이: 1,327 characters
# 📈 증가율: 105.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 965 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **구독 취소 API**
# - **Path:**
#   - 상용: `https://pcapis.onestore.net/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}/cancel`
#   - 개발: `https://sbpp.onestore.net/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}/cancel`
# - **기능:** 구독형 상품의 다음 자동결제를 취소 예약합니다.
# - **응답코드:** 표준 응답코드 참조
# - **주요 키워드:** 구독취소, 예약해지, API, 구매토큰
#
# 이 요약은 API 엔드포인트를 통해 구독 상품의 자동결제를 취소 예약하는 기능을 간결하게 전달하며, 관련 코드값과 주요 키워드를 포함하여 검색 효율성을 높입니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 965 characters
# 📏 향상된 길이: 1,591 characters
# 📈 증가율: 64.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,085 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 호출 요약 (API_V7)**
#
# - **목적**: 앱 구매 구독 관리 및 취소 요청
# - **주요 파라미터**: `clientId`, `purchaseToken`
# - **필수 헤더**: `Authorization` (User Access Token), `x-market-code` (마켓 구분 코드)
# - **엔드포인트 예시**: `POST /pc/v7/apps/{앱ID}/purchases/subscription/{구매ID}/cancel`
# - **대표 용어**: API_V7, 구매취소
#
# **키워드**: API_V7, 구매취소, 구독관리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,085 characters
# 📏 향상된 길이: 1,579 characters
# 📈 증가율: 45.5%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 642 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 구독 관리 API**
#
# 이 문서는 구독 관리와 관련된 REST API의 상세 구조와 동작 방식을 설명합니다. 주요 요소로는 구독 생성, 업데이트, 삭제(CRUD), 사용자 관리, 결제 정보 처리 등이 포함되어 있습니다. 각 요청은 HTTP 메소드와 함께 사용되며, 응답은 JSON 형식으로 제공됩니다. 특히 결제 관련 API는 보안과 인증을 강조하며, 결제 상태 확인과 구독 변경을 위한 엔드포인트를 제공합니다.
#
# **키워드:** 구독 관리, REST API, CRUD, 결제 처리
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 642 characters
# 📏 향상된 길이: 1,111 characters
# 📈 증가율: 73.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 987 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **Reactivate API**
# - **Path:** (상용) [https://pcapis.onestore.net/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}/reactivate](https://pcapis.onestore.net/pc/v7/apps/%7BclientId%%7D/purchases/subscription/%7BpurchaseToken%%7D/reactivate), 개발 [https://sbpp.onestore.net/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}/reactivate](https://sbpp.onestore.net/pc/v7/apps/%7BclientId%%7D/purchases/subscription/%7BpurchaseToken%%7D/reactivate)]
# - **기능:** 구독형 상품의 자동결제 취소 예약을 취소합니다.
# - **주요 코드:** HTTPS, POST
# - **키워드:** Reactivate, 구독, 자동결제 취소
#
# 이 요약은 API의 주요 기능과 경로를 간결하게 전달하며, 검색 및 통합 검색 품질 향상에 도움을 줍니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 987 characters
# 📏 향상된 길이: 1,814 characters
# 📈 증가율: 83.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,084 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약:** `reactivate` 엔드포인트는 특정 구독 항목의 재활성화를 요청하는 API입니다. 이 요청은 `clientId`, `purchaseToken` 등의 파라미터와 함께 `Authorization` 토큰 및 `x-market-code` 헤더를 통해 인증 및 마켓 구분을 수행합니다. 주로 앱 내에서 사용자의 구독 상태를 재시작하거나 재개하는데 사용됩니다.
#
# **주요 키워드:** reactivate, subscription, purchaseToken, Authorization, x-market-code
#
# 이 요약은 API 호출의 핵심 요소와 목적을 간결하게 전달하며, 검색 및 통합 검색 품질 향상에 기여할 것입니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,084 characters
# 📏 향상된 길이: 1,645 characters
# 📈 증가율: 51.8%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 642 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 구독 관리 API**
#
# 이 문서는 구독 관리와 관련된 REST API의 상세 구조와 동작 방식을 설명합니다. 주요 기능은 사용자 구독 상태 확인, 구독 변경 요청, 구독 취소 및 재구독 처리 등이 포함됩니다. 각 요청은 HTTP 메소드와 함께 사용되며, 응답은 JSON 형식으로 제공됩니다. 성공 응답은 `code`와 `message`를 포함하고, 실패 시는 `error` 코드와 설명 메시지를 반환합니다. 주요 응답 코드로는 `Success`, `NoSuchData`, `InvalidRequest` 등이 있습니다.
#
# **키워드:** 구독 관리, REST API, 구독 상태, 구독 변경, 응답 코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 642 characters
# 📏 향상된 길이: 1,192 characters
# 📈 증가율: 85.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 921 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 명세 요약:**
#
# - **API 경로:** 구독 정보 조회 API는 상용 환경에서는 `https://pcapis.onestore.net/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}`, 개발 환경에서는 `https://sbpp.onestore.net/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}` 에서 접근 가능하다.
# - **기능:** 구독 상세 정보 조회 및 오류 코드 확인
# - **주요 응답 코드:** Success, Fail, UserCancel, PaymentTimeExpired
# - **키워드:** 구독 조회, API 경로, 응답 코드
#
# 이 요약은 API 경로, 주요 기능, 그리고 주요 응답 코드를 포함하여 문서의 핵심 내용을 간결하게 전달합니다.
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 921 characters
# 📏 향상된 길이: 1,568 characters
# 📈 증가율: 70.2%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 1,077 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 엔드포인트 요약:**
# - **Endpoint:** `/pc/v7/apps/{clientId}/purchases/subscription/{purchaseToken}`
# - **기능명:** 구독 구매 정보 조회 및 관리 API
# - **주요 파라미터:**
#   - `clientId`: 앱 클라이언트 ID (필수)
#   - `purchaseToken`: 구매 토큰 (필수)
# - **헤더 파라미터:**
#   - `Authorization`: 사용자 액세스 토큰 (필수)
#   - `x-market-code`: 마켓 코드 (선택, MKT_ONE/MKT_GLB)
#
# **주요 내용:**
# 이 API는 특정 앱 클라이언트 ID와 구매 토큰을 기반으로 구독 구매 정보를 조회하고 관리하는 데 사용됩니다. 사용자 액세스 토큰 인증이 필요하며, 마켓 코드는 선택적으로 지정할 수 있습니다. 이 엔드포인트는 구독 관련 데이터의 정확한 접근과 업데이트를 지원합니다.
#
# **키워드:** 구독 API, 구매 관리, 토큰 인증
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 1,077 characters
# 📏 향상된 길이: 1,783 characters
# 📈 증가율: 65.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 5,777 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약문**
#
# 결제 및 구독 정보 API 문서는 결제 결과와 구독 상태를 상세히 제공합니다. 주요 필드로는 `result` 내의 성공/실패 코드와 메시지, `subscription` 내의 구독 상품 정보(`productId`, `productName`, `productAmount`, `status`, `purchaseToken` 등), 구독 기간(`startDate`, `expiryDate`), 결제 금액 및 일정 등이 포함됩니다. 또한 가격 변동 정보(`priceChanges`)를 통해 사용자에게 제공되는 프로모션 및 가격 변경 사항을 확인할 수 있습니다.
#
# **키워드**: 결제결과, 구독상태, 구독상품정보, 가격변동정보
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 5,777 characters
# 📏 향상된 길이: 6,322 characters
# 📈 증가율: 9.4%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 90 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# ONE 결제 요청 시, `paymentUrl`을 통해 `paymentParam`을 전달하여 ONE Store 표준 결제 화면을 활성화합니다. 결제 완료 시 개발사로 `returnUrl` 또는 `callbackUrl`을 통해 결제 결과를 JSON 형태로 전달합니다. 주요 응답 코드로는 `Success`, `Fail`, `UserCancel`, `PaymentTimeExpired` 등이 있습니다.
#
# **대표 키워드:** ONE 결제, paymentUrl, callbackUrl, 결제결과
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 90 characters
# 📏 향상된 길이: 478 characters
# 📈 증가율: 431.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 623 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# **API 요약: 결제 처리**
#
# - **결제 처리 API**는 HTTPS를 통해 결제 요청을 처리합니다.
# - **paymentUrl** 경로를 통해 웹 표준 결제 화면을 호출합니다.
# - **paymentParam**: 결제 요청 데이터를 전달하는 필수 매개변수입니다.
# - **결제 결과**는 **returnUrl** (폼 데이터 제출 형태) 또는 **callbackUrl** (JSON 형태)을 통해 개발자에게 전달됩니다.
# - **callbackUrl** 데이터는 실제 결제 연동 후 최종 결과만 전달됩니다.
# - **응답 코드**: Success, Fail, UserCancel, PaymentTimeExpired 등 다양한 상태를 나타냅니다.
#
# **키워드**: 결제 처리, HTTPS, paymentUrl, callbackUrl, 응답 코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 623 characters
# 📏 향상된 길이: 1,175 characters
# 📈 증가율: 88.6%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 423 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 원스토어 결제 프로세스에서 표준 브라우저 크기는 width=400, height=580로 최적화되어 있으며, 이 크기를 벗어나면 결제 화면이 제대로 작동하지 않을 수 있습니다. 결제 화면을 새 창에서 호출할 때는 아래 코드 예시를 참고하세요:
#
# ```javascript
# window.open('paymentUrl', 'pp01', 'width=400, height=580, left=((window.screen.width / 2) - (400 / 2)), top=((window.screen.height / 2) - (580 / 2)), status=no, menubar=no, toolbar=no, sizable=no');
# ```
#
# **핵심 용어:** 결제 화면 크기 최적화, 결제 호출 코드
#
# **키워드:** 결제 화면, 브라우저 크기, 호출 코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 423 characters
# 📏 향상된 길이: 981 characters
# 📈 증가율: 131.9%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 26 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 결제결과 전달: 개발사는 표준 결제화면을 통해 결제성공 여부와 필요 정보(orderId, purchaseId, purchaseToken 등)를 JSON 형태의 callbackUrl 또는 form 데이터로 받습니다. 응답코드는 Success 또는 오류 코드로 결제 상태를 나타냅니다.
#
# **대표 키워드:** 결제결과, callbackUrl, 응답코드, 표준결제화면
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 26 characters
# 📏 향상된 길이: 344 characters
# 📈 증가율: 1223.1%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 6,179 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 결제 API 문서는 결제 요청 및 응답 처리 방법을 상세히 설명합니다. 주요 기능은 상품 정보 요청(`getProductInfo`), 결제 요청(`requestPayment`), 결제 상태 조회(`getPaymentStatus`) 등이 포함되어 있습니다. 응답 처리는 `callbackUrl` (폼 데이터 전송)과 `callbackUrl` (JSON 데이터 전송) 두 가지 방식을 지원하며, 각 응답에는 `responseCode`, `responseMessage`, `purchaseSignature`, `billingKey` 등의 필수 파라미터가 포함됩니다. 결제 실패 시 다양한 오류 코드와 메시지를 제공하여 문제 해결을 돕습니다.
#
# **키워드:** 결제 API, 상품 정보, 결제 요청, 응답 처리, 오류 코드
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 6,179 characters
# 📏 향상된 길이: 6,715 characters
# 📈 증가율: 8.7%
#
# 🔍 컨텍스트 정보 생성 시작...
# 📊 청크 길이: 485 characters
# ==================================================
# ✅ 생성된 컨텍스트:
# **요약:**
#
# 결제 API 응답 코드 요약:
# - **Success**: 결제 성공 (빈 메시지)
# - **Fail**: 시스템 오류 설명 참조
# - **UserCancel**: 사용자 취소 (결제 취소됨)
# - **PaymentTimeExpired**: 결제 시간 초과 (10분 경과)
#
# **대표 키워드:** 결제응답코드 요약, 결제결과 확인
# ==================================================
# ✅ 향상된 Document 생성 완료!
# 📏 원본 길이: 485 characters
# 📏 향상된 길이: 792 characters
# 📈 증가율: 63.3%
# 마크다운 문서 분할 완료: 495개 청크

# %%
# fixed_model_name = "deepseek-coder:6.7b"
# fixed_model_name = "exaone3.5:latest"
# fixed_model_name = "mistral:latest"
# fixed_model_name = "llama3:8b"
fixed_model_name = "bge-m3:latest"    
# fixed_model_name = "solar:latest"

def embed_and_save(docs: List[Document], output_path: str):
    """문서를 임베딩하고 FAISS 데이터베이스로 저장합니다."""
    # 임베딩 모델 초기화
    embedding_model = OllamaEmbeddings(model=fixed_model_name)
    
    # FAISS 데이터베이스 생성 및 저장
    db = FAISS.from_documents(docs, embedding_model)
    db.save_local(output_path)
    print(f"✅ 임베딩 저장 완료: {output_path}")

# 모든 문서 통합
total_docs = docs_markdown #+ docs_kotlin
print(f"총 {len(total_docs)}개의 문서를 생성하였습니다.")
print(f"- 마크다운 문서: {len(docs_markdown)}개")
#print(f"- Kotlin 코드: {len(docs_kotlin)}개")

# 임베딩 생성 및 저장
output_dir = "models/faiss_vs_rag_iap_v11_cr_" + fixed_model_name[:3]
os.makedirs(output_dir, exist_ok=True)
# embed_and_save(total_docs, output_dir)
# Out:
# 총 495개의 문서를 생성하였습니다.
# - 마크다운 문서: 495개
# ✅ 임베딩 저장 완료: models/faiss_vs_rag_iap_v11_cr_bge

# %%
# docs_markdown에서 'launchPurchaseFlow()' 문자열을 포함하는 Documnet 를 출력

cnt = 0
for doc in docs_markdown:
    if 'PNS' in doc.page_content:
        # print(f"문서 제목: {doc.metadata.get('title', '제목 없음')}")
        print(f"--- doc_index: {cnt} ---")
        print(f"{doc.page_content}[EOD]")  # 처음 200자만 출력
        # print("-" * 40)  # 구분선 
        cnt += 1
        
print(f"'PNS' 문자열을 포함하는 문서 개수: {cnt}")
# Out:
# --- doc_index: 0 ---
# [제목]: 원스토어 인앱결제 API V7(SDK V21) 연동 안내 및 다운로드
#
# [요약]: **요약:**
#
# 원스토어 인앱결제 API V7(SDK V21)은 최신 기능과 강력한 보안을 제공하며, 이전 버전(V4 이하)과 호환되지 않습니다. 주요 기능은 결제 테스트, 서버 API 활용, 정기 결제 구현 등이 포함됩니다. 이 버전은 앱 배포 시 대한민국 외 지역 가이드도 함께 제공됩니다. **API V7**, **결제 구현**, **서버 API**, **앱 배포 가이드**
#
# [원문]: 원스토어의 최신 인앱결제 API V7(SDK V21)이 출시되었습니다.
# 보다 강력하고 다양한 기능을 지원하는 최신 버전을 적용해보세요.
# {% hint style="info" %}
# API V4(SDK V16) 이하 버전과는 호환되지 않습니다. 인앱결제 API V4(SDK V16)에 대한 안내 및 다운로드는 [여기](old-version/v16)를 클릭해주세요.
# {% endhint %}
# {% hint style="info" %}
# 현재 판매중인 앱을 대한민국 외 국가/지역으로 배포하기 위해서는 아래 가이드를 참고해주세요
# * [대한민국 외 국가 및 지역 배포를 위한 가이드](../glb)
# {% endhint %}
# If you are comfortable with English, please change the language to English from the upper left side in this page.
# * [01. 원스토어 인앱결제 개요](v21/ov)
# * [02. 원스토어 인앱결제 적용을 위한 사전준비](v21/pre)
# * [03. 결제 테스트 및 보안](v21/test)
# * [04. 원스토어 인앱결제 SDK를 사용해 구현하기](v21/sdk)
# * [05. 원스토어 인앱결제 레퍼런스](v21/references)
# * [06. 원스토어 인앱결제 서버 API (API V7)](v21/serverapi)
# * [07. PNS(Payment Notification Service) 이용하기](v21/pns)
# * [08. 정기 결제 적용하기](v21/subs)
# * [09. 원스토어 인앱결제 릴리즈 노트](v21/releasenote)
# * [10. Sample App Download](v21/sample)
# * [11. V21로 원스토어 인앱결제 업그레이드 하기](v21/upgrade)
# * [12. Unity에서 원스토어 인앱결제 (SDK V21) 사용하기](v21/unity)
# * [13. Unity에서 IAP SDK v21로 업그레이드 하기](v21/unitymig)
# * [14. Flutter에서 원스토어 인앱결제 사용하기](v21/flutter)
# * [15. 웹 결제 규격 적용하기](v21/web-payment)
# \
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/ov.md[EOD]
# --- doc_index: 1 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **개요**
#
# [요약]: **요약:**
#
# PNS (Payment Notification Service)는 네트워크 불안정성을 보완하기 위해 원스토어가 개발사 서버로 결제 상태(완료, 취소)를 전송하는 서버 간 통신 시스템입니다. 이 시스템은 인앱 결제 및 구독 상태 변경 시 알림을 보내며, 테스트 결제 건도 포함됩니다. 개발사는 이 알림을 통해 결제 트랜잭션 상태를 확인할 수 있지만, 실제 서비스 제공은 알림 수신보다는 직접 API 조회를 권장합니다. 주요 키워드: PNS, 결제 알림, 서버 간 통신, 구독 상태 변경
#
# **대표 키워드:** PNS, 결제 알림 서비스
#
# [원문]: PNS는 Payment Notification Service의 약자입니다. PNS는 모바일의 네트워크 연결 불안정성을 보완하기 위해 개발사가 지정한 서버로 원스토어의 서버가 개별 사용자의 결제 상태(결제 완료, 결제 취소)를 메시지로 전송하여 결제 트랜젝션의 상태를 손실없이 알려주기 위한 용도의 기능입니다. 즉, 개발사가 지정한 서버에서 원스토어가 정의한 규칙에 맞추어 API를 구현하면 해당 API를 원스토어의 결제 담당 서버에서 호출하는 형태입니다.
# Server to Server, 즉 서버간에 데이터를 전송한다고 할지라도 네트워크 문제로 메세지 전송 실패가 발생하기 때문에 200 OK로 응답을 인지하지 못할 경우 반복하여 메시지가 전송될 수 있습니다. 개발사의 서버는 메시지를 수신후 정의된 응답을 하여야 원스토어는 개발사 서버가 정상적으로 메시지를 전달 받았음을 인지합니다.
# 결제 트렌젝션의 유형에 따라 아래와 같은 유형의 메세지가 전송됩니다.
# * 인앱상품 결제 또는 결제취소가 발생하면 원스토어가 개발사 서버로 알림을 전송하는 PNS(Payment Notification Service)&#x20;
# * 구독 상태가 변경되면 개발사 서버로 알림을 전송하는 SNS (Subscription Notifacation Service)&#x20;
# {% hint style="warning" %}
# Notification은 발송/수신 서버의 상태에 따라 지연 또는 유실될 수 있으므로, notification 수신을 기준으로 상품(서비스)을 제공하는 것은 권장하지 않습니다.&#x20;
# 정상적인 결제 건인지 Server to Server로 확인하기를 원하신다면 PNS notification을 이용하는 대신, 관련 서버 API로 조회하는 것을 권장합니다.
# 원스토어는 검증 및 모니터링 목적으로 결제 테스트를 진행할 수 있으며, 해당 테스트 건들도 결제/결제취소 시 동일하게 notification이 발송됩니다. 원스토어가 진행한 결제 테스트 내역은 주기적으로 원스토어에서 자체 취소 처리합니다.
# {% endhint %}[EOD]
# --- doc_index: 2 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 수신 서버 URL 설정**
#
# [요약]: **요약:**
#
# 개발사 서버의 PNS 수신 URL은 '개발자센터 > Apps > 상품 선택 > In-App정보'에서 설정 가능합니다. Sandbox와 상용 환경을 각각 구분하여 설정할 수 있으며, 개발용과 상용 환경이 동일한 경우 동일 URL 사용 가능합니다. 이 설정은 결제 결과의 정확한 전달을 위해 중요합니다.
#
# **대표 키워드:** PNS 설정, 결제 결과 전달, 개발자센터
#
# [원문]: PNS를 수신 받을 개발사 서버의 URL은 '개발자센터 > Apps > 상품 선택 > In-App정보' 메뉴에서 'PNS 관리' 버튼을 클릭하면 설정할 수 있습니다.\
# URL은 Sandbox(개발용) 결제환경 및 상용(상용테스트 포함) 결제환경을 각각 설정할 수 있으며, 개발용/상용 서버가 동일할 경우 동일한 URL을 입력하시면 됩니다.[EOD]
# --- doc_index: 3 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세**
#
# [요약]: **요약:**
#
# PNS 3.1.0 버전 업데이트로 인해 `packageName` 파라미터가 `clientId`로 변경되었습니다. 주요 내용은 다음과 같습니다:
#
# - **API 버전**: PNS 3.1.0
# - **변경 사항**: `packageName` → `clientId` (3.0.0 이하 버전은 변경 없음)
# - **주요 기능**: 개발자 센터 개편에 따른 API 변경 사항 안내
#
# **키워드**: PNS, API 업데이트, clientId, 개발자센터 개편
#
# [원문]: {% hint style="info" %}
# 2025년 3월 20일 개발자센터 개편의 영향으로 PNS 3.1.0 버전이 추가 되었습니다.&#x20;
# * &#x20;packageName 파라미터가 clientId로 변경 되었으며, 3.0.0 이하 버전에서는 변경 사항이 없습니다.
# {% endhint %}[EOD]
# --- doc_index: 4 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Payment Notification 메시지 발송 규격 (원스토어 → 개발사 서버)
#
# [요약]: **요약:**
#
# **PaymentTransactionChunk**
# - **목적**: 사용자 결제 상태 알림 (결제 완료/취소)
# - **URI**: 개발자 설정 Payment Notification URL
# - **Method**: POST
# - **주요 내용**:
#   - `msgVersion`: 메시지 버전 (예: 3.1.0)
#   - `clientId`: 앱 클라이언트 ID
#   - `productId`: 상품 ID
#   - `messageType`: SINGLE_PAYMENT_TRANSACTION
#   - `purchaseId`: 구매 ID
#   - `developerPayload`: 개발사 식별자
#   - `purchaseTimeMillis`: 결제 완료 시간 (밀리초)
#   - `purchaseState`: 결제 상태 (COMPLETED/CANCELED)
#   - `price`, `priceCurrencyCode`: 결제 금액 및 통화
#   - `paymentTypeList`: 결제 수단 및 금액 목록
#   - `billingKey`: 확장 기능용 결제 키
#   - `isTestMdn`: 시험폰 여부 (true/false)
#   - `purchaseToken`: 구매 토큰
#   - `environment`, `marketCode`: 결제 환경 및 마켓 코드
#   - `signature`: 메시지 서명
#
# **키워드**: Payment Notification, Purchase State, Billing Key
#
# [원문]: * **메세지 이름** : Payment Transaction Notification
# * **설명** : 사용자의 개별 결제건의 상태(결제완료, 취소)포함된 message를 개발사의 서버로 전송(원스토어의 서버가 개발사가 사전에 정의한 url을 post(with json body) 형식으로 호출함)
# * **URI** : 개발자 센터에서 설정한 Payment Notification URL
# * **Method** : POST
# * **Request Parameters** : N/A
# *   **Request Header** :&#x20;
# | Parameter Name | Data Type | Description      |
# | -------------- | --------- | ---------------- |
# | Content-Type   | String    | application/json |
# * Request Body : JSON 형식
# | Element Name       | Data Type     | Description                                                                   |                                       |
# | ------------------ | ------------- | ----------------------------------------------------------------------------- | ------------------------------------- |
# | msgVersion         | String        | <p>메시지 버전</p><ul><li>개발(Sandbox) : 3.1.0D</li><li>상용(상용테스트) : 3.1.0</li></ul> |                                       |
# | clientId           | String        | 앱의 클라이언트 ID                                                                   |                                       |
# | productId          | String        | 인앱상품의 상품 ID                                                                   |                                       |
# | messageType        | String        | SINGLE\_PAYMENT\_TRANSACTION 고정                                               |                                       |
# | purchaseId         | String        | 구매 ID                                                                         |                                       |
# | developerPayload   | String        | 구매건을 식별하기 위해 개발사에서 관리하는 식별자                                                   |                                       |
# | purchaseTimeMillis | Long          | 원스토어 결제 시스템에서 결제가 완료된 시간(ms)                                                  |                                       |
# | purchaseState      | String        | COMPLETED : 결제완료 / CANCELED : 취소                                              |                                       |
# | price              | String        | 결제 금액                                                                         |                                       |
# | priceCurrencyCode  | String        | 결제 금액 통화코드(KRW, USD, ...)                                                     |                                       |
# | productName        | String        | 구매요청 시 개발사가 customized 인앱상품 제목을 설정한 경우 전달                                     |                                       |
# | paymentTypeList    | List          | 결제 정보 목록                                                                      |                                       |
# | <p><br></p>        | paymentMethod | String                                                                        | 결제 수단 (상세 내용은 아래 paymentMethod 정의 참고) |
# | <p><br></p>        | amount        | String                                                                        | 결제 수단 별 금액                            |
# | billingKey         | String        | 확장 기능용 결제 키                                                                   |                                       |
# | isTestMdn          | Boolean       | 시험폰 여부(true : 시험폰, false : 시험폰 아님)                                            |                                       |
# | purchaseToken      | String        | 구매토큰                                                                          |                                       |
# | environment        | String        | <p>결제환경</p><ul><li>개발(샌드박스) : SANDBOX</li><li>상용 :COMMERCIAL</li></ul>        |                                       |
# | marketCode         | String        | 마켓 구분코드 ( MKT\_ONE : 원스토어, MKT\_STM : 스톰 )                                    |                                       |
# | signature          | String        | 본 메시지에 대한 signature                                                           |                                       |
# \
# **Example**
# ```
# {
# "msgVersion" : "3.1.0"
# "clientId":"0000000001",
# "productId":"0900001234",
# "messageType":"SINGLE_PAYMENT_TRANSACTION",
# "purchaseId":"SANDBOX3000000004564",
# "developerPayload":"OS_000211234",
# "purchaseTimeMillis":24431212233,
# "purchaseState":"COMPLETED",
# "price":"10000",
# "priceCurrencyCode":"KRW"
# "productName":"GOLD100(+20)"
# "paymentTypeList":[
# {
# "paymentMethod":"DCB",
# "amount":"3000"
# },
# {
# "paymentMethod":"ONESTORECASH",
# "amount":"7000"
# }
# ],
# "billingKey" : "36FED4C6E4AC9E29ADAF356057DB98B5CB92126B1D52E8757701E3A261AF49CCFBFC49F5FEF6E277A7A10E9076B523D839E9D84CE9225498155C5065529E22F5",
# "isTestMdn" : true,
# "purchaseToken" : "TOKEN...",
# "environment" : "SANDBOX",
# "marketCode" : "MKT_ONE"
# "signature" "SIGNATURE..."
# }
# ```
# \[EOD]
# --- doc_index: 5 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Payment Notification 메시지 발송 규격 (원스토어 → 개발사 서버) / **paymentMethod(원스토어 결제수단) 정의**
#
# [요약]: **요약:**
#
# 결제 API 문서는 다양한 결제 방법(DCB, PHONEBILL, ONEPAY, 신용카드 등)을 지원하며, 주요 기능으로는 결제 요청, 결제 상태 확인, 결제 결과 수신이 포함됩니다. 결제 결과는 `returnUrl`을 통한 리다이렉트 페이지 또는 `callbackUrl`을 통한 REST API 호출로 전달됩니다. 응답 코드는 결제 성공('Success'), 실패('Fail'), 사용자 취소('UserCancel'), 결제 시간 만료('PaymentTimeExpired') 등을 포함합니다. 주요 키워드: 결제 API, 다양한 결제 수단, 결제 결과 처리.
#
# **대표 키워드:** 결제API, 결제수단, 결과처리
#
# [원문]: | paymentMethod    | 결제수단 명칭    | 설명                         |
# | ---------------- | ---------- | -------------------------- |
# | DCB              | 휴대폰결제      | 통신사 요금청구서에 '정보이용료' 항목으로 청구 |
# | PHONEBILL        | 휴대폰 소액결제   | 통신사 요금청구서에 '소액결제' 항목으로 청구  |
# | ONEPAY           | ONE pay    | 원스토어가 제공하는 간편결제            |
# | CREDITCARD       | 신용카드       | 일반 신용카드 결제                 |
# | 11PAY            | 11Pay      | 11번가에서 제공하는 신용카드 간편결제      |
# | NAVERPAY         | N pay      | 네이버에서 제공하는 네이버페이 결제        |
# | CULTURELAND      | 컬쳐캐쉬       | 한국문화진흥에서 제공한는 컬쳐캐쉬 결제      |
# | OCB              | OK cashbag | SK플래닛이 제공하는 OK캐쉬백 결제       |
# | ONESTORECASH     | 원스토어 캐쉬    | 원스토어 캐쉬 결제                 |
# | COUPON           | 원스토어 쿠폰    | 원스토어 쿠폰 결제                 |
# | POINT            | 원스토어 포인트   | 원스토어 포인트 결제                |
# | TELCOMEMBERSHIP | 통신사멤버십     | 통신사에서 제공하는 멤버십 결제          |
# | EWALLET          | e-Wallet   | e-Wallet 결제                |
# | BANKACCT         | 계좌결제       | 일반 계좌결제                    |
# | PAYPAL           | 페이팔        | 페이팔이 제공하는 결제               |
# | MYCARD           | 마이카드       | 소프트월드에서 제공하는 마이카드 결제       |[EOD]
# --- doc_index: 6 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Payment Notification 메시지 발송 규격 (원스토어 → 개발사 서버) / **Signature 검증 방법**
#
# [요약]: **요약:**
#
# 결제 시스템 문서는 결제 프로세스, 보안 서명 검증 방법, 그리고 다양한 프로그래밍 언어(Java, PHP, Python)를 활용한 서명 위변조 확인 코드를 포함하고 있습니다. 특히, `verify` 함수는 JSON 메시지의 서명을 공개키로 검증하여 결제 거래의 무결성을 보장합니다. 주요 키워드: 결제 프로세스, 서명 검증, 보안, API 참조.
#
# [원문]: 아래 코드를 사용하면 signature에 대한 위변조 여부를 확인할 수 있습니다.
# * 코드 내 PublicKey는 '라이선스 관리'에서 제공되는 라이선스 키를 의미합니다.
# {% tabs %}
# {% tab title="Java" %}
# ```
# import java.security.PublicKey;
#
# import org.apache.commons.codec.binary.Base64;
# import org.codehaus.jackson.JsonNode;
# import org.codehaus.jackson.map.ObjectMapper;
# import org.codehaus.jackson.node.ObjectNode;
#
#
# public class SignatureVerifier {
#
# private static final String SIGN_ALGORITHM = "SHA512withRSA";
# private ObjectMapper mapper = new ObjectMapper();
#
#
# boolean verify(String rawMsg, PublicKey key) throws Exception {
# // JSON 메시지에서 signature를 추출한다.
# JsonNode root = mapper.readTree(rawMsg);
# String signature = root.get("signature").getValueAsText();
# ((ObjectNode)root).remove("signature");
#
# // 추출한 signature가 올바른 값인지 검증한다.
# Signature sign = Signature.getInstance(SIGN_ALGORITHM);
# sign.initVerify(key);
# sign.update(root.toString().getBytes("UTF-8"));
# return sign.verify(Base64.decodeBase64(signature));
# }
# }
# ```
# {% endtab %}
# {% tab title="PHP" %}
# ```
# <?php
# function formatPublicKey($publicKey) {
# $BEGIN= "-----BEGIN PUBLIC KEY-----";
# $END = "-----END PUBLIC KEY-----";
#
# $pem = $BEGIN . "\n";
# $pem .= chunk_split($publicKey, 64, "\n");
# $pem .= $END . "\n";
#
# return $pem;
# }
#
# function formatSignature($signature) {
# return base64_decode(chunk_split($signature, 64, "\n"));
# }
#
# // Sample message
# $sampleMessage = '{"msgVersion":"3.1.0D","purchaseId":"SANDBOX3000000004564","developerPayload":"OS_000211234","clientId":"0000000001","productId":"0900001234","messageType":"SINGLE_PAYMENT_TRANSACTION","purchaseMillis":24431212233,"purchaseState":"COMPLETED","price":20000,"productName":"한글은?GOLD100(+20)","paymentTypeList":[{"paymentMethod":"DCB","amount":3000},{"paymentMethod":"ONESTORECASH","amount":7000}],"billingKey":"36FED4C6E4AC9E29ADAF356057DB98B5CB92126B1D52E8757701E3A261AF49CCFBFC49F5FEF6E277A7A10E9076B523D839E9D84CE9225498155C5065529E22F5","isTestMdn":true,"signature":"MNxIl32ws+yYWpUr7om+jail4UQxBUXdNX5yw5PJKlqW2lurfvhiqF0p4XWa+fmyV6+Ot63w763Gnx2+7Zp2Wgl73TWru5kksBjqVJ3XqyjUHDDaF80aq0KvoQdLAHfKze34cJXKR/Qu8dPHK65PDH/Vu6MvPVRB8TvCJpkQrqg="}';
#
# // Sample public key
# $publicKey = "MIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQDMzpWJoK1GSOrr4juma5+sREYjdCW8/xSd9+6z6PAkUH5af97wy8ecfkLtP9LK5VskryfDlcOjfu0BgmHYntAqKT7B4KWk8jWbJ8VHUpp30H95UbcnCRFDqpEtwYzNA5gNMYKtAdbL41K8Fbum0Xqxo65pPEI4UC3MAG96O7X1WQIDAQAB";
#
#
# // Parse JSON message
# $jsonArr = json_decode($sampleMessage, true);
#
# // Extract and remove signature
# $signature = $jsonArr["signature"];
# unset($jsonArr["signature"]);
# $originalMessage = json_encode($jsonArr, JSON_UNESCAPED_UNICODE);
#
# // Veify
# $formattedKey = formatPublicKey($publicKey);
# $formattedSign = formatSignature($signature);
# $hash_algorithm = 'sha512';
#
# $success = openssl_verify($originalMessage, $formattedSign, $formattedKey, $hash_algorithm);
# if ($success == 1) {
# echo "verified";
# }
# else {
# echo "unverified";
# }
# ?>
# ```
# {% endtab %}
# {% tab title="Python" %}
# {% code overflow="wrap" %}
# ```
# # -*- coding: utf-8 -*-
#
# import json
# from base64 import b64decode
# from collections import OrderedDict
#
# from Crypto.Hash import SHA512
# from Crypto.PublicKey import RSA
# from Crypto.Signature import PKCS1_v1_5
#
# import sys
# reload(sys)
# sys.setdefaultencoding('utf-8')
#
# hash = "SHA-512"
#
#
# def verify(message, signature, pub_key):
# signer = PKCS1_v1_5.new(pub_key)
# digest = SHA512.new()
# digest.update(message)
# return signer.verify(digest, signature)
#
#
# jsonData = json.loads(rawMsg, encoding='utf-8', object_pairs_hook=OrderedDict)
# signature = jsonData['signature']
# del jsonData['signature']
# originalMessage = json.dumps(jsonData, ensure_ascii=False, encoding='utf-8', separators=(',', ':'))
#
# RSA.importKey(publickey).publickey()
# print(verify(originalMessage, b64decode(signature), RSA.importKey(publickey).publickey()))
# ```
# {% endcode %}
# {% endtab %}
# {% endtabs %}[EOD]
# --- doc_index: 7 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Subscription Notification 메시지 발송 규격 (원스토어 → 개발사 서버)
#
# [요약]: **요약:**
#
# **STN (Subscription Transaction Notification)** 메시지는 원스토어 서버가 개발자 센터에 설정된 URL로 정기 결제 상태 정보를 POST 방식으로 전송합니다. 주요 내용은 다음과 같습니다:
#
# - **버전**: 메시지 버전 정보 (예: 3.1.0)
# - **클라이언트 ID**: 앱의 고유 클라이언트 ID
# - **이벤트 시간**: 이벤트 발생 시간
# - **구독 알림**: 구독 상태, 구매 토큰, 상품 ID 등 결제 관련 정보 포함
# - **환경 및 마켓 코드**: 결제 환경(COMMERCIAL) 및 마켓 구분코드(MKT_ONE) 정보
#
# 이 메시지는 개발자 서버로 구독 상태 업데이트를 실시간으로 전달하여 앱 내 결제 관리를 지원합니다.
#
# **키워드**: STN, 구독 알림, 결제 상태 업데이트
#
# [원문]: * **메세지 이름** : Subscription Transaction Notification
# * **설명** : 사용자의 개별 정기 결제건의 정기결제 상태정보(subscriptionNotification)가 포함된 message를 개발사의 서버로 전송(원스토어의 서버가 개발사가 사전에 정의한 url을 post(with json body) 형식으로 호출함)
# * **URI** : 개발자 센터에서 설정한 Subscription Notification URL
# * **Method** : POST
# * **Request Parameters** : N/A
# *   **Request Header** :&#x20;
# | Parameter Name | Data Type | Description      |
# | -------------- | --------- | ---------------- |
# | Content-Type   | String    | application/json |
# * Request Body : JSON 형식
# | Element Name             | Data Type        | Description                                                                   |              |
# | ------------------------ | ---------------- | ----------------------------------------------------------------------------- | ------------ |
# | msgVersion               | String           | <p>메시지 버전</p><ul><li>개발(Sandbox) : 3.1.0D</li><li>상용(상용테스트) : 3.1.0</li></ul> |              |
# | clientId                 | String           | 앱의 클라이언트 ID                                                                   |              |
# | eventTimeMillis          | Long             | 이벤트 발생 시간                                                                     |              |
# | subscriptionNotification | Object           | 결제 정보 목록                                                                      |              |
# | <p><br></p>              | version          | String                                                                        | 구독 알람 메시지 버전 |
# | <p><br></p>              | notificationType | Integer                                                                       | 구독상태         |
# | <p><br></p>              | purchaseToken    | String                                                                        | 구매 토큰        |
# | <p><br></p>              | productId        | String                                                                        | 인앱상품의 상품 ID  |
# | environment              | String           | <p>결제환경</p><ul><li>개발(샌드박스) : SANDBOX</li><li>상용 :COMMERCIAL</li></ul>        |              |
# | marketCode               | String           | 마켓 구분코드 ( MKT\_ONE : 원스토어, MKT\_GLB : 글로벌 원스토어                                |              |
# \
# **Example**
# ```
# {
# "msgVersion":"3.1.0",
# "clientId":"0000000001",
# "eventTimeMillis":24431212233000,
# "subscriptionNotification": {
# "version": "1",
# "notificationType" : 1,
# "purchaseToken":"TOKEN",
# "productId": "com.product.id"
# },
# "environmenmt": "COMMERCIAL",
# "marketCode": "MKT_ONE"
# }
# ```
# \[EOD]
# --- doc_index: 8 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Subscription Notification 메시지 발송 규격 (원스토어 → 개발사 서버) / **구독상태 정의**
#
# [요약]: **요약:**
#
# 구독 상태 코드와 설명 요약:
#
# - **SUBSCRIPTION_RECOVERED**: 정기 결제 복구 완료
# - **SUBSCRIPTION_RENEWED**: 정기 결제 갱신 성공
# - **SUBSCRIPTION_CANCELED**: 정기 결제 해지 요청
# - **SUBSCRIPTION_PURCHASED**: 새로운 정기 결제 상품 구매
# - **SUBSCRIPTION_ON_HOLD**: 결제 실패로 인한 보류 상태
# - **SUBSCRIPTION_IN_GRACE_PERIOD**: 결제 실패 후 유예 기간 진입
# - **SUBSCRIPTION_RESTARTED**: 정기 결제 해지 취소
# - **SUBSCRIPTION_PRICE_CHANGE_CONFIRMED**: 가격 변경 동의 완료
# - **SUBSCRIPTION_DEFERRED**: 정기 결제 기간 연장
# - **SUBSCRIPTION_PAUSED**: 정기 결제 일시 중지
# - **SUBSCRIPTION_PAUSE_SCHEDULE_CHANGED**: 일시 중지 일정 변경
# - **SUBSCRIPTION_REVOKED**: 정기 결제 즉시 해지
# - **SUBSCRIPTION_EXPIRED**: 정기 결제 만료
#
# **대표 용어**: 구독 상태 코드
#
# **키워드**: 구독 관리, 결제 상태 업데이트
#
# [원문]: | 구독 상태 | 구독 코드                                  | 설명                          |
# | ----- | -------------------------------------- | --------------------------- |
# | 1     | SUBSCRIPTION\_RECOVERED                | 정기 결제가 보류 상태에서 복구 되었습니다.    |
# | 2     | SUBSCRIPTION\_RENEWED                  | 정기 결제가 갱신 되었습니다.            |
# | 3     | SUBSCRIPTION\_CANCELED                 | 고객이 정기 결제 해지를 요청 하였습니다.     |
# | 4     | SUBSCRIPTION\_PURCHASED                | 새로운 정기 결제 상품이 구매 되었습니다.     |
# | 5     | SUBSCRIPTION\_ON\_HOLD                 | 결제 실패로 정기 결제가 보류 상태가 되었습니다. |
# | 6     | SUBSCRIPTION\_IN\_GRACE\_PERIOD        | 결제 실패로 정기 결제가 유예 상태가 되었습니다. |
# | 7     | SUBSCRIPTION\_RESTARTED                | 고객이 정기 결제 해지 요청을 취소 하였습니다.  |
# | 8     | SUBSCRIPTION\_PRICE\_CHANGE\_CONFIRMED | 사용자가 정기 결제 가격 변경에 동의 하였습니다. |
# | 9     | SUBSCRIPTION\_DEFERRED                 | 정기 결제 이용 기간이 연장 되었습니다.      |
# | 10    | SUBSCRIPTION\_PAUSED                   | 정기 결제가 일시 중지 되었습니다.         |
# | 11    | SUBSCRIPTION\_PAUSE\_SCHEDULE\_CHANGED | 정기 결제 일시 중지 일정이 변경 되었습니다.   |
# | 12    | SUBSCRIPTION\_REVOKED                  | 정기 결제가 즉시 해지 되었습니다.         |
# | 13    | SUBSCRIPTION\_EXPIRED                  | 정기 결제가 만료 되었습니다.            |
# \[EOD]
# --- doc_index: 9 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / Notification 전송 정책
#
# [요약]: **요약:**
#
# 원스토어 PNS 서버는 개발사 서버로 알림을 HTTP(S) 요청을 통해 전송하며, 서버는 이를 수신했음을 나타내기 위해 200 HTTP Status Code로 응답해야 합니다. 네트워크 지연이나 서버 오류 시 최대 3일간 30회까지 재전송을 시도하며, 재시도 간격은 점차 늘어납니다 (예: 0회차: 0초, 1회차: 30초, 2회차: 120초). 이 과정은 알림의 안정적 전달을 보장합니다.
#
# **대표 키워드:** PNS 알림 재전송, HTTP 200 응답
#
# [원문]: 원스토어의 PNS 서버는 HTTP(S) 요청을 통하여 개발사 서버로 notification을 전송합니다.
# 이때 개발사 서버는 notification를 정상적으로 수신했다는 의미로 HTTP Status Code를 200으로 응답하여야 합니다.
# 만약 네트워크 지연으로 인한 유실 또는 개발사 서버의 비정상적인 상황으로 HTTP Status Code를 200으로 응답받지 못한 경우, PNS서버는 notification 전송이 실패했다고 판단하고 3일간 최대 30회의 재전송을 수행하게 됩니다.
# notification의 재전송은 아래의 예시와 같이 일정한 delay를 가진 후 실행되며, 재시도 회수가 많아지면 delay가 점차 늘어나는 구조로 되어 있습니다.
# **Example**
# | 회차     | delay (초) | 재전송 시간              |
# | ------ | --------- | ------------------- |
# | 0 (최초) | 0         | 2020-05-17 13:10:00 |
# | 1      | 30        | 2020-05-17 13:10:30 |
# | 2      | 120       | 2020-05-17 13:12:30 |
# | 3      | 270       | 2020-05-17 13:17:00 |
# | 4      | 480       | 2020-05-17 13:25:00 |
# | ...    | ...       | ...                 |
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/subs.md[EOD]
# --- doc_index: 10 ---
# [제목]: 08. 정기 결제 적용하기 / **정기 결제 처리 하기**  <a href="#id-08." id="id-08."></a>
#
# [요약]: **요약:**
#
# 정기 결제 상품의 상태 변경(구독중, 해지, 유예, 보류, 일시중지, 만료)은 PurchaseClient 또는 getSubscriptionDetail API를 통해 확인 가능합니다. 각 상태 변경 시 SubscriptionNotification이 전송되며, 이를 통해 앱은 적절한 대응 조치를 취할 수 있습니다. 주요 상태 코드: `autoRenewing` (구독 지속), `expiryTimeMillis` (만료 시간). 정기 결제 관리 및 알림 서비스를 통해 효율적인 운영이 가능합니다.
#
# **키워드:** 정기 결제, 상태 변경, SubscriptionNotification, PNS
#
# [원문]: 사용자가 정기 결제 상품을 구매하면, 상품을 이용하는 동안 다양한 상태 변경을 거칠 수 있습니다.&#x20;
# 앱은 정기 결제의 상태를 확인하여, 각 상태 변경에 대응해야 합니다.&#x20;
# 정기 결제의 상태는 원스토어 인앱 결제 라이브러리의 PurchaseClient.queryPurchasesAsync() 또는 서버 API getSubscriptionDetail을 사용하여 확인 할 수 있습니다.&#x20;
# |      | PurchaseClient.queryPurchasesAsync() |                | getSubscriptionDetail |                                     |              |
# | ---- | ------------------------------------ | -------------- | --------------------- | ----------------------------------- | ------------ |
# | 상태   | 반환 여부                                | recurringState | 반환 여부                 | expiryTimeMillis                    | autoRenewing |
# | 구독중  | 예                                    | 0              | 예                     | 향후 일정                               | true         |
# | 해지   | 예                                    | 1              | 예                     | 향후 일정                               | false        |
# | 유예   | 예                                    | 0              | 예                     | 향후 일정(유예 기간 종료)                     | true         |
# | 보류   | 아니오                                  | 0              | 예                     | 종료됨(예상 만료 시간 종료 또는 유예 기간 종료(있는 경우)) | true         |
# | 일시중지 | 아니오                                  | 0              | 예                     | 종료됨                                 | true         |
# | 만료   | 아니오                                  | 1              | 예                     | 종료됨                                 | false        |
# 정기 결제 상태가 변경되면, SubscriptionNotification이 전송됩니다. 관련 내용은 PNS(Payment Notification Service) 이용하기를 참고하세요.[EOD]
# --- doc_index: 11 ---
# [제목]: 09. 원스토어 인앱결제 릴리즈 노트 / **원스토어 인앱결제 라이브러리 API V6(SDK V19) 출시** <a href="#id-09.-apiv6-sdkv19" id="id-09.-apiv6-sdkv19"></a> / PNS 메시지 규격 변경  <a href="#id-09.-pns" id="id-09.-pns"></a>
#
# [요약]: **요약:**
#
# 결제 API 문서는 원화 외 통화 지원을 위해 결제금액과 결제수단 금액의 데이터 타입을 String으로 변경하고, 통화코드(priceCurrencyCode)를 추가했습니다. 응답 규격에는 purchaseToken, environment, marketCode 필드가 추가되었습니다. 주요 기능은 결제 요청, 응답 처리, 그리고 다양한 통화 및 결제 수단을 지원하는 결제 시스템 관리입니다. **결제API, 통화지원, 결제요청**
#
# [원문]: * 원화 외의 통화를 지원하기 위하여 결제금액(price)의 데이터 타입이 Number에서 String으로 변경하였습니다.
# * 원화 외의 통화를 지원하기 위하여 결제금액의 통화코드(priceCurrencyCode)를 추가하였습니다.
# * 원화 외의 통화를 지원하기 위하여 결제수단별금액(amount)의 데이터 타입이 Number에서 String으로 변경하였습니다.
# * 응답 규격에 purchaseToken, environment, marketCode 필드가 추가되었습니다.&#x20;
# 상세한 규격은 PNS 메시지 상세 변경 내역에서 확인 할 수 있습니다. &#x20;[EOD]
# 'PNS' 문자열을 포함하는 문서 개수: 12

# %%
###### Retriever Check from FAISS Vector DB ######

from langchain.embeddings import OllamaEmbeddings
from langchain.vectorstores import FAISS
from langchain_core.documents import Document
from langchain.prompts import PromptTemplate
from langchain_community.chat_models import ChatOllama
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.vectorstores import FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import PromptTemplate
from langchain.retrievers import EnsembleRetriever
from langchain.retrievers import BM25Retriever

# fixed_model_name_ret = "bge-m3:latest"
# ✅ 3. 임베딩 모델 초기화 (Ollama)
embedding_model = OllamaEmbeddings(model=fixed_model_name)

# 저장된 데이터를 로드
loaded_db = FAISS.load_local(
    folder_path=output_dir,
    # index_name="index",
    embeddings=embedding_model,
    allow_dangerous_deserialization=True,
)

retriever = loaded_db.as_retriever(
    search_type="mmr",
    search_kwargs={"k": 30, "fetch_k": 70, "lambda_mult": 0.7}
    # search_type="similarity",
    # search_kwargs={"k": 50}
)

bm25 = BM25Retriever.from_documents(
    docs_markdown,
    bm25_params={"k1": 1.5, "b": 0.75}
)

bm25.k = 30

ensembled_retriever = EnsembleRetriever(
    retrievers=[bm25, retriever],
    weights=[0.5, 0.5]
)


res = ensembled_retriever.invoke(
    # "원스토어 인앱결제의 PNS의 개념을 설명해주세요"
    "PNS 메시지 규격의 purcahseState는 어떤 값으로 구성되나요?"
)

# res = bm25.invoke(
#     # "PNS의 메세지 규격을 설명해주세요",
#     "PNS 메시지 규격의 purcahseState는 어떤 값으로 구성되나요?"
# )

# res = bm25.invoke(
#     # "원스토어 인앱결제의 PNS의 개념을 설명해주세요",
#     "PNS 메시지 규격의 purcahseState는 어떤 값으로 구성되나요?"
# )

print(f"검색된 문서 수: {len(res)}")

idx = 0
for doc in res: 
    print(f"--- doc_index: {idx} ---")
    print(doc.page_content)  # Print first 100 characters of each document
    # print(doc.metadata)
    # print('-' * 40)
    idx += 1
# Out:
# 검색된 문서 수: 53
# --- doc_index: 0 ---
# [제목]: 09. 원스토어 인앱결제 릴리즈 노트 / **원스토어 인앱결제 라이브러리 API V6(SDK V19) 출시** <a href="#id-09.-apiv6-sdkv19" id="id-09.-apiv6-sdkv19"></a> / PNS 메시지 규격 변경  <a href="#id-09.-pns" id="id-09.-pns"></a>
#
# [요약]: **요약:**
#
# 결제 API 문서는 원화 외 통화 지원을 위해 결제금액과 결제수단 금액의 데이터 타입을 String으로 변경하고, 통화코드(priceCurrencyCode)를 추가했습니다. 응답 규격에는 purchaseToken, environment, marketCode 필드가 추가되었습니다. 주요 기능은 결제 요청, 응답 처리, 그리고 다양한 통화 및 결제 수단을 지원하는 결제 시스템 관리입니다. **결제API, 통화지원, 결제요청**
#
# [원문]: * 원화 외의 통화를 지원하기 위하여 결제금액(price)의 데이터 타입이 Number에서 String으로 변경하였습니다.
# * 원화 외의 통화를 지원하기 위하여 결제금액의 통화코드(priceCurrencyCode)를 추가하였습니다.
# * 원화 외의 통화를 지원하기 위하여 결제수단별금액(amount)의 데이터 타입이 Number에서 String으로 변경하였습니다.
# * 응답 규격에 purchaseToken, environment, marketCode 필드가 추가되었습니다.&#x20;
# 상세한 규격은 PNS 메시지 상세 변경 내역에서 확인 할 수 있습니다. &#x20;
# --- doc_index: 1 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / Notification 전송 정책
#
# [요약]: **요약:**
#
# 원스토어 PNS 서버는 개발사 서버로 알림을 HTTP(S) 요청을 통해 전송하며, 서버는 이를 수신했음을 나타내기 위해 200 HTTP Status Code로 응답해야 합니다. 네트워크 지연이나 서버 오류 시 최대 3일간 30회까지 재전송을 시도하며, 재시도 간격은 점차 늘어납니다 (예: 0회차: 0초, 1회차: 30초, 2회차: 120초). 이 과정은 알림의 안정적 전달을 보장합니다.
#
# **대표 키워드:** PNS 알림 재전송, HTTP 200 응답
#
# [원문]: 원스토어의 PNS 서버는 HTTP(S) 요청을 통하여 개발사 서버로 notification을 전송합니다.
# 이때 개발사 서버는 notification를 정상적으로 수신했다는 의미로 HTTP Status Code를 200으로 응답하여야 합니다.
# 만약 네트워크 지연으로 인한 유실 또는 개발사 서버의 비정상적인 상황으로 HTTP Status Code를 200으로 응답받지 못한 경우, PNS서버는 notification 전송이 실패했다고 판단하고 3일간 최대 30회의 재전송을 수행하게 됩니다.
# notification의 재전송은 아래의 예시와 같이 일정한 delay를 가진 후 실행되며, 재시도 회수가 많아지면 delay가 점차 늘어나는 구조로 되어 있습니다.
# **Example**
# | 회차     | delay (초) | 재전송 시간              |
# | ------ | --------- | ------------------- |
# | 0 (최초) | 0         | 2020-05-17 13:10:00 |
# | 1      | 30        | 2020-05-17 13:10:30 |
# | 2      | 120       | 2020-05-17 13:12:30 |
# | 3      | 270       | 2020-05-17 13:17:00 |
# | 4      | 480       | 2020-05-17 13:25:00 |
# | ...    | ...       | ...                 |
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/subs.md
# --- doc_index: 2 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세**
#
# [요약]: **요약:**
#
# PNS 3.1.0 버전 업데이트로 인해 `packageName` 파라미터가 `clientId`로 변경되었습니다. 주요 내용은 다음과 같습니다:
#
# - **API 버전**: PNS 3.1.0
# - **변경 사항**: `packageName` → `clientId` (3.0.0 이하 버전은 변경 없음)
# - **주요 기능**: 개발자 센터 개편에 따른 API 변경 사항 안내
#
# **키워드**: PNS, API 업데이트, clientId, 개발자센터 개편
#
# [원문]: {% hint style="info" %}
# 2025년 3월 20일 개발자센터 개편의 영향으로 PNS 3.1.0 버전이 추가 되었습니다.&#x20;
# * &#x20;packageName 파라미터가 clientId로 변경 되었으며, 3.0.0 이하 버전에서는 변경 사항이 없습니다.
# {% endhint %}
# --- doc_index: 3 ---
# [제목]: PurchaseData / Public methods <a href="#id-c-purchasedata-publicmethods" id="id-c-purchasedata-publicmethods"></a> / getRecurringState <a href="#id-c-purchasedata-getrecurringstate" id="id-c-purchasedata-getrecurringstate"></a>
#
# [요약]: **요약:**
#
# `getRecurringState()` 함수는 월정액 상품의 상태를 나타내는 값을 반환합니다. 반환값은 [\[A\]PurchaseData.RecurringState](../annotations/purchasedata.recurringstate)](RecurringState) 중 하나로, 구독 상태를 정의합니다. 이 함수는 구독 관리 및 상태 확인에 필수적입니다.
#
# **키워드:** recurringState, 구독상태, 구매데이터
#
# [원문]: ```
# int getRecurringState()
# ```
# 월정액 상품의 상태를 나타내는 값으로 [\[A\]PurchaseData.RecurringState](../annotations/purchasedata.recurringstate) 중 하나를 반환합니다.
# | **Returns:** |             |
# | ------------ | ----------- |
# | int          | <p><br></p> |
# --- doc_index: 4 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 수신 서버 URL 설정**
#
# [요약]: **요약:**
#
# 개발사 서버의 PNS 수신 URL은 '개발자센터 > Apps > 상품 선택 > In-App정보'에서 설정 가능합니다. Sandbox와 상용 환경을 각각 구분하여 설정할 수 있으며, 개발용과 상용 환경이 동일한 경우 동일 URL 사용 가능합니다. 이 설정은 결제 결과의 정확한 전달을 위해 중요합니다.
#
# **대표 키워드:** PNS 설정, 결제 결과 전달, 개발자센터
#
# [원문]: PNS를 수신 받을 개발사 서버의 URL은 '개발자센터 > Apps > 상품 선택 > In-App정보' 메뉴에서 'PNS 관리' 버튼을 클릭하면 설정할 수 있습니다.\
# URL은 Sandbox(개발용) 결제환경 및 상용(상용테스트 포함) 결제환경을 각각 설정할 수 있으며, 개발용/상용 서버가 동일할 경우 동일한 URL을 입력하시면 됩니다.
# --- doc_index: 5 ---
# [제목]: PurchaseData / Public methods <a href="#id-c-purchasedata-publicmethods" id="id-c-purchasedata-publicmethods"></a> / getPurchaseState <a href="#id-c-purchasedata-getpurchasestate" id="id-c-purchasedata-getpurchasestate"></a>
#
# [요약]: **요약:**
#
# `getPurchaseState()` 함수는 구매 상태를 나타내는 정수 값을 반환하며, 이 값은 \[A]PurchaseData.PurchaseState 열거형의 멤버 중 하나입니다. 이 함수는 구매 프로세스의 현재 상태를 확인하는데 사용됩니다.
#
# **대표 키워드:** PurchaseState, 구매상태 확인
#
# 이 요약은 `getPurchaseState()` 함수의 주요 목적과 반환 값을 간결하게 전달하며, 관련 키워드를 포함하여 검색 품질을 향상시킵니다.
#
# [원문]: ```
# int getPurchaseState()
# ```
# 구매 상태를 나타내는 값으로 \[A]PurchaseData.PurchaseState 중 하나를 반환합니다.
# | **Returns:** |             |
# | ------------ | ----------- |
# | int          | <p><br></p> |
# --- doc_index: 6 ---
# [제목]: IapResult.Builder / Public methods <a href="#id-c-iapresult.builder-publicmethods" id="id-c-iapresult.builder-publicmethods"></a> / setMessage <a href="#id-c-iapresult.builder-setmessage" id="id-c-iapresult.builder-setmessage"></a>
#
# [요약]: **요약:**
#
# `IapResult.Builder` 클래스는 In-app Purchase API 응답 메시지를 설정하는 메서드를 제공합니다. 이 메서드는 구매 결과를 나타내는 메시지를 전달하여 개발자에게 결제 상태를 명확히 알려줍니다. 주요 기능은 `message` 파라미터를 통해 응답 메시지를 설정하는 것입니다. 이는 결제 성공 여부와 관련 정보를 포함합니다.
#
# **대표 용어:** `IapResult`, `message`
#
# **키워드:** In-app Purchase, API 응답 메시지
#
# [원문]: ```
# IapResult.Builder setMessage(String message)
# ```
# <table data-header-hidden><thead><tr><th></th><th></th></tr></thead><tbody><tr><td><strong>Parameters:</strong></td><td></td></tr><tr><td><pre><code>message
# </code></pre></td><td>In-app Purchase API 응답 메시지입니다.</td></tr><tr><td><strong>Returns:</strong></td><td></td></tr><tr><td>IapResult.Builder</td><td><br></td></tr></tbody></table>
# --- doc_index: 7 ---
# [제목]: PurchaseData.PurchaseState / Constants <a href="#id-a-purchasedata.purchasestate-constants" id="id-a-purchasedata.purchasestate-constants"></a> / PURCHASED <a href="#id-a-purchasedata.purchasestate-purchased" id="id-a-purchasedata.purchasestate-purchased"></a>
#
# [요약]: **요약문:**
#
# **PURCHASE** 처리 상태를 나타내는 상수 값으로, 구매가 완료되었음을 의미합니다 (Constant Value: 0). 이 값은 결제 및 주문 관리 시스템에서 구매 상태를 확인하는 데 사용됩니다.
#
# **키워드:** PURCHASE, 구매상태, 상수값 0
#
# [원문]: ```
# int PURCHASED
# ```
# 구매됨
# Constant Value: 0
# --- doc_index: 8 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Subscription Notification 메시지 발송 규격 (원스토어 → 개발사 서버)
#
# [요약]: **요약:**
#
# **STN (Subscription Transaction Notification)** 메시지는 원스토어 서버가 개발자 센터에 설정된 URL로 정기 결제 상태 정보를 POST 방식으로 전송합니다. 주요 내용은 다음과 같습니다:
#
# - **버전**: 메시지 버전 정보 (예: 3.1.0)
# - **클라이언트 ID**: 앱의 고유 클라이언트 ID
# - **이벤트 시간**: 이벤트 발생 시간
# - **구독 알림**: 구독 상태, 구매 토큰, 상품 ID 등 결제 관련 정보 포함
# - **환경 및 마켓 코드**: 결제 환경(COMMERCIAL) 및 마켓 구분코드(MKT_ONE) 정보
#
# 이 메시지는 개발자 서버로 구독 상태 업데이트를 실시간으로 전달하여 앱 내 결제 관리를 지원합니다.
#
# **키워드**: STN, 구독 알림, 결제 상태 업데이트
#
# [원문]: * **메세지 이름** : Subscription Transaction Notification
# * **설명** : 사용자의 개별 정기 결제건의 정기결제 상태정보(subscriptionNotification)가 포함된 message를 개발사의 서버로 전송(원스토어의 서버가 개발사가 사전에 정의한 url을 post(with json body) 형식으로 호출함)
# * **URI** : 개발자 센터에서 설정한 Subscription Notification URL
# * **Method** : POST
# * **Request Parameters** : N/A
# *   **Request Header** :&#x20;
# | Parameter Name | Data Type | Description      |
# | -------------- | --------- | ---------------- |
# | Content-Type   | String    | application/json |
# * Request Body : JSON 형식
# | Element Name             | Data Type        | Description                                                                   |              |
# | ------------------------ | ---------------- | ----------------------------------------------------------------------------- | ------------ |
# | msgVersion               | String           | <p>메시지 버전</p><ul><li>개발(Sandbox) : 3.1.0D</li><li>상용(상용테스트) : 3.1.0</li></ul> |              |
# | clientId                 | String           | 앱의 클라이언트 ID                                                                   |              |
# | eventTimeMillis          | Long             | 이벤트 발생 시간                                                                     |              |
# | subscriptionNotification | Object           | 결제 정보 목록                                                                      |              |
# | <p><br></p>              | version          | String                                                                        | 구독 알람 메시지 버전 |
# | <p><br></p>              | notificationType | Integer                                                                       | 구독상태         |
# | <p><br></p>              | purchaseToken    | String                                                                        | 구매 토큰        |
# | <p><br></p>              | productId        | String                                                                        | 인앱상품의 상품 ID  |
# | environment              | String           | <p>결제환경</p><ul><li>개발(샌드박스) : SANDBOX</li><li>상용 :COMMERCIAL</li></ul>        |              |
# | marketCode               | String           | 마켓 구분코드 ( MKT\_ONE : 원스토어, MKT\_GLB : 글로벌 원스토어                                |              |
# \
# **Example**
# ```
# {
# "msgVersion":"3.1.0",
# "clientId":"0000000001",
# "eventTimeMillis":24431212233000,
# "subscriptionNotification": {
# "version": "1",
# "notificationType" : 1,
# "purchaseToken":"TOKEN",
# "productId": "com.product.id"
# },
# "environmenmt": "COMMERCIAL",
# "marketCode": "MKT_ONE"
# }
# ```
# \
# --- doc_index: 9 ---
# [제목]: PurchaseClient.Builder / Public Methods <a href="#id-c-purchaseclient.builder-publicmethods" id="id-c-purchaseclient.builder-publicmethods"></a> / setBase64PublicKey <a href="#id-c-purchaseclient.builder-setbase64publickey" id="id-c-purchaseclient.builder-setbase64publickey"></a>
#
# [요약]: **요약:**
#
# `PurchaseClient.Builder` 클래스를 사용하여 구매 정보의 유효성을 검증하기 위해 개발자 센터에서 발급받은 `base64PublicKey`를 설정할 수 있습니다. 이 설정은 구매 요청의 보안성을 강화하는데 필수적입니다.
#
# **대표 용어:** PurchaseClient, base64PublicKey
#
# **키워드:** 구매 검증, 보안 설정
#
# [원문]: ```
# @UiThread
# public PurchaseClient.Builder setBase64PublicKey(String base64PublicKey)
# ```
# 구매정보의 유효성 체크를 위해 개발자센터에서 발급된 public key 를 지정하세요.
# | **Parameters:**                   |                        |
# | --------------------------------- | ---------------------- |
# | base64PublicKey                   | base64EncodedPublicKey |
# | **Returns**                       |                        |
# | <p>PurchaseClient.Builder<br></p> |                        |
# --- doc_index: 10 ---
# [제목]: PurchaseClient.ConnectionState
#
# [요약]: **요약:**
#
# `PurchaseClient.ConnectionState` 인터페이스는 `com.gaa.sdk.iap.PurchaseClient` 클래스의 연결 상태를 정의합니다. 이 상태 값은 앱 내 구매 클라이언트의 연결 상태를 관리하는데 사용되며, 개발자가 클라이언트의 실시간 연결 상태를 추적하고 관리할 수 있도록 지원합니다. 주요 키워드: PurchaseClient, ConnectionState, 구매 클라이언트 연결 상태 관리.
#
# **키워드:** PurchaseClient, 연결 상태 관리
#
# [원문]: ```
# public static @interface PurchaseClient.ConnectionState
# ```
# ```
# com.gaa.sdk.iap.PurchaseClient.ConnectionState
# ```
# PurchaseClient 의 연결 상태 값.
# --- doc_index: 11 ---
# [제목]: IapResult / Public methods <a href="#id-c-iapresult-publicmethods" id="id-c-iapresult-publicmethods"></a> / isFailure <a href="#id-c-iapresult-isfailure" id="id-c-iapresult-isfailure"></a>
#
# [요약]: **요약:**
#
# In-app Purchase API 응답 코드 `isFailure()`는 결제 요청의 성공 여부를 확인합니다. 이 메서드는 결제 결과가 실패했는지 여부를 불리언 값으로 반환하여 개발자가 오류 처리를 효과적으로 수행할 수 있도록 지원합니다. 주요 키워드: `isFailure`, `결제결과`, `실패처리`.
#
# [원문]: ```
# boolean isFailure()
# ```
# In-app Purchase API 응답 코드가 실패 인지를 나타냅니다.
# | **Returns:** |             |
# | ------------ | ----------- |
# | boolean      | <p><br></p> |
# --- doc_index: 12 ---
# [제목]: PurchaseClientStateListener / Public methods <a href="#id-i-purchaseclientstatelistener-publicmethods" id="id-i-purchaseclientstatelistener-publicmethods"></a> / onSetupFinished <a href="#id-i-purchaseclientstatelistener-onsetupfinished" id="id-i-purchaseclientstatelistener-onsetupfinished"></a>
#
# [요약]: **요약:**
#
# `onSetupFinished` 함수는 연결 설정이 완료되었음을 알리는 역할을 합니다. 이 함수는 `iapResult` 매개변수를 통해 요청 작업의 결과를 전달합니다. 이 기능은 서비스 설정 및 초기화 과정에서 중요한 역할을 수행하며, 원활한 시스템 연동을 보장합니다. **키워드:** 연결 설정, 초기화, iapResult
#
# **참고:** 요약문은 주요 기능과 매개변수를 간결하게 전달하며, 문서의 맥락을 유지하면서 검색 품질을 향상시키는 데 초점을 맞추었습니다.
#
# [원문]: ```
# void onSetupFinished(iapResult)
# ```
# 연결 설정이 완료 되었음을 알리기 위해 호출됩니다.\
# | **Parameters:** |             |
# | --------------- | ----------- |
# | iapResult       | 요청작업에 대한 결과 |
# --- doc_index: 13 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Payment Notification 메시지 발송 규격 (원스토어 → 개발사 서버) / **paymentMethod(원스토어 결제수단) 정의**
#
# [요약]: **요약:**
#
# 결제 API 문서는 다양한 결제 방법(DCB, PHONEBILL, ONEPAY, 신용카드 등)을 지원하며, 주요 기능으로는 결제 요청, 결제 상태 확인, 결제 결과 수신이 포함됩니다. 결제 결과는 `returnUrl`을 통한 리다이렉트 페이지 또는 `callbackUrl`을 통한 REST API 호출로 전달됩니다. 응답 코드는 결제 성공('Success'), 실패('Fail'), 사용자 취소('UserCancel'), 결제 시간 만료('PaymentTimeExpired') 등을 포함합니다. 주요 키워드: 결제 API, 다양한 결제 수단, 결제 결과 처리.
#
# **대표 키워드:** 결제API, 결제수단, 결과처리
#
# [원문]: | paymentMethod    | 결제수단 명칭    | 설명                         |
# | ---------------- | ---------- | -------------------------- |
# | DCB              | 휴대폰결제      | 통신사 요금청구서에 '정보이용료' 항목으로 청구 |
# | PHONEBILL        | 휴대폰 소액결제   | 통신사 요금청구서에 '소액결제' 항목으로 청구  |
# | ONEPAY           | ONE pay    | 원스토어가 제공하는 간편결제            |
# | CREDITCARD       | 신용카드       | 일반 신용카드 결제                 |
# | 11PAY            | 11Pay      | 11번가에서 제공하는 신용카드 간편결제      |
# | NAVERPAY         | N pay      | 네이버에서 제공하는 네이버페이 결제        |
# | CULTURELAND      | 컬쳐캐쉬       | 한국문화진흥에서 제공한는 컬쳐캐쉬 결제      |
# | OCB              | OK cashbag | SK플래닛이 제공하는 OK캐쉬백 결제       |
# | ONESTORECASH     | 원스토어 캐쉬    | 원스토어 캐쉬 결제                 |
# | COUPON           | 원스토어 쿠폰    | 원스토어 쿠폰 결제                 |
# | POINT            | 원스토어 포인트   | 원스토어 포인트 결제                |
# | TELCOMEMBERSHIP | 통신사멤버십     | 통신사에서 제공하는 멤버십 결제          |
# | EWALLET          | e-Wallet   | e-Wallet 결제                |
# | BANKACCT         | 계좌결제       | 일반 계좌결제                    |
# | PAYPAL           | 페이팔        | 페이팔이 제공하는 결제               |
# | MYCARD           | 마이카드       | 소프트월드에서 제공하는 마이카드 결제       |
# --- doc_index: 14 ---
# [제목]: PurchaseData.PurchaseState
#
# [요약]: **요약:**
#
# `PurchaseState` 어노테이션은 `com.gaa.sdk.iap.PurchaseData` 클래스 내에서 구매한 데이터의 상태를 나타내는 중요한 속성입니다. 이 속성은 구매 내역의 유효성과 상태를 추적하는데 사용되며, 개발자가 구매 정보를 효과적으로 관리하고 확인할 수 있도록 지원합니다.
#
# **대표 키워드:** PurchaseState, PurchaseData, 구매상태 관리
#
# [원문]: ```
# public static @interface PurchaseData.PurchaseState
# ```
# ```
# com.gaa.sdk.iap.PurchaseData.PurchaseState
# ```
# 구매한 데이터의 상태값
# --- doc_index: 15 ---
# [제목]: 01. 원스토어 인앱결제 개요 / **인앱 상품의 유형** <a href="#id-01." id="id-01."></a>
#
# [요약]: **요약:**
#
# 원스토어 인앱결제 API V7(SDK V21)는 관리형 상품과 구독형 상품을 지원합니다. 관리형 상품은 일회성 구매로 소비 전까지 재구매가 필요하며, 구독형 상품은 정해진 주기로 자동 결제를 처리합니다. 구독형 상품은 프로모션 기능과 결제 편의성을 제공하여 정기 결제 상품을 효과적으로 관리할 수 있습니다. (**API V7, 구독형 상품, 자동결제**)
#
# **키워드:** 인앱 결제, API V7, 구독형 상품, 자동결제
#
# [원문]: 원스토어 인앱결제 API V7(SDK V21)는 관리형 상품과 구독형 상품. 두 가지 유형의 인앱 상품을 제공 합니다.\
# 우선, 각 타입이 어떤 특성을 가지고 있는지 확인하신 후 본인이 제공하는 상품에 맞게 인앱 상품 목록을 구성해 보시기 바랍니다.
# <table><thead><tr><th width="239">구분</th><th>내용</th></tr></thead><tbody><tr><td>관리형 상품</td><td>구매 후 소비(consume)하기 전까지 재구매가 되지 않는 상품입니다. 해당 상품을 다시 구매하기 위해서는 소비(consume) 처리를 해야 합니다.<br>해당 특성을 이용하여 소비성/영구성/기간제 형태의 인앱 상품을 제공 할 수 있습니다.</td></tr><tr><td>월정액 상품 (Deprecated)</td><td><p>한 번 가입하면 지정된 날짜에 매월 일정 금액이 자동결제 되는 상품으로, 자동결제 갱신(재결제)은 원스토어에서 처리합니다.</p><p>SDK V21 (API V7) 적용 이후 신규 월정액 상품은 만들 수 없습니다. (기존에 만들어진 월정액 상품은 계속 이용 하실 수 있습니다.) </p><p>구독형 상품을 이용하여 정기 결제 상품을 제공할 수 있습니다,  </p></td></tr><tr><td>구독형 상품</td><td><p>SDK V21 (API V7) 부터 제공되는 정기 결제 상품 타입입니다.</p><p>정해진 주기에 따라 원스토어에서 정기 결제를 처리하며, 신규 고객을 유치하기 위한 프로모션 기능 및 결제 수단 변경 등의 사용자 편의 기능을 제공합니다. </p><p>구독형 상품에 대한 자세한 내용은 <a href="subs">정기결제 적용하기</a> 페이지를 참고하시기 바랍니다.</p></td></tr></tbody></table>
# --- doc_index: 16 ---
# [제목]: PurchaseFlowParams.ProrationMode / Constants <a href="#id-a-purchaseflowparams.prorationmode-constants" id="id-a-purchaseflowparams.prorationmode-constants"></a> / UNKNOWN\_SUBSCRIPTION\_UPGRADE\_DOWNGRADE\_POLICY <a href="#id-a-purchaseflowparams.prorationmode-unknown_subscription_upgrade_downgrade_policy" id="id-a-purchaseflowparams.prorationmode-unknown_subscription_upgrade_downgrade_policy"></a>
#
# [요약]: **요약:**
#
# UNKNOWN_SUBSCRIPTION 관련 상수 값은 `0`으로 정의되어 있으며, 이는 명시되지 않은 구독 업그레이드/다운그레이드 정책 상태를 나타냅니다. 이 문서는 주로 구독 관리 API와 결제 처리 과정에 대한 상세 내용을 다루고 있습니다. 특히, 구독 상태 업데이트, 결제 요청 및 응답 처리, 그리고 다양한 응답 코드와 그 의미에 대해 설명하고 있습니다. 핵심 키워드: 구독 관리, 결제 API, 응답 코드.
#
# **대표 키워드:** 구독 관리 API, 결제 처리, 응답 코드
#
# [원문]: ```
# int UNKNOWN_SUBSCRIPTION_UPGRADE_DOWNGRADE_POLICY
# ```
# 명시되지 않은 상태값
# Constant Value: 0
# --- doc_index: 17 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Payment Notification 메시지 발송 규격 (원스토어 → 개발사 서버)
#
# [요약]: **요약:**
#
# **PaymentTransactionChunk**
# - **목적**: 사용자 결제 상태 알림 (결제 완료/취소)
# - **URI**: 개발자 설정 Payment Notification URL
# - **Method**: POST
# - **주요 내용**:
#   - `msgVersion`: 메시지 버전 (예: 3.1.0)
#   - `clientId`: 앱 클라이언트 ID
#   - `productId`: 상품 ID
#   - `messageType`: SINGLE_PAYMENT_TRANSACTION
#   - `purchaseId`: 구매 ID
#   - `developerPayload`: 개발사 식별자
#   - `purchaseTimeMillis`: 결제 완료 시간 (밀리초)
#   - `purchaseState`: 결제 상태 (COMPLETED/CANCELED)
#   - `price`, `priceCurrencyCode`: 결제 금액 및 통화
#   - `paymentTypeList`: 결제 수단 및 금액 목록
#   - `billingKey`: 확장 기능용 결제 키
#   - `isTestMdn`: 시험폰 여부 (true/false)
#   - `purchaseToken`: 구매 토큰
#   - `environment`, `marketCode`: 결제 환경 및 마켓 코드
#   - `signature`: 메시지 서명
#
# **키워드**: Payment Notification, Purchase State, Billing Key
#
# [원문]: * **메세지 이름** : Payment Transaction Notification
# * **설명** : 사용자의 개별 결제건의 상태(결제완료, 취소)포함된 message를 개발사의 서버로 전송(원스토어의 서버가 개발사가 사전에 정의한 url을 post(with json body) 형식으로 호출함)
# * **URI** : 개발자 센터에서 설정한 Payment Notification URL
# * **Method** : POST
# * **Request Parameters** : N/A
# *   **Request Header** :&#x20;
# | Parameter Name | Data Type | Description      |
# | -------------- | --------- | ---------------- |
# | Content-Type   | String    | application/json |
# * Request Body : JSON 형식
# | Element Name       | Data Type     | Description                                                                   |                                       |
# | ------------------ | ------------- | ----------------------------------------------------------------------------- | ------------------------------------- |
# | msgVersion         | String        | <p>메시지 버전</p><ul><li>개발(Sandbox) : 3.1.0D</li><li>상용(상용테스트) : 3.1.0</li></ul> |                                       |
# | clientId           | String        | 앱의 클라이언트 ID                                                                   |                                       |
# | productId          | String        | 인앱상품의 상품 ID                                                                   |                                       |
# | messageType        | String        | SINGLE\_PAYMENT\_TRANSACTION 고정                                               |                                       |
# | purchaseId         | String        | 구매 ID                                                                         |                                       |
# | developerPayload   | String        | 구매건을 식별하기 위해 개발사에서 관리하는 식별자                                                   |                                       |
# | purchaseTimeMillis | Long          | 원스토어 결제 시스템에서 결제가 완료된 시간(ms)                                                  |                                       |
# | purchaseState      | String        | COMPLETED : 결제완료 / CANCELED : 취소                                              |                                       |
# | price              | String        | 결제 금액                                                                         |                                       |
# | priceCurrencyCode  | String        | 결제 금액 통화코드(KRW, USD, ...)                                                     |                                       |
# | productName        | String        | 구매요청 시 개발사가 customized 인앱상품 제목을 설정한 경우 전달                                     |                                       |
# | paymentTypeList    | List          | 결제 정보 목록                                                                      |                                       |
# | <p><br></p>        | paymentMethod | String                                                                        | 결제 수단 (상세 내용은 아래 paymentMethod 정의 참고) |
# | <p><br></p>        | amount        | String                                                                        | 결제 수단 별 금액                            |
# | billingKey         | String        | 확장 기능용 결제 키                                                                   |                                       |
# | isTestMdn          | Boolean       | 시험폰 여부(true : 시험폰, false : 시험폰 아님)                                            |                                       |
# | purchaseToken      | String        | 구매토큰                                                                          |                                       |
# | environment        | String        | <p>결제환경</p><ul><li>개발(샌드박스) : SANDBOX</li><li>상용 :COMMERCIAL</li></ul>        |                                       |
# | marketCode         | String        | 마켓 구분코드 ( MKT\_ONE : 원스토어, MKT\_STM : 스톰 )                                    |                                       |
# | signature          | String        | 본 메시지에 대한 signature                                                           |                                       |
# \
# **Example**
# ```
# {
# "msgVersion" : "3.1.0"
# "clientId":"0000000001",
# "productId":"0900001234",
# "messageType":"SINGLE_PAYMENT_TRANSACTION",
# "purchaseId":"SANDBOX3000000004564",
# "developerPayload":"OS_000211234",
# "purchaseTimeMillis":24431212233,
# "purchaseState":"COMPLETED",
# "price":"10000",
# "priceCurrencyCode":"KRW"
# "productName":"GOLD100(+20)"
# "paymentTypeList":[
# {
# "paymentMethod":"DCB",
# "amount":"3000"
# },
# {
# "paymentMethod":"ONESTORECASH",
# "amount":"7000"
# }
# ],
# "billingKey" : "36FED4C6E4AC9E29ADAF356057DB98B5CB92126B1D52E8757701E3A261AF49CCFBFC49F5FEF6E277A7A10E9076B523D839E9D84CE9225498155C5065529E22F5",
# "isTestMdn" : true,
# "purchaseToken" : "TOKEN...",
# "environment" : "SANDBOX",
# "marketCode" : "MKT_ONE"
# "signature" "SIGNATURE..."
# }
# ```
# \
# --- doc_index: 18 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Subscription Notification 메시지 발송 규격 (원스토어 → 개발사 서버) / **구독상태 정의**
#
# [요약]: **요약:**
#
# 구독 상태 코드와 설명 요약:
#
# - **SUBSCRIPTION_RECOVERED**: 정기 결제 복구 완료
# - **SUBSCRIPTION_RENEWED**: 정기 결제 갱신 성공
# - **SUBSCRIPTION_CANCELED**: 정기 결제 해지 요청
# - **SUBSCRIPTION_PURCHASED**: 새로운 정기 결제 상품 구매
# - **SUBSCRIPTION_ON_HOLD**: 결제 실패로 인한 보류 상태
# - **SUBSCRIPTION_IN_GRACE_PERIOD**: 결제 실패 후 유예 기간 진입
# - **SUBSCRIPTION_RESTARTED**: 정기 결제 해지 취소
# - **SUBSCRIPTION_PRICE_CHANGE_CONFIRMED**: 가격 변경 동의 완료
# - **SUBSCRIPTION_DEFERRED**: 정기 결제 기간 연장
# - **SUBSCRIPTION_PAUSED**: 정기 결제 일시 중지
# - **SUBSCRIPTION_PAUSE_SCHEDULE_CHANGED**: 일시 중지 일정 변경
# - **SUBSCRIPTION_REVOKED**: 정기 결제 즉시 해지
# - **SUBSCRIPTION_EXPIRED**: 정기 결제 만료
#
# **대표 용어**: 구독 상태 코드
#
# **키워드**: 구독 관리, 결제 상태 업데이트
#
# [원문]: | 구독 상태 | 구독 코드                                  | 설명                          |
# | ----- | -------------------------------------- | --------------------------- |
# | 1     | SUBSCRIPTION\_RECOVERED                | 정기 결제가 보류 상태에서 복구 되었습니다.    |
# | 2     | SUBSCRIPTION\_RENEWED                  | 정기 결제가 갱신 되었습니다.            |
# | 3     | SUBSCRIPTION\_CANCELED                 | 고객이 정기 결제 해지를 요청 하였습니다.     |
# | 4     | SUBSCRIPTION\_PURCHASED                | 새로운 정기 결제 상품이 구매 되었습니다.     |
# | 5     | SUBSCRIPTION\_ON\_HOLD                 | 결제 실패로 정기 결제가 보류 상태가 되었습니다. |
# | 6     | SUBSCRIPTION\_IN\_GRACE\_PERIOD        | 결제 실패로 정기 결제가 유예 상태가 되었습니다. |
# | 7     | SUBSCRIPTION\_RESTARTED                | 고객이 정기 결제 해지 요청을 취소 하였습니다.  |
# | 8     | SUBSCRIPTION\_PRICE\_CHANGE\_CONFIRMED | 사용자가 정기 결제 가격 변경에 동의 하였습니다. |
# | 9     | SUBSCRIPTION\_DEFERRED                 | 정기 결제 이용 기간이 연장 되었습니다.      |
# | 10    | SUBSCRIPTION\_PAUSED                   | 정기 결제가 일시 중지 되었습니다.         |
# | 11    | SUBSCRIPTION\_PAUSE\_SCHEDULE\_CHANGED | 정기 결제 일시 중지 일정이 변경 되었습니다.   |
# | 12    | SUBSCRIPTION\_REVOKED                  | 정기 결제가 즉시 해지 되었습니다.         |
# | 13    | SUBSCRIPTION\_EXPIRED                  | 정기 결제가 만료 되었습니다.            |
# \
# --- doc_index: 19 ---
# [제목]: 12. Unity에서 원스토어 인앱결제 (SDK V21) 사용하기 / 게임에서 원스토어 인앱 결제 라이브러리 적용하기 / 구매 요청하기
#
# [요약]: **요약:**
#
# **구매 프로세스 요약 (OneStore)**
#
# - 앱에서 구매 요청 시 `Purchase()` 함수 호출.
# - `QueryProductDetails()` API를 통해 얻은 `ProductDetail` 정보로 `PurchaseFlowParams` 생성.
# - `SetDeveloperPayload()`, `SetProductName()`, `SetQuantity()` 등 옵션 파라미터 설정 가능.
# - 프로모션 참여 여부 확인을 위해 `gameUserId`, `promotionApplicable` 사용 (사전 협의 필요).
# - 구매 성공 시 `IPurchaseCallback.OnPurchaseSucceeded()`, 실패 시 `OnPurchaseFailed()` 호출.
# - 구매 토큰 생성 및 보안을 위해 백엔드 서버로 전송 권장.
# - 영수증 이메일 발송 (관리형 상품 및 정기 결제 상품에 대해).
#
# **키워드:** 구매 플로우, 토큰 보안, 영수증 이메일, 관리형 상품
#
# [원문]: 앱에서 구매 요청을 하기 위해서는 기본 스레드에서 `Purchase()` 함수를 호출합니다.
# `QueryProductDetails()` API를 호출해서 얻은 `ProductDetail` 객체의 값을 토대로 `PurchaseFlowParams` 객체를 생성합니다.\
# `PurchaseFlowParams` 객체를 생성하려면 `PurchaseFlowParams.Builder` 클래스를 사용합니다.
# `SetDeveloperPayload()`는 개발사에서 임의로 입력한 값으로 최대 `200byte`입니다. 이 값은 결제 후에 데이터의 정합성과 부가 데이터를 확인하기 위해 사용할 수 있습니다.\
# `SetProductName()`은 상품 이름을 결제 시 변경하여 노출하고 싶을 때 사용됩니다.\
# `SetQuantity()`는 관리형 인앱 상품에만 적용되며 한 상품을 여러 개 구매할 때 사용됩니다.
# {% hint style="success" %}
# 원스토어는 사용자에게 할인 쿠폰, 캐시백 등의 다양한 혜택 프로모션을 진행하고 있습니다.\
# 개발사는 구매 요청 시에 `gameUserId`, `promotionApplicable` 파라미터를 이용하여 앱을 사용하는 유저의 프로모션 참여를 제한하거나 허용할 수 있습니다.\
# 개발사는 앱의 고유한 유저 식별 번호 및 프로모션 참여 여부를 선택하여 전달하고, 원스토어는 이 값을 토대로 사용자의 프로모션 혜택을 적용하게 됩니다.
# {% endhint %}
# {% hint style="warning" %}
# `gameUserId`, `promotionApplicable` 파라미터는 옵션 값으로 원스토어 사업 부서 담당자와 프로모션에 대해 사전협의가 된 상태에서만 사용하여야 하며, 일반적인 경우에는 값을 보내지 않습니다.\
# 또한, 사전협의가 되어 값을 보낼 경우에도 개인 정보보호를 위해 `gameUserId`는 `hash`된 고유한 값으로 전송하여야 합니다.
# {% endhint %}
# ```csharp
# using OneStore.Purchasing;
#
# ProductDetail productDetail = ...
# ProductType productType = ProductType.Get(productDetail.type);
#
# var purchaseFlowParams = new PurchaseFlowParams.Builder()
# .SetProductId(productId)                // mandatory
# .SetProductType(productType)            // mandatory
# .SetDeveloperPayload(developerPayload)  // optional
# .SetQuantity(quantity)                  // optional
# // .SetProductName(null)                // optional: Change the name of the product to appear on the purchase screen.
#
# // It should be used only in advance consultation with the person in charge of the One Store business, and is not normally used.
# // .SetGameUserId(null)                 // optional: User ID to use for promotion.
# // .SetPromotionApplicable(false)       // optional: Whether to participate in the promotion.
# .Build();
#
# purchaseClient.Purchase(purchaseFlowParams);
# ```
# `Purchase()` 호출에 성공하면 아래와 같은 화면을 표시합니다. **\[그림 1]**&#xC740; 관리형 상품 구매 화면을 나타냅니다.\
# <figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2FQlQqSb2MeYLL9LZvqvAT%2Fimage.png?alt=media&#x26;token=dfbde249-6cb3-461e-abc8-a8d830f41d46" alt=""><figcaption><p>[그림 1] </p></figcaption></figure>
# 구매에 성공하면 `IPurchaseCallback.OnPurchaseSucceeded()` 함수에 결과를 전송합니다.\
# 실패 시에는 `IPurchaseCallback.OnPurchaseFailed()` 함수가 호출됩니다.
# ```csharp
# using OneStore.Purchasing;
#
# // IPurchaseCallback implementations
# public void OnPurchaseSucceeded(List purchases)
# {
# handlePurchase(purchases);
# }
#
# public void OnPurchaseFailed(IapResult iapResult)
# {
# ...
# }
# ```
# \
# 구매가 성공하면 구매 데이터에는 사용자 및 상품 ID를 나타내는 고유 식별자인 구매 토큰도 생성됩니다. 구매 토큰을 앱 내에 저장할 수 있지만 구매를 인증하고 사기로부터 보호할 수 있는 백엔드 서버로 토큰을 전달하는 것이 좋습니다.
# <figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2F7QWzCSwkc5tCI8ZTdTqM%2Fimage.png?alt=media&#x26;token=a5d9347e-c6b9-4b60-bc37-1ddbeae24270" alt=""><figcaption></figcaption></figure>
# 관리형 상품과 정기 결제 상품의 구매 토큰은 결제가 일어날 때마다 구매 토큰이 발행됩니다. (월 정액 상품의 경우 자동 결제가 갱신되는 동안 구매 토큰은 동일하게 유지됩니다.)
# 또한 사용자는 영수증 번호가 포함된 거래 영수증을 이메일로 받습니다. 관리형 상품은 구매할 때마다 이메일을 받으며, 월 정액 상품과 정기 결제 상품은 처음 구매 시 그리고 이후 갱신될 때마다 이메일을 받습니다.
# --- doc_index: 20 ---
# [제목]: PurchaseData.AcknowledgeState
#
# [요약]: **요약:**
#
# `PurchaseData.AcknowledgeState`는 구매 확인 상태를 나타내는 인터페이스로, 구매 프로세스의 검증 및 승인 단계를 관리합니다. 이 상태값은 구매 요청의 정확성과 유효성을 확인하는데 필수적입니다. 주요 상태 코드들은 구매 확인 과정에서의 다양한 단계를 반영합니다.
#
# **대표 키워드:** PurchaseData, AcknowledgeState, 구매확인 상태
#
# [원문]: ```
# public static @interface PurchaseData.AcknowledgeState
# ```
# ```
# com.gaa.sdk.iap.PurchaseData.AcknowledgeState
# ```
# 구매확인에 대한 상태값
# --- doc_index: 21 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **개요**
#
# [요약]: **요약:**
#
# PNS (Payment Notification Service)는 네트워크 불안정성을 보완하기 위해 원스토어가 개발사 서버로 결제 상태(완료, 취소)를 전송하는 서버 간 통신 시스템입니다. 이 시스템은 인앱 결제 및 구독 상태 변경 시 알림을 보내며, 테스트 결제 건도 포함됩니다. 개발사는 이 알림을 통해 결제 트랜잭션 상태를 확인할 수 있지만, 실제 서비스 제공은 알림 수신보다는 직접 API 조회를 권장합니다. 주요 키워드: PNS, 결제 알림, 서버 간 통신, 구독 상태 변경
#
# **대표 키워드:** PNS, 결제 알림 서비스
#
# [원문]: PNS는 Payment Notification Service의 약자입니다. PNS는 모바일의 네트워크 연결 불안정성을 보완하기 위해 개발사가 지정한 서버로 원스토어의 서버가 개별 사용자의 결제 상태(결제 완료, 결제 취소)를 메시지로 전송하여 결제 트랜젝션의 상태를 손실없이 알려주기 위한 용도의 기능입니다. 즉, 개발사가 지정한 서버에서 원스토어가 정의한 규칙에 맞추어 API를 구현하면 해당 API를 원스토어의 결제 담당 서버에서 호출하는 형태입니다.
# Server to Server, 즉 서버간에 데이터를 전송한다고 할지라도 네트워크 문제로 메세지 전송 실패가 발생하기 때문에 200 OK로 응답을 인지하지 못할 경우 반복하여 메시지가 전송될 수 있습니다. 개발사의 서버는 메시지를 수신후 정의된 응답을 하여야 원스토어는 개발사 서버가 정상적으로 메시지를 전달 받았음을 인지합니다.
# 결제 트렌젝션의 유형에 따라 아래와 같은 유형의 메세지가 전송됩니다.
# * 인앱상품 결제 또는 결제취소가 발생하면 원스토어가 개발사 서버로 알림을 전송하는 PNS(Payment Notification Service)&#x20;
# * 구독 상태가 변경되면 개발사 서버로 알림을 전송하는 SNS (Subscription Notifacation Service)&#x20;
# {% hint style="warning" %}
# Notification은 발송/수신 서버의 상태에 따라 지연 또는 유실될 수 있으므로, notification 수신을 기준으로 상품(서비스)을 제공하는 것은 권장하지 않습니다.&#x20;
# 정상적인 결제 건인지 Server to Server로 확인하기를 원하신다면 PNS notification을 이용하는 대신, 관련 서버 API로 조회하는 것을 권장합니다.
# 원스토어는 검증 및 모니터링 목적으로 결제 테스트를 진행할 수 있으며, 해당 테스트 건들도 결제/결제취소 시 동일하게 notification이 발송됩니다. 원스토어가 진행한 결제 테스트 내역은 주기적으로 원스토어에서 자체 취소 처리합니다.
# {% endhint %}
# --- doc_index: 22 ---
# [제목]: PurchaseClient.ResponseCode / Constants <a href="#id-a-purchaseclient.responsecode-constants" id="id-a-purchaseclient.responsecode-constants"></a> / RESULT\_EMERGENY\_ERROR <a href="#id-a-purchaseclient.responsecode-result_emergeny_error" id="id-a-purchaseclient.responsecode-result_emergeny_error"></a>
#
# [요약]: **요약:**
#
# **EmergencyError (RESULT_EMERGENY_ERROR)**: 서버 점검 중 상태를 나타내며, 코드 값은 `99999`입니다. 이 상태는 개발자와 운영팀에게 즉시 서버 상태 확인이 필요함을 알리는 중요한 지표입니다.
#
# **키워드**: EmergencyError, 서버점검, 상태코드
#
# [원문]: ```
# int RESULT_EMERGENY_ERROR
# ```
# 서버 점검중입니다.
# Constant Value: 99999
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/references/annotations/purchasedata.acknowledgestate.md
# --- doc_index: 23 ---
# [제목]: PurchaseClient.ConnectionState / Constants <a href="#id-a-purchaseclient.connectionstate-constants" id="id-a-purchaseclient.connectionstate-constants"></a> / CLOSED <a href="#id-a-purchaseclient.connectionstate-closed" id="id-a-purchaseclient.connectionstate-closed"></a>
#
# [요약]: **요약:**
#
# **API 문서 요약:**
#
# **API 이름:** OnePay API
# **주요 기능:** 결제 요청 및 결과 처리
# **요청 타입:** REST API
# ** ** **
# - **결제 요청:**
#   - **엔드포인트:** `/payment`
#   - **방법:** POST
#   - **요청 파라미터:** 결제 정보 (금액, 상품 정보 등)
#   - **응답:** 결제 요청 확인 메시지 및 토큰 반환
#
# - **결제 응답 처리:**
#   - **방법:**
#     - **리턴 URL 방식:** 결제 결과 페이지로 리다이렉트 (`returnUrl` 파라미터 사용)
#     - **콜백 URL 방식:** JSON 형식으로 결제 결과 전달 (`callbackUrl` 파라미터 사용)
#   - **응답 코드:**
#     - `Success`: 결제 성공
#     - `Fail`: 결제 실패 (오류 메시지 포함)
#     - `UserCancel`: 사용자 취소
#     - `PaymentTimeExpired`: 결제 시간 만료
#
# **주요 키워드:** OnePay API, 결제 요청, 결제 응답, REST API, 리턴 URL, 콜백 URL, 응답 코드
#
# **문서 키워드:** OnePay API 결제 처리 문서
#
# [원문]: ```
# int CLOSED
# ```
# 서비스의 연결이 이미 닫혔으므로 다시 사용하면 안됩니다.
# Constant Value: 3
# --- doc_index: 24 ---
# [제목]: PurchaseClient / Public methods <a href="#id-c-purchaseclient-publicmethods" id="id-c-purchaseclient-publicmethods"></a> / isFeatureSupported <a href="#id-c-purchaseclient-isfeaturesupported" id="id-c-purchaseclient-isfeaturesupported"></a>
#
# [요약]: **요약:**
#
# `@UiThread` 메서드 `IapResultisFeatureSupported`는 지정된 기능(`PurchaseClient.FeatureType` 상수)이 현재 서비스에서 지원되는지 확인합니다. 기능이 지원되면 `RESULT_OK`, 그렇지 않으면 `ERROR_FEATURE_NOT_SUPPORTED`를 반환합니다. 이 메서드는 서비스 기능 지원 여부를 빠르게 검사하는 데 사용됩니다.
#
# **키워드:** IAP, 기능지원 확인, PurchaseClient
#
# [원문]: ```
# @UiThread
# public abstract[C]IapResultisFeatureSupported(String feature)
# ```
# 지정한  기능이 서비스에서 지원 되는지 확인합니다.
# | **Parameters:** |                                                                                                                               |
# | --------------- | ----------------------------------------------------------------------------------------------------------------------------- |
# | String          | [PurchaseClient.FeatureType](../annotations/purchaseclient.featuretype) 상수 중 하나 입니다.                                          |
# | **Returns:**    |                                                                                                                               |
# | IapResult       | <p>기능이 지원되는 경우 PurchaseClient.ResponseCode.RESULT_OK<br>그렇지 않을 경우 PurchaseClient.ResponseCode.ERROR_FEATURE_NOT_SUPPORTED</p> |
# --- doc_index: 25 ---
# [제목]: 04. 원스토어 인앱결제 SDK를 사용해 구현하기 / 인앱 라이브러리 적용하기 / 구매 요청하기 <a href="#id-04.-sdk" id="id-04.-sdk"></a>
#
# [요약]: **요약:**
#
# 구매 플로우 처리를 위해 앱은 `launchPurchaseFlow()` 함수를 호출하며, 이 과정에서 `PurchaseFlowParams` 객체를 생성합니다. 이 객체는 상품 정보와 함께 개발자 페이로드, 상품 수량, 상품 이름, 사용자 ID 및 프로모션 적용 여부 등의 옵션 파라미터를 설정할 수 있습니다. 구매 요청이 성공하면 사용자에게 결제 완료 화면이 표시되고, 성공 시 구매 토큰과 영수증 이메일이 제공됩니다. 주요 키워드: PurchaseFlowParams, launchPurchaseFlow, 구매 토큰, 영수증 이메일, 프로모션 적용.
#
# [원문]: 앱에서 구매 요청을 하기 위해서는 기본 스레드에서 `launchPurchaseFlow()` 함수를 호출합니다.
# 이 함수는 `queryProductDetailsAsync()` 함수를 호출해서 얻은 `ProductDetail` 객체의 값을 토대로 `PurchaseFlowParams` 객체를 생성합니다.\
# `PurchaseFlowParams` 객체를 생성하려면 `PurchaseFlowParams.Builder` 클래스를 사용합니다.
# `setDeveloperPayload()`는 개발사에서 임의로 입력한 값으로 최대 200byte입니다. 이 값은 결제 후에 데이터의 정합성과 부가 데이터를 확인하기 위해 사용할 수 있습니다.\
# `setProductName()`은 상품 이름을 결제 시 변경하여 노출하고 싶을 때 사용됩니다.\
# `setQuantity()`는 관리형 인앱 상품에만 적용되며 한 상품을 여러 개 구매할 때 사용됩니다.
# {% hint style="success" %}
# 원스토어는 사용자에게 할인 쿠폰, 캐시백 등의 다양한 혜택 프로모션을 진행하고 있습니다.\
# 개발사는 구매 요청 시에 `gameUserId`, `promotionApplicable` 파라미터를 이용하여 앱을 사용하는 유저의 프로모션 참여를 제한하거나 허용할 수 있습니다.\
# 개발사는 앱의 고유한 유저 식별 번호 및 프로모션 참여 여부를 선택하여 전달하고, 원스토어는 이 값을 토대로 사용자의 프로모션 혜택을 적용하게 됩니다.
# {% endhint %}
# {% hint style="warning" %}
# `gameUserId`, `promotionApplicable` 파라미터는 옵션 값으로 원스토어 사업 부서 담당자와 프로모션에 대해 사전협의가 된 상태에서만 사용하여야 하며, 일반적인 경우에는 값을 보내지 않습니다.\
# 또한, 사전협의가 되어 값을 보낼 경우에도 개인 정보보호를 위해 `gameUserId`는 _has&#x68;_&#xB41C; 고유한 값으로 전송하여야 합니다.
# {% endhint %}
# {% tabs %}
# {% tab title="Kotlin" %}
# ```kotlin
# val activity: Activity = ...
#
# val purchaseFlowParams = PurchaseFlowParams.newBuilder()
# .setProductId(productId)
# .setProductType(productType)
# .setDeveloperPayload(devPayload)    // optional
# .setQuantity(1)                     // optional
# .setProductName("")                 // optional
# .setGameUserId("")                  // optional
# .setPromotionApplicable(false)      // optional
# .build()
#
# purchaseClient.launchPurchaseFlow(activity, purchaseFlowParams)
# ```
# {% endtab %}
# {% tab title="Java" %}
# ```java
# Activity activity = ...
#
# PurchaseFlowParams purchaseFlowParams = PurchaseFlowParams.newBuilder()
# .setProductId(productId)
# .setProductType(productType)
# .setDeveloperPayload(devPayload)    // optional
# .setQuantity(1)                     // optional
# .setProductName("")                 // optional
# .setGameUserId("")                  // optional
# .setPromotionApplicable(false)      // optional
# .build();
#
# purchaseClient.launchPurchaseFlow(activity, purchaseFlowParams);
# ```
# {% endtab %}
# {% endtabs %}
# `launchPurchaseFlow()` 호출에 성공하면 아래와 같은 화면을 표시합니다. \[그림 1]은 정기 결제 구매 화면을 나타냅니다.
# <figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2F2Lkq8XusttkJ8sImrM8C%2F2.png?alt=media&#x26;token=9da3eb3f-02b1-45f9-9727-2c200068c65d" alt=""><figcaption><p>그림 1</p></figcaption></figure>
# 구매에 성공하면 `PurchasesUpdatedListener` 인터페이스의 `onPurchasesUpdated()` 함수에 구매 작업 결과가 전송됩니다. 이 리스너는 [PurchaseClient 초기화](#id-04.-sdk-purchaseclient) 할 때 `setListener()` 함수를 사용하여 지정됩니다.
# {% tabs %}
# {% tab title="Kotlin" %}
# ```kotlin
# override fun onPurchasesUpdated(iapResult: IapResult, purchases: List<PurchaseData>?) {
# if (iapResult.isSuccess && purchases != null) {
# for (purchase in purchases) {
# handlePurchase(purchase)
# }
# } else if (iapResult.responseCode == ResponseCode.NEED_UPDATE) {
# // PurchaseClient by calling the launchUpdateOrInstallFlow() method.
# } else if (iapResult.responseCode == ResponseCode.NEED_LOGIN) {
# // PurchaseClient by calling the launchLoginFlow() method.
# } else {
# // Handle any other error codes.
# }
# }
# ```
# {% endtab %}
# {% tab title="Java" %}
# ```java
# @Override
# public void onPurchasesUpdated(IapResult iapResult, List<PurchaseData> purchases) {
# if (iapResult.isSuccess() && purchases != null) {
# for (purchase in purchases) {
# handlePurchase(purchase);
# }
# } else if (iapResult.getResponseCode() == ResponseCode.NEED_UPDATE) {
# // PurchaseClient by calling the launchUpdateOrInstallFlow() method.
# } else if (iapResult.getResponseCode() == ResponseCode.NEED_LOGIN) {
# // PurchaseClient by calling the launchLoginFlow() method.
# } else {
# // Handle any other error codes.
# }
# }
# ```
# {% endtab %}
# {% endtabs %}
# <figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2F58l823PfVJNsedj5q9sw%2F3.png?alt=media&#x26;token=f7c93cc2-cc7b-482d-af7f-3b491fb92cd8" alt=""><figcaption><p>그림 2</p></figcaption></figure>
# 구매가 성공하면 구매 데이터에는 사용자 및 상품 ID를 나타내는 고유 식별자인 구매 토큰도 생성됩니다. 구매 토큰을 앱 내에 저장할 수 있지만 구매를 인증하고 사기로부터 보호할 수 있는 백엔드 서버로 토큰을 전달하는 것이 좋습니다.
# 관리형 상품과 정기 결제 상품의 구매 토큰은 결제가 일어날 때마다 구매 토큰이 발행됩니다. (월정액 상품의 경우 자동 결제가 갱신되는 동안 구매 토큰은 동일하게 유지됩니다.)
# 또한 사용자는 영수증 번호가 포함된 거래 영수증을 이메일로 받습니다. 관리형 상품은 구매할 때마다 이메일을 받으며, 월정액 상품과 정기 결제 상품은 처음 구매 시 그리고 이후 갱신될 때마다 이메일을 받습니다.
# --- doc_index: 26 ---
# [제목]: PurchaseClient.ConnectionState / Constants <a href="#id-a-purchaseclient.connectionstate-constants" id="id-a-purchaseclient.connectionstate-constants"></a> / CONNECTED <a href="#id-a-purchaseclient.connectionstate-connected" id="id-a-purchaseclient.connectionstate-connected"></a>
#
# [요약]: **요약:**
#
# 현재 서비스는 `CONNECTED` 상태로, 사용자와의 안정적인 연결을 유지하고 있습니다 (Constant Value: 2). 이 상태는 서비스의 지속적인 가용성과 사용자 요청 처리 능력을 보장합니다. 키워드: CONNECTED, 서비스 가용성
#
# **참고 키워드:** CONNECTED 상태, 서비스 연결 품질
#
# [원문]: ```
# int CONNECTED
# ```
# 현재 서비스와 연결된 상태입니다.
# Constant Value: 2
# --- doc_index: 27 ---
# [제목]: 07. PNS(Payment Notification Service) 이용하기 / **PNS 상세** / PNS Payment Notification 메시지 발송 규격 (원스토어 → 개발사 서버) / **Signature 검증 방법**
#
# [요약]: **요약:**
#
# 결제 시스템 문서는 결제 프로세스, 보안 서명 검증 방법, 그리고 다양한 프로그래밍 언어(Java, PHP, Python)를 활용한 서명 위변조 확인 코드를 포함하고 있습니다. 특히, `verify` 함수는 JSON 메시지의 서명을 공개키로 검증하여 결제 거래의 무결성을 보장합니다. 주요 키워드: 결제 프로세스, 서명 검증, 보안, API 참조.
#
# [원문]: 아래 코드를 사용하면 signature에 대한 위변조 여부를 확인할 수 있습니다.
# * 코드 내 PublicKey는 '라이선스 관리'에서 제공되는 라이선스 키를 의미합니다.
# {% tabs %}
# {% tab title="Java" %}
# ```
# import java.security.PublicKey;
#
# import org.apache.commons.codec.binary.Base64;
# import org.codehaus.jackson.JsonNode;
# import org.codehaus.jackson.map.ObjectMapper;
# import org.codehaus.jackson.node.ObjectNode;
#
#
# public class SignatureVerifier {
#
# private static final String SIGN_ALGORITHM = "SHA512withRSA";
# private ObjectMapper mapper = new ObjectMapper();
#
#
# boolean verify(String rawMsg, PublicKey key) throws Exception {
# // JSON 메시지에서 signature를 추출한다.
# JsonNode root = mapper.readTree(rawMsg);
# String signature = root.get("signature").getValueAsText();
# ((ObjectNode)root).remove("signature");
#
# // 추출한 signature가 올바른 값인지 검증한다.
# Signature sign = Signature.getInstance(SIGN_ALGORITHM);
# sign.initVerify(key);
# sign.update(root.toString().getBytes("UTF-8"));
# return sign.verify(Base64.decodeBase64(signature));
# }
# }
# ```
# {% endtab %}
# {% tab title="PHP" %}
# ```
# <?php
# function formatPublicKey($publicKey) {
# $BEGIN= "-----BEGIN PUBLIC KEY-----";
# $END = "-----END PUBLIC KEY-----";
#
# $pem = $BEGIN . "\n";
# $pem .= chunk_split($publicKey, 64, "\n");
# $pem .= $END . "\n";
#
# return $pem;
# }
#
# function formatSignature($signature) {
# return base64_decode(chunk_split($signature, 64, "\n"));
# }
#
# // Sample message
# $sampleMessage = '{"msgVersion":"3.1.0D","purchaseId":"SANDBOX3000000004564","developerPayload":"OS_000211234","clientId":"0000000001","productId":"0900001234","messageType":"SINGLE_PAYMENT_TRANSACTION","purchaseMillis":24431212233,"purchaseState":"COMPLETED","price":20000,"productName":"한글은?GOLD100(+20)","paymentTypeList":[{"paymentMethod":"DCB","amount":3000},{"paymentMethod":"ONESTORECASH","amount":7000}],"billingKey":"36FED4C6E4AC9E29ADAF356057DB98B5CB92126B1D52E8757701E3A261AF49CCFBFC49F5FEF6E277A7A10E9076B523D839E9D84CE9225498155C5065529E22F5","isTestMdn":true,"signature":"MNxIl32ws+yYWpUr7om+jail4UQxBUXdNX5yw5PJKlqW2lurfvhiqF0p4XWa+fmyV6+Ot63w763Gnx2+7Zp2Wgl73TWru5kksBjqVJ3XqyjUHDDaF80aq0KvoQdLAHfKze34cJXKR/Qu8dPHK65PDH/Vu6MvPVRB8TvCJpkQrqg="}';
#
# // Sample public key
# $publicKey = "MIGfMA0GCSqGSIb3DQEBAQUAA4GNADCBiQKBgQDMzpWJoK1GSOrr4juma5+sREYjdCW8/xSd9+6z6PAkUH5af97wy8ecfkLtP9LK5VskryfDlcOjfu0BgmHYntAqKT7B4KWk8jWbJ8VHUpp30H95UbcnCRFDqpEtwYzNA5gNMYKtAdbL41K8Fbum0Xqxo65pPEI4UC3MAG96O7X1WQIDAQAB";
#
#
# // Parse JSON message
# $jsonArr = json_decode($sampleMessage, true);
#
# // Extract and remove signature
# $signature = $jsonArr["signature"];
# unset($jsonArr["signature"]);
# $originalMessage = json_encode($jsonArr, JSON_UNESCAPED_UNICODE);
#
# // Veify
# $formattedKey = formatPublicKey($publicKey);
# $formattedSign = formatSignature($signature);
# $hash_algorithm = 'sha512';
#
# $success = openssl_verify($originalMessage, $formattedSign, $formattedKey, $hash_algorithm);
# if ($success == 1) {
# echo "verified";
# }
# else {
# echo "unverified";
# }
# ?>
# ```
# {% endtab %}
# {% tab title="Python" %}
# {% code overflow="wrap" %}
# ```
# # -*- coding: utf-8 -*-
#
# import json
# from base64 import b64decode
# from collections import OrderedDict
#
# from Crypto.Hash import SHA512
# from Crypto.PublicKey import RSA
# from Crypto.Signature import PKCS1_v1_5
#
# import sys
# reload(sys)
# sys.setdefaultencoding('utf-8')
#
# hash = "SHA-512"
#
#
# def verify(message, signature, pub_key):
# signer = PKCS1_v1_5.new(pub_key)
# digest = SHA512.new()
# digest.update(message)
# return signer.verify(digest, signature)
#
#
# jsonData = json.loads(rawMsg, encoding='utf-8', object_pairs_hook=OrderedDict)
# signature = jsonData['signature']
# del jsonData['signature']
# originalMessage = json.dumps(jsonData, ensure_ascii=False, encoding='utf-8', separators=(',', ':'))
#
# RSA.importKey(publickey).publickey()
# print(verify(originalMessage, b64decode(signature), RSA.importKey(publickey).publickey()))
# ```
# {% endcode %}
# {% endtab %}
# {% endtabs %}
# --- doc_index: 28 ---
# [제목]: PurchaseData.AcknowledgeState / Constants <a href="#id-a-purchasedata.acknowledgestate-constants" id="id-a-purchasedata.acknowledgestate-constants"></a> / ACKNOWLEDGED <a href="#id-a-purchasedata.acknowledgestate-acknowledged" id="id-a-purchasedata.acknowledgestate-acknowledged"></a>
#
# [요약]: **요약:**
#
# **ACKN** - 구매 확인 처리 상태 문서 요약
#
# 이 문서는 OneStore 결제 API 버전 21의 구매 데이터 처리 방법을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **구매 데이터 구조**: 구매 정보, 결제 정보, 개발자 페이로드 등 다양한 필드에 대한 설명.
# 2. **상태 코드**: 구매 상태를 나타내는 코드와 그 의미 (예: ACKNOWLEDGED - 구매 확인 됨).
# 3. **결제 프로세스**: 표준 결제 화면 구현 방법과 결제 결과 전달 방식 (returnUrl, callbackUrl).
# 4. **응답 코드**: 결제 성공, 실패 등 다양한 응답 코드와 그 의미 설명.
#
# **키워드**: 구매 데이터, 결제 API, 상태 코드, 결제 프로세스, 응답 코드
#
# [원문]: ```
# int ACKNOWLEDGED
# ```
# 구매확인 됨
# Constant Value: 1
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/references/annotations/purchasedata.purchasestate.md
# --- doc_index: 29 ---
# [제목]: PurchaseClient / Public methods <a href="#id-c-purchaseclient-publicmethods" id="id-c-purchaseclient-publicmethods"></a> / startConnection <a href="#id-c-purchaseclient-startconnection" id="id-c-purchaseclient-startconnection"></a>
#
# [요약]: **요약:**
#
# `startConnection` 메서드는 PurchaseClient 설정 프로세스를 비동기적으로 시작하며, 완료 시 [PurchaseClientStateListener] 리스너를 통해 응답을 제공합니다. 이 메서드는 결제 모듈 연결 완료를 감지하고 알림을 제공하는 데 사용됩니다.
#
# **대표 키워드:**
# PurchaseClient, 비동기 시작, 결제 모듈 연결 완료
#
# 이 요약은 문서의 핵심 기능과 목적을 간결하게 전달하며, 검색 품질 향상에 기여할 수 있습니다.
#
# [원문]: ```
# @AnyThread
# public abstractvoidstartConnection([I]PurchaseClientStateListener listener)
# ```
# PurchaseClient 설정 프로세스를 비동기적으로 시작합니다.\
# 완료되면 [\[I\]PurchaseClientStateListener](../interfaces/purchaseclientstatelistener)를 통해 응답 받습니다.
# | **Parameters:** |                                                |
# | --------------- | ---------------------------------------------- |
# | listener        | PurchaseClient 설정과 결제모듈 연결이 완료 되었을 때 응답을 받습니다. |
# --- doc_index: 30 ---
# [제목]: ProductDetailsParams / Public methods <a href="#id-c-productdetailsparams-publicmethods" id="id-c-productdetailsparams-publicmethods"></a>
#
# [요약]: **요약:**
#
# API 문서는 원스토어 결제 시스템의 상세한 API 사용법을 설명하고 있습니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 요청**: 결제 요청을 위한 요청 파라미터와 서명 검증 방법 설명.
# 2. **결제 응답 처리**: 결제 성공 시 반환 URL 또는 콜백 URL을 통해 결과를 개발자에게 전달하는 방법.
# 3. **응답 코드**: 결제 결과를 나타내는 다양한 응답 코드와 메시지 설명 (예: Success, Fail, UserCancel 등).
#
# **대표 키워드**: 결제 API, 서명 검증, 응답 처리, 결제 결과 확인
#
# [원문]: ***
# --- doc_index: 31 ---
# [제목]: PurchaseClient / Public methods <a href="#id-c-purchaseclient-publicmethods" id="id-c-purchaseclient-publicmethods"></a> / getConnectionState <a href="#id-c-purchaseclient-getconnectionstate" id="id-c-purchaseclient-getconnectionstate"></a>
#
# [요약]: **요약:**
#
# `PurchaseClient` 클래스는 구매 클라이언트의 연결 상태를 추상적으로 반환하는 `getConnectionState()` 메서드를 제공합니다. 이 메서드는 `PurchaseClient.ConnectionState` 열거형 값을 반환하여 현재 연결 상태를 나타냅니다. 주요 키워드: PurchaseClient, ConnectionState
#
# **요약 키워드:** PurchaseClient, 연결상태
#
# [원문]: ```
# @AnyThread
# public abstract int getConnectionState()
# ```
# 현재 PurchaseClient 의 연결상태를 반환합니다.
# | Returns: |                                                                                              |
# | -------- | -------------------------------------------------------------------------------------------- |
# | int      | [PurchaseClient.ConnectionState](../annotations/purchaseclient.connectionstate) 에 해당하는 상태 값. |
# --- doc_index: 32 ---
# [제목]: PurchaseClient.FeatureType / Constants <a href="#id-a-purchaseclient.featuretype-constants" id="id-a-purchaseclient.featuretype-constants"></a>
#
# [요약]: **요약:**
#
# API 문서는 원스토어 결제 시스템의 상세한 API 사용법을 설명합니다. 주요 내용은 다음과 같습니다:
#
# - **결제 요청**: 결제 요청을 위한 요청 파라미터와 서명 검증 방법 설명.
# - **결제 응답**: 결제 결과를 전달하는 두 가지 방식 (`returnUrl`, `callbackUrl`)에 대한 세부 사항 포함.
# - **응답 코드**: 결제 성공 및 실패 시의 응답 코드와 메시지 목록 제공.
#
# **대표 키워드:** 결제 API, 서명 검증, 응답 처리, 결제 결과 전달
#
# 이 요약은 문서의 핵심 내용을 간결하게 전달하여 검색 및 이해를 돕습니다.
#
# [원문]: ***
# --- doc_index: 33 ---
# [제목]: PurchaseClient.ResponseCode / Constants <a href="#id-a-purchaseclient.responsecode-constants" id="id-a-purchaseclient.responsecode-constants"></a> / RESULT\_NOT\_SUPPORT\_SANDBOX <a href="#id-a-purchaseclient.responsecode-result_not_support_sandbox" id="id-a-purchaseclient.responsecode-result_not_support_sandbox"></a>
#
# [요약]: **요약:**
#
# **API 버전 및 상수:**
# - `RESULT_NOT_SUPPORT_SANDBOX` 상수는 테스트 환경에서 지원하지 않는 기능을 나타내며, 값은 `14`입니다.
#
# **API 문서 주요 내용:**
# - **결제 API 버전:** 2.0
# - **결제 상태 확인 엔드포인트:** `/payment/v2/status`
# - **결제 결과 확인 엔드포인트:** `/payment/v2/result`
# - **결제 관련 응답 코드 및 메시지:** 성공, 실패, 사용자 취소, 결제 시간 만료 등 다양한 응답 상태 설명 포함.
# - **결제 프로세스:** 표준 결제 화면 오픈 및 결제 결과 개발사로 전달 방식 설명 (`returnUrl`, `callbackUrl`).
#
# **키워드:** 결제_API_v2_결과 확인
#
# [원문]: ```
# int RESULT_NOT_SUPPORT_SANDBOX
# ```
# 테스트 환경에서는 지원하지 않는 기능입니다.
# Constant Value: 14
# --- doc_index: 34 ---
# [제목]: PurchaseClient.ProductType / Constants <a href="#id-a-purchaseclient.producttype-constants" id="id-a-purchaseclient.producttype-constants"></a>
#
# [요약]: **요약:**
#
# API 문서는 원스토어 결제 시스템의 상세한 API 사용법을 설명합니다. 주요 내용은 다음과 같습니다:
#
# - **결제 요청**: 결제 요청을 위한 요청 파라미터와 서명 검증 방법 설명.
# - **결제 응답**: 결제 결과를 전달하는 두 가지 방식 (`returnUrl`, `callbackUrl`)에 대한 세부 사항 포함.
# - **응답 코드**: 결제 성공 및 실패 시의 응답 코드와 메시지 목록 제공.
#
# **대표 키워드:** 결제 API, 서명 검증, 응답 처리, 결제 결과 전달
#
# 이 요약은 문서의 핵심 내용을 간결하게 전달하여 검색 및 이해를 돕습니다.
#
# [원문]: ***
# --- doc_index: 35 ---
# [제목]: PurchaseData.RecurringState / Constants <a href="#id-a-purchasedata.recurringstate-constants" id="id-a-purchasedata.recurringstate-constants"></a> / CANCEL <a href="#id-a-purchasedata.recurringstate-cancel" id="id-a-purchasedata.recurringstate-cancel"></a>
#
# [요약]: **요약문:**
#
# CANCEL 상수는 자동 결제 해지 예약 상태를 나타내며, 값은 1입니다. 이 기능은 사용자가 결제를 취소하거나 일정 시간 후 자동으로 결제를 종료하도록 설정할 때 활용됩니다. 주요 키워드: 자동 결제 해지, CANCEL (상수 값: 1)
#
# **대표 키워드:** 자동결제 해지 예약, CANCEL
#
# [원문]: ```
# int CANCEL
# ```
# 자동 결제 해지 예약중
# Constant Value: 1
# --- doc_index: 36 ---
# [제목]: IapResult.Builder / Public methods <a href="#id-c-iapresult.builder-publicmethods" id="id-c-iapresult.builder-publicmethods"></a>
#
# [요약]: **요약:**
#
# API 문서는 원스토어 결제 시스템의 상세한 API 사용법을 설명합니다. 주요 내용은 다음과 같습니다:
#
# - **결제 요청**: 결제 요청을 위한 요청 파라미터와 서명 검증 방법 설명.
# - **결제 응답**: 결제 결과를 전달하는 두 가지 방식 (`returnUrl`, `callbackUrl`)에 대한 세부 사항 포함.
# - **응답 코드**: 결제 성공 및 실패 시의 응답 코드와 메시지 목록 제공.
#
# **대표 키워드:** 결제 API, 서명 검증, 응답 처리, 결제 결과 전달
#
# 이 요약은 문서의 핵심 내용을 간결하게 전달하여 검색 및 이해를 돕습니다.
#
# [원문]: ***
# --- doc_index: 37 ---
# [제목]: PurchasesUpdatedListener / Public methods <a href="#id-i-purchasesupdatedlistener-publicmethods" id="id-i-purchasesupdatedlistener-publicmethods"></a>
#
# [요약]: **요약:**
#
# API 문서는 원스토어 결제 시스템의 상세한 API 사용법을 설명합니다. 주요 내용은 다음과 같습니다:
#
# - **결제 요청**: 결제 요청을 위한 요청 파라미터와 서명 검증 방법 설명.
# - **결제 응답**: 결제 결과를 전달하는 두 가지 방식 (`returnUrl`, `callbackUrl`)에 대한 세부 사항 포함.
# - **응답 코드**: 결제 성공 및 실패 시의 응답 코드와 메시지 목록 제공.
#
# **대표 키워드:** 결제 API, 서명 검증, 응답 처리, 결제 결과 전달
#
# 이 요약은 문서의 핵심 내용을 간결하게 전달하여 검색 및 이해를 돕습니다.
#
# [원문]: ***
# --- doc_index: 38 ---
# [제목]: PurchaseClient.ProductType / Constants <a href="#id-a-purchaseclient.producttype-constants" id="id-a-purchaseclient.producttype-constants"></a> / SUBS <a href="#id-a-purchaseclient.producttype-subs" id="id-a-purchaseclient.producttype-subs"></a>
#
# [요약]: **요약:**
#
# SUBS는 구독형 상품 타입을 나타내며, 주로 반복적인 결제 모델을 가진 상품을 의미합니다. 이 타입은 OneStore 플랫폼에서 구매 클라이언트의 반복 행동을 정의하는 데 사용됩니다 (출처: OneStore 개발 문서).
#
# **대표 키워드:** SUBS, 구독형 상품, 반복 결제 모델
#
# [원문]: ```
# String SUBS
# ```
# 구독형 상품 타입
# Constant Value: "subscription"
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/references/annotations/purchaseclient.recurringaction.md
# --- doc_index: 39 ---
# [제목]: ProductDetailsParams.Builder / Public methods <a href="#id-c-productdetailsparams.builder-publicmethods" id="id-c-productdetailsparams.builder-publicmethods"></a>
#
# [요약]: **요약:**
#
# **API 요약: 결제 서비스 API**
#
# 이 문서는 결제 서비스를 위한 API 구조와 기능을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 서비스 엔드포인트**: 결제 관련 요청을 처리하는 엔드포인트 정보 제공.
# 2. **결제 요청 및 응답 포맷**: 결제 요청과 응답의 구조와 필요한 파라미터 설명.
# 3. **결제 상태 확인**: 결제 상태를 확인하기 위한 엔드포인트와 요청 방법 설명.
# 4. **결제 결과 처리**: 결제 성공 및 실패 시 개발자에게 전달되는 응답 코드와 메시지 설명.
# 5. **결제 보안**: 서명 및 보안 관련 정보 제공.
#
# **키워드**: 결제 API, 엔드포인트, 요청 포맷, 보안 서명, 결제 상태 확인
#
# [원문]: ***
# --- doc_index: 40 ---
# [제목]: PurchaseClient.Builder / Public Methods <a href="#id-c-purchaseclient.builder-publicmethods" id="id-c-purchaseclient.builder-publicmethods"></a> / build <a href="#id-c-purchaseclient.builder-build" id="id-c-purchaseclient.builder-build"></a>
#
# [요약]: **요약:**
#
# `PurchaseClient` 인스턴스 생성 메서드 `build()`는 구매 클라이언트 객체를 반환합니다. 이 메서드는 `context` 또는 `listener`가 올바르지 않을 경우 `IllegalArgumentException`을 발생시킵니다. 주요 기능은 구매 데이터 관리에 있으며, 이를 통해 앱 내 구매 처리와 관련된 작업을 수행할 수 있습니다. **키워드:** PurchaseClient, build 메서드, 구매 데이터 관리
#
# 이 요약은 `PurchaseClient` 클래스의 핵심 기능과 주요 오류 처리 방식을 간결하게 전달하며, 관련 키워드를 포함하여 검색 품질을 향상시킵니다.
#
# [원문]: ```
# @UiThread
# public [C]PurchaseClientbuild()
# ```
# PurchaseClient 인스턴스를 생성합니다.
# | **Return:**                           |                                          |
# | ------------------------------------- | ---------------------------------------- |
# | [\[C\]PurchaseClient](purchaseclient) |                                          |
# | **Throws:**                           |                                          |
# | java.lang.IllegalArgumentException    | context or listener 가 정상적이지 않을 경우 발생합니다. |
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/references/classes/purchasedata.md
# --- doc_index: 41 ---
# [제목]: SubscriptionParams.Builder / Public methods <a href="#id-c-subscriptionparams.builder-publicmethods" id="id-c-subscriptionparams.builder-publicmethods"></a>
#
# [요약]: **요약:**
#
# **API 요약: 결제 서비스 API**
#
# 이 문서는 결제 서비스를 위한 API 구조와 기능을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 서비스 엔드포인트**: 결제 관련 요청을 처리하는 엔드포인트 정보 제공.
# 2. **결제 요청 및 응답 포맷**: 결제 요청과 응답의 구조와 필요한 파라미터 설명.
# 3. **결제 상태 확인**: 결제 상태를 확인하기 위한 엔드포인트와 요청 방법 설명.
# 4. **결제 결과 처리**: 결제 성공 및 실패 시 개발자에게 전달되는 응답 코드와 메시지 설명.
# 5. **결제 보안**: 서명 및 보안 관련 정보 제공.
#
# **키워드**: 결제 API, 엔드포인트, 요청 포맷, 보안 서명, 결제 상태 확인
#
# [원문]: ***
# --- doc_index: 42 ---
# [제목]: PurchaseData.RecurringState
#
# [요약]: **요약:**
#
# `RecurringState`는 `com.gaa.sdk.iap.PurchaseData` 패키지 내에서 월정액 상품의 반복 구매 상태를 나타내는 어노테이션입니다. 이 어노테이션은 구독 모델의 현재 상태를 정의하여 앱 내에서 구독 관리를 용이하게 합니다.
#
# **키워드:** RecurringState, 구독상태, PurchaseData
#
# [원문]: ```
# public static @interface PurchaseData.RecurringState
# ```
# ```
# com.gaa.sdk.iap.PurchaseData.RecurringState
# ```
# 월정액 상품의 상태값
# --- doc_index: 43 ---
# [제목]: SubscriptionParams / Public methods <a href="#id-c-subscriptionparams-publicmethods" id="id-c-subscriptionparams-publicmethods"></a>
#
# [요약]: **요약:**
#
# **API 요약: 결제 서비스 API**
#
# 이 문서는 결제 서비스를 위한 API 구조와 기능을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 서비스 엔드포인트**: 결제 관련 요청을 처리하는 엔드포인트 정보 제공.
# 2. **결제 요청 및 응답 포맷**: 결제 요청과 응답의 구조와 필요한 파라미터 설명.
# 3. **결제 상태 확인**: 결제 상태를 확인하기 위한 엔드포인트와 요청 방법 설명.
# 4. **결제 결과 처리**: 결제 성공 및 실패 시 개발자에게 전달되는 응답 코드와 메시지 설명.
# 5. **보안 및 서명**: 결제 요청의 보안 처리와 서명 방법 설명.
#
# **키워드**: 결제 API, 엔드포인트, 요청 포맷, 결제 상태 확인, 보안 서명
#
# [원문]: ***
# --- doc_index: 44 ---
# [제목]: PurchaseData.RecurringState / Constants <a href="#id-a-purchasedata.recurringstate-constants" id="id-a-purchasedata.recurringstate-constants"></a> / NON\_AUTO\_PRODUCT <a href="#id-a-purchasedata.recurringstate-non_auto_product" id="id-a-purchasedata.recurringstate-non_auto_product"></a>
#
# [요약]: **요약:**
#
# `NON_AUTO_PRODUCT` 상수는 자동결제가 아닌 구매 건을 나타내며, 값은 `-1`입니다. 이 값은 구매 흐름 파라미터 중 가격 조정 모드를 정의하는데 사용되며, 자동결제 기능이 적용되지 않은 상품을 구분하는 데 핵심적입니다. 키워드: `NON_AUTO_PRODUCT`, `구매흐름`, `가격조정`
#
# **키워드:** `구매흐름`, `가격조정`, `NON_AUTO_PRODUCT`
#
# [원문]: ```
# int NON_AUTO_PRODUCT
# ```
# 자동결제가 아닌 경우
# Constant Value: -1
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/references/annotations/purchaseflowparams.prorationmode.md
# --- doc_index: 45 ---
# [제목]: IapResult / Public methods <a href="#id-c-iapresult-publicmethods" id="id-c-iapresult-publicmethods"></a>
#
# [요약]: **요약:**
#
# **API 요약: 결제 서비스 API**
#
# 이 문서는 결제 서비스를 위한 API 구조와 기능을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 서비스 엔드포인트**: 결제 관련 요청을 처리하는 엔드포인트 정보 제공.
# 2. **결제 요청 및 응답 포맷**: 결제 요청과 응답의 구조와 필요한 파라미터 설명.
# 3. **결제 상태 확인**: 결제 상태를 확인하기 위한 엔드포인트와 요청 방법 설명.
# 4. **결제 취소 및 환불**: 취소 요청 방법과 환불 절차 안내.
# 5. **결제 로그 및 오류 처리**: 로그 확인 방법과 오류 코드 및 메시지 설명.
#
# **키워드**: 결제 API, 엔드포인트, 요청 포맷, 상태 확인, 취소 환불, 오류 처리
#
# [원문]: ***
# --- doc_index: 46 ---
# [제목]: PurchaseData.PurchaseState / Constants <a href="#id-a-purchasedata.purchasestate-constants" id="id-a-purchasedata.purchasestate-constants"></a> / CANCEL <a href="#id-a-purchasedata.purchasestate-cancel" id="id-a-purchasedata.purchasestate-cancel"></a>
#
# [요약]: **요약:**
#
# **API 키:** `APIKEY`
# **기능명:** 결제 API
# **주요 키워드:** 결제 요청, 응답 처리, 보안 서명, 결제 결과 전달
#
# 이 문서는 게임 및 앱 결제를 위한 REST API 사용법을 설명합니다. 주요 기능은 결제 요청(`/payment/request`)과 응답 처리(`/payment/response`)로 구성되어 있으며, 보안을 위한 서명 검증과 결제 결과의 안전한 전달 방법을 포함하고 있습니다. 특히, 결제 성공 및 실패 시의 응답 코드와 메시지, 그리고 개발자 페이로드와 서명 정보의 중요성이 강조됩니다. 결제 프로세스는 개발사의 `returnUrl` 또는 `callbackUrl`을 통해 결과를 전달하며, 이는 결제 성공 시의 확인 및 자동 결제 승인에 활용됩니다.
#
# **키워드:** 결제 API, 서명 검증, 결제 결과 전달
#
# [원문]: ```
# int CANCEL
# ```
# 취소
# Constant Value: 1
# --- doc_index: 47 ---
# [제목]: 06. 원스토어 인앱결제 서버 API (API V7) / **원스토어 OAuth**  <a href="#id-06.-api-apiv7-oauth" id="id-06.-api-apiv7-oauth"></a> / **OAuth 개요** <a href="#id-06.-api-apiv7-oauth" id="id-06.-api-apiv7-oauth"></a>
#
# [요약]: **요약:**
#
# 원스토어 서버 Open API 연동을 위해서는 OAuth v2 인증이 필수적입니다. AccessToken은 Server Open API 호출 시 사용되며, 유효기간은 3600초입니다. 인증 오류 발생 시 `getAccessToken()`을 통해 새로운 AccessToken을 발급받을 수 있습니다. API 호출 시 `Authorization Bearer <AccessToken>` 헤더를 사용해야 하며, 정확한 형식 준수가 중요합니다. 주요 API 엔드포인트와 인증 과정을 통해 안정적인 연동이 가능합니다.
#
# **키워드:** OAuth, AccessToken, API 연동, Authorization Bearer
#
# [원문]: 원스토어 서버 Open API를 연동하기 위해서는 OAuth 인증이 필요합니다.
# * 원스토어 OAuth v2의 이해
# * AccessToken은 원스토어의 Server Open API를 통하여 발급받을 수 있는 값으로 원스토어에서 제공하는 Server Open API 호출시 인증값으로 사용됩니다.
# * AccessToken은 기본적으로 3600초의 유효기간이 있으며, 유효기간이 만료 되거나 600초 미만으로 남은 경우에 getAccessToken()을 호출하면 새로운 AccessToken이 발급됩니다.
# * 기존의 AccessToken도 유효기간이 끝날 때까지는 사용이 가능합니다.
# * 다수의 AccessToken이 발행되는 방식이므로 개발사의 서비스 인스턴스 별로 서로 다른 AccessToken을 취득하고 사용할 수 있는 형태가 됩니다. \
# \
# *   일반적인 연동 흐름은 다음과 같습니다.\
# <figure><img src="https://1837360763-files.gitbook.io/~/files/v0/b/gitbook-x-prod.appspot.com/o/spaces%2Fot0z57AnnXZ02C5qyePV%2Fuploads%2FrewUDEKtBdLoX8gRJs9L%2Fimage.png?alt=media&#x26;token=86dc5393-c873-48cb-af6a-1488ff07b0dd" alt=""><figcaption></figcaption></figure>
# * AccessToken을 얻는 과정(1번)은 API 호출 시 인증 오류가 발생했을 때 호출하면 됩니다. \
# 원스토어의 인앱결제 서버 API의 호출을 위해서는 Authorization Bearer 스킴을 사용하며 호출 샘플은 아래와 같습니다.
# ```
# GET /v7/apps/com.onestore.game.goindol/purchases/inapp/products/product01/SANDBOXT000120004476 HTTP/1.1
# Host: sbpp.onestore.net
# Authorization: Bearer 680b3621-1234-1234-1234-8adfaef561b4
# ```
# Authorization 헤더에는 위 예제와 같이 Bearer + 공백 + AccessToken이 대소문자 구분하여 정확히 입력되어야 합니다.\
# Bearer의 값은 getAccessToken()을 호출하여 발급받은 AccessToken 값입니다.
# 잘못된 예&#x20;
# ```
# Authorization: 680b3621-1234-1234-1234-8adfaef561b4
# Authorization: bearer 680b3621-1234-1234-1234-8adfaef561b4
# Authorization: Bearer <680b3621-1234-1234-1234-8adfaef561b4>
# Authorization:Bearer680b3621-1234-1234-1234-8adfaef561b4
# ```
# \
# --- doc_index: 48 ---
# [제목]: PurchaseFlowParams / Public methods <a href="#id-c-purchaseflowparams-publicmethods" id="id-c-purchaseflowparams-publicmethods"></a> / isPromotionApplicable <a href="#id-c-purchaseflowparams-ispromotionapplicable" id="id-c-purchaseflowparams-ispromotionapplicable"></a>
#
# [요약]: **요약:**
#
# `isPromotionApplicable` 함수는 구독 서비스에서 프로모션 적용 가능 여부를 확인합니다. 이 함수는 프로모션 기간 내에 있는지 판단하여 구독 상품에 대한 프로모션 혜택 적용 여부를 반환합니다. 주요 용도는 구독 관리 시스템 내에서 프로모션 기간을 효과적으로 관리하고 사용자에게 적절한 혜택을 제공하는 데 있습니다. **키워드:** 구독 프로모션 관리
#
# **참고:** 주요 코드값은 변경 없이 유지되었습니다.
#
# [원문]: ```
# booleanisPromotionApplicable()
# ```
# 프로모션 가능 여부를 나타냅니다.\
# | **Returns:** |             |
# | ------------ | ----------- |
# | boolean      | <p><br></p> |
# --- doc_index: 49 ---
# [제목]: PurchaseClientStateListener / Public methods <a href="#id-i-purchaseclientstatelistener-publicmethods" id="id-i-purchaseclientstatelistener-publicmethods"></a>
#
# [요약]: **요약:**
#
# **API 요약: 결제 서비스 API**
#
# 이 문서는 결제 서비스를 위한 API 구조와 기능을 설명합니다. 주요 내용은 다음과 같습니다:
#
# 1. **결제 서비스 엔드포인트**: 결제 관련 요청을 처리하는 엔드포인트 정보 제공.
# 2. **결제 요청 및 응답 포맷**: 결제 요청과 응답의 구조와 필요한 파라미터 설명.
# 3. **결제 상태 확인**: 결제 상태를 확인하기 위한 엔드포인트와 요청 방법 설명.
# 4. **결제 취소 및 환불**: 취소 요청 방법과 환불 정책 안내.
# 5. **결제 로그 및 오류 처리**: 로그 기록 방법과 오류 응답 코드 및 메시지 설명.
#
# **키워드**: 결제 API, 엔드포인트, 요청 포맷, 상태 확인, 취소 환불, 로그 오류 처리
#
# [원문]: ***
# --- doc_index: 50 ---
# [제목]: PurchaseData.PurchaseState / Constants <a href="#id-a-purchasedata.purchasestate-constants" id="id-a-purchasedata.purchasestate-constants"></a> / REFUND <a href="#id-a-purchasedata.purchasestate-refund" id="id-a-purchasedata.purchasestate-refund"></a>
#
# [요약]: **요약:**
#
# REFUND 상수는 환불 처리를 나타내며, 값은 2로 정의됩니다. 이는 구매 데이터에서 반복 상태를 나타내는 중요한 요소로, 환불 관련 기능을 식별하는 데 사용됩니다. 키워드: REFUND, 구매데이터, 반복상태
#
# **요약 키워드:** REFUND, 구매데이터 처리
#
# [원문]: ```
# int REFUND
# ```
# 환불
# Constant Value: 2
# 출처: https://onestore-dev.gitbook.io/dev/tools/billing/v21/references/annotations/purchasedata.recurringstate.md
# --- doc_index: 51 ---
# [제목]: ConsumeParams / Summary <a href="#id-c-consumeparams-summary" id="id-c-consumeparams-summary"></a>
#
# [요약]: **요약:**
#
# **API 문서 요약:**
#
# - **API 버전:** 7.0
# - **주요 기능:** 게임 내 구매 및 결제 처리 API 제공
# - **클래스:** `ConsumeParams`, `ConsumeResult`, `PaymentParams`, `PaymentResult` 등으로 구성
#   - `ConsumeParams.Builder`: 구매 파라미터 생성을 위한 빌더 클래스
# - **결제 처리:** 구매 토큰 생성, 결제 요청, 결제 결과 수신
# - **응답 처리:** 결제 성공/실패 응답 코드 및 메시지 제공
# - **보안:** 서명 검증을 통한 데이터 무결성 보장
#
# **키워드:** 게임 결제 API, 구매 토큰, 서명 검증, 결제 결과 처리
#
# [원문]: ***
# | Nested classes |                                                                             |
# | -------------- | --------------------------------------------------------------------------- |
# | class          | <p>[C]ConsumeParams.Builder</p><p>ConsumeParams의 인스턴스를 쉽게 만들기 위한 빌더입니다.</p> |
# --- doc_index: 52 ---
# [제목]: PurchaseClient.Builder / Public Methods <a href="#id-c-purchaseclient.builder-publicmethods" id="id-c-purchaseclient.builder-publicmethods"></a> / setListener <a href="#id-c-purchaseclient.builder-setlistener" id="id-c-purchaseclient.builder-setlistener"></a>
#
# [요약]: **요약:**
#
# `PurchaseClient.Builder`를 사용하여 `PurchasesUpdatedListener`를 설정하면 `onPurchasesUpdated` 이벤트를 수신할 수 있습니다. 이 메서드는 구매 업데이트 리스너를 지정하여 앱 내 구매 상태 변화를 실시간으로 감지할 수 있게 합니다.
#
# **대표 용어:** PurchaseClient, PurchasesUpdatedListener
#
# **키워드:** 구매 업데이트, 리스너 설정
#
# [원문]: ```
# @UiThread
# public PurchaseClient.Builder setListener([I]PurchasesUpdatedListenerlistener)
# ```
# onPurchasesUpdated 이벤트를 받을 수 있게 지정하세요.
# | **Parameters:**                   |                                                                    |
# | --------------------------------- | ------------------------------------------------------------------ |
# | listener                          | [PurchasesUpdatedListener](../interfaces/purchasesupdatedlistener) |
# | **Returns:**                      |                                                                    |
# | <p>PurchaseClient.Builder<br></p> |                                                                    |
